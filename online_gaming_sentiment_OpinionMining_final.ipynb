# %%
import itertools
import os
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("/content/Dataset.xlsx")

# %%
len(df)
# Out:
# 401

# %%
df.head(10)
# Out:
#                                              opinion     class
# 0                                       মন্তব্য নেই।  নিরপেক্ষ
# 1                                         অভিমত নেই।  নিরপেক্ষ
# 2     অনলাইন গেম শুধুমাত্র  আমাদের  সময়কে নষ্ট করে।   নেগেটিভ
# 3                                ভালো-মন্দ কিছুই না।  নিরপেক্ষ
# 4   অনলাইন গেম খেললে যে মানুষের শুধু সমস্যা-ই হয় ...    পজিটিভ
# 5                                         মতামত নেই।  নিরপেক্ষ
# 6  এটা সত্য যে কিছু গবেষণায় দেখানো হয়েছে যে কিছ...    পজিটিভ
# 7  গেম খেলা একটি স্ব-উন্নয়ন দক্ষতা। যদি কেউ একবা...    পজিটিভ
# 8        গেম খেললে শুধুমাত্র আমাদের সময়েরই অপচয় হয়।    নেগেটিভ
# 9                              ভালো তবে সময়সাপেক্ষ।   নিরপেক্ষ

# %%
df['length'] = df['opinion'].str.split().apply(len)
df.head(20)
# Out:
#                                               opinion     class  length
# 0                                        মন্তব্য নেই।  নিরপেক্ষ       2
# 1                                          অভিমত নেই।  নিরপেক্ষ       2
# 2      অনলাইন গেম শুধুমাত্র  আমাদের  সময়কে নষ্ট করে।   নেগেটিভ       7
# 3                                 ভালো-মন্দ কিছুই না।  নিরপেক্ষ       3
# 4    অনলাইন গেম খেললে যে মানুষের শুধু সমস্যা-ই হয় ...    পজিটিভ      15
# 5                                          মতামত নেই।  নিরপেক্ষ       2
# 6   এটা সত্য যে কিছু গবেষণায় দেখানো হয়েছে যে কিছ...    পজিটিভ      26
# 7   গেম খেলা একটি স্ব-উন্নয়ন দক্ষতা। যদি কেউ একবা...    পজিটিভ      22
# 8         গেম খেললে শুধুমাত্র আমাদের সময়েরই অপচয় হয়।    নেগেটিভ       7
# 9                               ভালো তবে সময়সাপেক্ষ।   নিরপেক্ষ       3
# 10                           এটি বিনোদনের একটি উপায়।  নিরপেক্ষ       4
# 11                                 নেশা ছাড়াই খেলুন।  নিরপেক্ষ       3
# 12   অনলাইন গেমিং সম্পর্কে আমার মতামত হচ্ছে নিরপেক্ষ।  নিরপেক্ষ       7
# 13  আবর্জনা, টাকা নষ্ট, পড়াশুনা নষ্ট, এগুলা দিয়ে ক...   নেগেটিভ      10
# 14                গেম খেলা আমাদের  শরীরের জন্য খারাপ।   নেগেটিভ       6
# 15                                       মন্তব্য নেই।  নিরপেক্ষ       2
# 16                                    কোন মতামত নেই।   নিরপেক্ষ       3
# 17  গেমটি একটি খেলা হিসাবে খেলুন। তেমন সিরিয়াসলি না।  নিরপেক্ষ       8
# 18                       সময়ের অপচয়, এক ধরনের ওষুধ।   নেগেটিভ       5
# 19  আমি সব ধরনের গেম খেলা ঘৃণা করি l বিশেষ করে অনল...   নেগেটিভ      12

# %%
df.length.describe()
# Out:
# count    401.000000
# mean      14.768080
# std       10.716276
# min        2.000000
# 25%        7.000000
# 50%       11.000000
# 75%       20.000000
# max       68.000000
# Name: length, dtype: float64

# %%
df.isna().sum()
# Out:
# opinion    0
# class      0
# length     0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# নেগেটিভ     161
# নিরপেক্ষ    124
# পজিটিভ      116
# Name: class, dtype: int64

# %%
# df = df.sample(frac=1)

# %%
# df

# %%
# df=df.reset_index(drop=True)

# %%
# df.head(10)

# %%
for i in range(10):
  print("Data#"+str(i+1))
  print("Text: "+df['opinion'][i])
  print("Type: "+df['class'][i])
  print(" ")
# Out:
# Data#1
# Text: মন্তব্য নেই।
# Type: নিরপেক্ষ
#
# Data#2
# Text: অভিমত নেই।
# Type: নিরপেক্ষ
#
# Data#3
# Text: অনলাইন গেম শুধুমাত্র  আমাদের  সময়কে নষ্ট করে।
# Type: নেগেটিভ
#
# Data#4
# Text: ভালো-মন্দ কিছুই না।
# Type: নিরপেক্ষ
#
# Data#5
# Text:  অনলাইন গেম খেললে যে মানুষের শুধু সমস্যা-ই হয় তা না, এর থেকে অনেকে উপার্জনও করছে।
# Type: পজিটিভ
#
# Data#6
# Text: মতামত নেই।
# Type: নিরপেক্ষ
#
# Data#7
# Text: এটা সত্য যে কিছু গবেষণায় দেখানো হয়েছে যে কিছু ভিডিও গেম হাত-চোখের সমন্বয়, সমস্যা সমাধানের দক্ষতা এবং তথ্য প্রক্রিয়া করার জন্য মনের ক্ষমতাকে উন্নত করতে পারে।
# Type: পজিটিভ
#
# Data#8
# Text: গেম খেলা একটি স্ব-উন্নয়ন দক্ষতা। যদি কেউ একবার ব্যবহার করে এবং দক্ষতার সাথে তাদের পছন্দের ভারসাম্য বজায় রাখে তবে কোন সমস্যা নেই।
# Type: পজিটিভ
#
# Data#9
# Text: গেম খেললে শুধুমাত্র আমাদের সময়েরই অপচয় হয়।
# Type: নেগেটিভ
#
# Data#10
# Text: ভালো তবে সময়সাপেক্ষ।
# Type: নিরপেক্ষ

# %%
contractions = { 
"বি.দ্র ": "বিশেষ দ্রষ্টব্য",
"ড.": "ডক্টর",
"ডা.": "ডাক্তার",
"ইঞ্জি:": "ইঞ্জিনিয়ার",
"রেজি:": "রেজিস্ট্রেশন",
"মি.": "মিস্টার",
"মু.": "মুহাম্মদ",
"মো.": "মোহাম্মদ",
}

# %%
import string
import re

def clean_text(text, remove_stopwords):

    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)

    # Format words and remove unwanted characters
    whitespace = re.compile(u"[\s\u0020\u00a0\u1680\u180e\u202f\u205f\u3000\u2000-\u200a]+", re.UNICODE)
    bangla_digits = u"[\u09E6\u09E7\u09E8\u09E9\u09EA\u09EB\u09EC\u09ED\u09EE\u09EF]+"
    english_chars = u"[a-zA-Z0-9]"
    punc = u"[(),$%^&*+={}\[\]:\"|\'\~`<>/,¦!?½£¶¼©⅐⅑⅒⅓⅔⅕⅖⅗⅘⅙⅚⅛⅜⅝⅞⅟↉¤¿º;-]+"
    bangla_fullstop = u"\u0964"     #bangla fullstop(dari)
    
    punctSeq   = u"['\"“”‘’]+|[.?!,…]+|[:;]+"
    
    text = re.sub(bangla_digits, " ", text)
    text = re.sub(punc, " ", text)
    text = re.sub(english_chars, " ", text)
    text = re.sub(bangla_fullstop, " ", text)
    text = re.sub(punctSeq, " ", text)
    text = whitespace.sub(" ", text).strip()
    
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;‘:‘ ’', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]। ,', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub(r"[\@$#%~+-\.\'।\"]"," ",text)
    text = re.sub(r"(?m)^\s+", "", text)
    text = re.sub("[()]","",text)
    text = re.sub("[‘’]","",text)
    text = re.sub("[!]","",text)
    text = re.sub("[/]","",text)
    text = re.sub("[:]","",text)
    text= re.sub('\ |\?|\.|\!|\/|\;|\:', ' ',text)
    text= text.strip("/")
    
            
    return text

# %%
clear_text2 = []
clear_type2 = []

for textLine in df['opinion']:
  clear_text2.append(clean_text(textLine, True))
for typeLine in df['class']:
  clear_type2.append(clean_text(typeLine, False))

# %%
clear_text2
# Out:
# ['মন্তব্য নেই',
#  'অভিমত নেই',
#  'অনলাইন গেম শুধুমাত্র আমাদের সময়কে নষ্ট করে',
#  'ভালো মন্দ কিছুই না',
#  'অনলাইন গেম খেললে যে মানুষের শুধু সমস্যা ই হয় তা না এর থেকে অনেকে উপার্জনও করছে',
#  'মতামত নেই',
#  'এটা সত্য যে কিছু গবেষণায় দেখানো হয়েছে যে কিছু ভিডিও গেম হাত চোখের সমন্বয় সমস্যা সমাধানের দক্ষতা এবং তথ্য প্রক্রিয়া করার জন্য মনের ক্ষমতাকে উন্নত করতে পারে',
#  'গেম খেলা একটি স্ব উন্নয়ন দক্ষতা যদি কেউ একবার ব্যবহার করে এবং দক্ষতার সাথে তাদের পছন্দের ভারসাম্য বজায় রাখে তবে কোন সমস্যা নেই',
#  'গেম খেললে শুধুমাত্র আমাদের সময়েরই অপচয় হয়',
#  'ভালো তবে সময়সাপেক্ষ',
#  'এটি বিনোদনের একটি উপায়',
#  'নেশা ছাড়াই খেলুন',
#  'অনলাইন গেমিং সম্পর্কে আমার মতামত হচ্ছে নিরপেক্ষ',
#  'আবর্জনা টাকা নষ্ট পড়াশুনা নষ্ট এগুলা দিয়ে কিছু হয় না',
#  'গেম খেলা আমাদের শরীরের জন্য খারাপ',
#  'মন্তব্য নেই',
#  'কোন মতামত নেই',
#  'গেমটি একটি খেলা হিসাবে খেলুন তেমন সিরিয়াসলি না',
#  'সময়ের অপচয় এক ধরনের ওষুধ',
#  'আমি সব ধরনের গেম খেলা ঘৃণা করি বিশেষ করে অনলাইন গেম',
#  'ভালো কিন্তু আমরা প্রতিদিন আমাদের মূল্যবান সময় নষ্ট করতে পারি না',
#  'মাত্রাতিরিক্ত অনলাইন গেম আমাদের চোখের ক্ষতিসাধণ করে',
#  'অনলাইন গেম খেলা আমাদের মস্তিষ্কের কর্মক্ষমতা বাড়িয়ে দেয়',
#  'এটা ভালো যদি আপনি এটিকে বিনোদন হিসেবে নেন তবে আপনাকে অবশ্যই দীর্ঘ সময়ের গেমিং সম্পর্কে সচেতন হতে হবে',
#  'অনলাইনে গেম খেলা খারাপ',
#  'অনলাইনে গেম খেলা স্বাস্থ্যের জন্য ক্ষতিকর',
#  'এটা মানুষের মস্তিষ্কের জন্য আতঙ্ক',
#  'আমি একটা জিনিস বলতে চাই যে যদি সম্ভব হয় তাহলে আমাদের অনলাইন গেমিং এড়িয়ে চলতে হবে সময় বাঁচাতে',
#  'শিক্ষাগত শিল্প এবং প্রাসঙ্গিক খেলা সবার জন্য ভাল হবে কিছু গেম আমাদের দৈনন্দিন জীবনকে নষ্ট করে দিতে পারে যেমনঃ পাবজি ফ্রি ফায়ার এবং আরো কিছু অপ্রাসঙ্গিক গেম',
#  'ইচ্ছা হলে খেলি আবার ইচ্ছা না হলে খেলি না',
#  'প্রাপ্তবয়স্ক থেকে বাচ্চারা ফ্রি ফায়ার পাবজির মতো অনলাইন গেম খেলে অনেক সময় ব্যয় করে এবং এটি পড়াশোনায়র ক্ষতি করে',
#  'অনলাইন গেম খেলতে মজা লাগে এবং বিরক্তিকর সময় নিমিষেই দূর হয়ে যায়',
#  'অনলাইন গেম বহিস্কার করা হোক বাংলাদেশের কোনো লোক যেন গেম খেলে সময় অপচয় না করে সেই উদ্যেগ নেয়া হোক',
#  'সবকিছু বাদ দিয়ে গেম খেললে পরিবারের মানুষের ভেতর মনোমালিন্যতার সৃষ্টি হয়',
#  'অনলাইন গেম সম্পর্কে তেমন কোনো অভিজ্ঞতা আমার নেই',
#  'পরিমিতভাবে অনলাইন গেম খেলা ঠিক আছে',
#  'নিয়ন্ত্রণে থাকা পর্যন্ত কোনো কিছুই খারাপ নয়',
#  'ভালো গেম খেলার দক্ষতা থাকলে উপার্জন করার সম্ভব',
#  'এতে আপনার মূল্যবান সময় নষ্ট হয়',
#  'এটা আমার জন্য কখনই প্রয়োজন ছিল না বরং মাঝে মাঝে আমি শুধুমাত্র টাইম পাসের জন্য অনলাইন গেম খেলি',
#  'মতাামত শূন্য',
#  'এর অনেক পার্শ্বপ্রতিক্রিয়া আছে এবং মানুষ এতে করে বিভিন্ন রোগের উপসর্গের সম্মুখীন হয়',
#  'গেম খেলে মানসিক প্রশান্তি পাওয়া যায়',
#  'সময় নষ্ট এলাকা বলে মনে হয় গেম খেলা',
#  'সময় কাটানোর জন্য ভালো',
#  'যেহেতু গেম খেলা হয়ে উঠে না সেহেতু এর ভালো মন্দ দিক সম্পর্কে ধারনা নেই',
#  'বর্ধিত সময়ের জন্য অনলাইন গেম খেলেও আসক্তি হতে পারে',
#  'আমি মনে করি সম্পূর্নরুপে ব্যাক্তির উপরেই নির্ভরশীল কেননা অবসরে বিনোদনের একটা মাধ্যম হিসেবে এর কোনো প্রকার ক্ষতি আছে বলে আমি মনে করি না',
#  'যদি আসক্তি নিয়ে অনলাইন গেমের পিছনে লেগে থাকে তাহলে তা অবশ্যই খারাপ',
#  'আমরা যদি উন্নত দেশের দিকে তাকাই তাদের গেমিং সেক্টর অনেক বেশি উন্নত এবং সেখানে অনেক শিক্ষার্থী গেমিংয়ে তাদের ক্যারিয়ার সেট করে',
#  'আমাদের শিক্ষার্থীদেরও অনলাইন গেমিংয়ের সঠিক শিক্ষার প্রয়োজন এবং একজন ভালো মানুষ হওয়ার জন্য তাদের যথাযথ শিক্ষারও প্রয়োজন',
#  'কিছুই বলার নাই অনলাইন গেম এর খারাপ ভালো দিক সম্পর্কে',
#  'সময়ের অপচয় ছাড়া কিছুই না',
#  'অনলাইন গেম আমাদের অবসর সময় কাটাতে সাহায্য করে',
#  'নিজেকে নিয়ন্ত্রণ করে গেমিং করলে খুব বেশি সমস্যা হওয়ার কথা নয় যদি না আসক্ত হয়ে যায় শুধু বিনোদন রিফ্রেশমেন্ট এর জন্য দিনের কোন একটা সময় গেমিং করা যেতে পারে',
#  'অনলাইনে গেম খেলা খারাপ এর ফলে মানসিক সমস্যা হতে পারে',
#  'অনলাইন গেম সম্পর্কে আমার কোনো মন্তব্য নেই',
#  'আমরা সাধারণত বিনোদনের জন্য গেমিং করে থাকি একেক জন মানুষ একেকটা মাধ্যমকে বিনোদনের জন্য ব্যবহার করে থাকে সেটা মুভি সিরিজ বই পড়া বা গেমিং যে কোনো একটা হতে পারে সেখানে গেমিংকে অফেন্সিভ হিসেবে দেখানোর কোনো মানে হয় না আমি আমার বিনোদনের জন্য যে মাধ্যমটা ব্যবহার করার করতেছি সেটা যদি কারো ক্ষতির কারন না হয় সেখানে কোনো সমস্যা দেখছি না',
#  'অনলাইন গেম খেলার ফলে প্রতিদিন আমাদের মূল্যবান সময় নষ্ট হয়',
#  'অনলাইনে গেমে খেলে কতটা সময় ব্যয় করবো তা সবসময় আমার নিজের উপর নির্ভর করবে যদি আমি মনে করি যে আমার জীবনে এর খারাপ প্রভাব আছে তাহলে আমাকে অবশ্যই এই গেমগুলি ছেড়ে দিতে হবে',
#  'মন্তব্য নেই',
#  'কখনও কখনও এটি ভালো তবে অবশ্যই এটি আমাদের জন্য ক্ষতিকারক',
#  'কিছুুই না',
#  'এটা শুধু উপভোগের জন্য নিন',
#  'ক্ষতিকারক বিষয় জড়িত থাকার কারণে আমি অনলাইন গেম খেলি না',
#  'অনলাইন গেম খেলে সময় নষ্ট করা ছাড়া আর কিছুই না',
#  'আমার মতামত হলো অনলাইন গেম হচ্ছে মজা নিতে কাটানো কিছু মুহূর্ত যেটাকে আমরা সময় অপচয় এর ভেতর ফেলতে পারি',
#  'অনলাইন গেম খেললে পরিবাবের সাথে দূরুত্ব তৈরি হতে পারে',
#  'আপনি যখন অতিরিক্ত বেশি সময় নষ্ট করছেন তখন এটি খুব খারাপ',
#  'আপনি খেলার সময় একটি নির্দিষ্ট সীমা অনুসরণ করলে এটি ঠিক হবে',
#  'অনলাইন গেম খেলা একজন ব্যক্তিকে তার কৌশলগত চিন্তাভাবনা বিকাশে সহায়তা করে',
#  'বাচ্চারা অনলাইন গেম খেলে অনেক বেশি সময় নষ্ট করে এবং এটা বাচ্চাদের জন্য ক্ষতিকর',
#  'অনলাইন গেম খেলা একটি শিশুর মানসিক বৃদ্ধিতে সবচেয়ে গুরুত্বপূর্ণ ভূমিকা পালন করে তবে এটি সীমাবদ্ধ এবং নিয়ন্ত্রণের মধ্যে হওয়া উচিত',
#  'যতক্ষণ না অনলাইন গেম খেলা আমাদের মানসিকতা আচার আচরণ শিষ্টাচার বা সমাজের ক্ষতি না করে ততক্ষণ এটি বিনোদন হিসেবে একেবারেই ঠিক',
#  'মন্তব্য নেই অনলাইন গেম খেলা সম্পর্কে',
#  'কিছুই বলার নাই অনলাইন গেম সম্পর্কে',
#  'এটা আসক্তি কিন্তু এর সাথে অন্য কাজের অগ্রাধিকার অনুভব করা উচিত অনলাইন গেমিং মুছে না দিয়ে আমাদের এই প্ল্যাটফর্মটিকে প্রধানত আমাদের বাচ্চাদের জন্য একটি শেখার পরিবেশ পরিবর্তন করার দিকে আরও বেশি মনোযোগ দেওয়া উচিত',
#  'কিছু সময় কাটানোর জন্য ভালো মাধ্যম',
#  'অনলাইন গেম খেলা মানুষকে ব্যস্ত করে ফেলে এবং যেটা একসময় মানুষকে আসক্তির দিকে নিয়ে যায়',
#  'অনলাইন গেম খেলা এক ধরনের ডিজিটাল ড্রাগ',
#  'অনলাইন গেমিং সময় নষ্ট করা ছাড়া আর কিছুই না',
#  'অনলাইন গেম খেলা সত্যিই একটি খারাপ অভ্যাস',
#  'সীমার মধ্যে অনলাইন গেম খেলা উচিত যেনো এর ক্ষতিকর প্রভাব না পড়ে',
#  'অনলাইন গেম খেলা বিনোদনের একটি মাধ্যম',
#  'আমি গেমিং পছন্দ করি না',
#  'বেশিরভাগ ক্ষেত্রে আমি অনলাইন গেম খেলা সমর্থন করি না',
#  'সময় নষ্ট করা ছাড়া কিছুই না অনলাইন গেম খেলা',
#  'নিজেকে নিয়ন্ত্রণ করতে পারলে ভালো তাছাড়া ক্ষতিকর',
#  'অনলাইন গেমটি বিনোদনমূলক কিন্তু দৈনিক ভিত্তিতে দীর্ঘ সময়ের জন্য অনলাইন গেম খেলা একটি ক্ষতিকর দিক',
#  'অনলাইন গেম খেলার কোনো দরকার আসে না',
#  'অনলাইন গেমে আসক্তি হয়ে গেলে সমস্যা',
#  'জীবনের প্রয়োজনীয় সময়কে কাজে লাগানোর জন্য সব সময় গেম খেলতে হবে',
#  'প্রত্যাহিক কাজে নিয়োজিত ব্যক্তিরা কখনো গেম খেলে সময় নষ্ট করে না',
#  'বিনোদনের জন্য খেলা যায় কিন্তু আসক্ত হয়ে যাওয়া মোটেও কাজের কথা নয় যদি আসক্তি আসে তাহলে অবশ্যই গ্যাপ দেওয়া বা ছেড়ে দেয়া উচিৎ',
#  'এটি বিনোদনের একটি মাধ্যম কিন্তু বর্তমানে এটি প্রধানত নেতিবাচক প্রভাব ফেলেছে',
#  'অনলাইন গেম খেলা ভালো না আমার দৃষ্টিতে',
#  'আমি গেইম খুব কম খেলি শিক্ষামূলক গেইম বা পাজল গেইম হলে খেলে থাকি',
#  'অনলাইন গেম মানসিক স্বাস্থ্যের জন্য ক্ষতিকর এছাড়া এটা সময় নষ্ট করে',
#  'এটা আমাদের মূল্যবান সময় নষ্ট করে আমাদের পড়াশোনায় বাঁধা দেয়',
#  'মানসিক প্রশান্তির জন্য অনলাইন গেম খেলা ভালো',
#  'অনলাইন গেম খেলা ভাালো মানসিক বিকাশের জন্য',
#  'অনলাইন গেম খেলা আমাকে আনন্দের সাথে আমার অবসর সময় কাটাতে সাহায্য করে এবং এটি আমাকে মানসিকভাবে সক্রিয় থাকতেও সাহায্য করে',
#  'অনলাইন গেমিং আমাদের দিনের অনেকটা সময় নষ্ট করে',
#  'গেম খেলা বিনোদনের উদ্দেশ্য মাত্র তবে এটা নিয়ে সিরিয়াস হয়ে পড়লে ক্ষতিকর',
#  'আমি মনে করি অনলাইন গেম খেলা সময়ের অপচয় করে এবং মস্তিষ্কেরও ক্ষতিসাধন করে',
#  'অতিরিক্ত গেম খেলা একজন সুস্থ ব্যক্তিকে অস্বাভাবিক করে তুলতে পারে',
#  'কখনও কখনও আমাদের অনলাইন গেম খেলতে হয় কারণ আমরা যখন একটানা কাজ করে ক্লান্ত হয়ে পড়ি তখন আমরা খুব বিরক্ত বোধ করি তখন যদি আমরা গেম খেলি তবে এটি আমাদের আনন্দ দেয় যেটা অনলাইন গেম খেলার ইতিবাচক দিক বলে আমি মনে করি',
#  'অনলাইন গেম খেলা আমার জীবনের একটা অংশ বলা চলে',
#  'অনলাইন গেম খেলা আমাদের দৈনন্দিন জীবনের একটি অংশ সময় কাটানোর জন্য এটি একটি ভাল মাধ্যম',
#  'অবসর সময় কাটানোর ক্ষেত্রে ভালো উপায়',
#  'সময় অপচয় হয় এবং ইন্টারনেট কিনতে টাকার প্রয়োজন পড়ে',
#  'এটি ভালো যদি লিমিটেড সময়ে খেলা হয়',
#  'মানুষের নৈতিকতা বিকাশের লক্ষ্যে গেম খেলার বিকাশ করা উচিত যা মানুষকে শান্তিতে থাকতে দেয়',
#  'এটি একজন ব্যক্তির গুরুত্বপূর্ণ সময় নষ্ট করে',
#  'কোন মন্তব্য নেই অনলাইন গেম খেলা নিয়ে',
#  'ভালো খারাপ কোনোকিছু নিয়ে বলার কিছু নাই অনলাইন গেম সম্পর্কে',
#  'গবেষণায় দেখা গেছে যে নিয়মিত ভিডিও গেম খেললে মস্তিষ্কে ধূসর পদার্থ বাড়তে পারে এবং মস্তিষ্কের সংযোগ বাড়াতে পারে',
#  'গেম খেলা একটি ইতিবাচক দিক বলে মনে করি',
#  'অনলাইন গেম খেলা জীবনের মূল্যবান সময় নষ্ট করে',
#  'ভালো সময় কাটানোর ক্ষেত্রে হঠাৎ খেলা যেতে পারে তবে সেটা যেনো মাত্রাতিরিক্ত হয়ে না পড়ে',
#  'অনলাইন গেম খেলা ভালো এবং সেই সাথে আনন্দদায়ক',
#  'এটা আমাদের সময় কাটানোর জন্য ভালো',
#  'এটি আমাদের জীবনের একটি অপরিহার্য অংশ হয়ে উঠেছে',
#  'ব্যক্তিগতভাবে আমি গেম খেলা পছন্দ করি না',
#  'গেম খেলা শুধু সময়ের অপচয় ছাড়া কিছুই না',
#  'অনলাইন গেম সম্পর্কে জানা নেই',
#  'আমরা একটি বধ্য পরিবেশে বাস করি খেলার মতো তেমন কোন পরিবেশ নেই তাই বিনোদনের জন্য হলেও কিছু সময় অনলাইন গেম খেলা দরকার',
#  'আমাদের মজার জন্য হলেও অনলাইন গেম খেলা উচিত',
#  'অবসর সময়ের জন্য ভালো অনলাইন গেম খেলা',
#  'অনলাইন গেম থেকে ভালো কিছুই আসে না',
#  'অনলাইন গেমস শিক্ষা জীবনে ছাত্র ছাত্রীদের উপর প্রভাব পেলে এটি সময় নষ্টের পাশাপাশি জীবন গঠনে বাঁধা হয়ে দাঁড়ায় সুতারং অনলাইন গেমসকে প্রত্যাখান করাই উচিৎ',
#  'গেম খেলা খারাপ আমার দৃষ্টিতে',
#  'গেম খেলা যার যার ব্যক্তিগত ইচ্ছা বলে আমার মনে হয়',
#  'উপভোগের উদ্দেশ্যে এটি ঠিক আছে কিন্তু যখন এটি গেমিং আসক্তিতে চলে যায় তখন এটি যে কারও জন্য সমস্যার কারণ হতে পারে',
#  'আমাদের মূল্যবান সময় নষ্ট করে',
#  'আমি যখন গেম খেলি তখন আমার সময়টা উপভোগ্য হয়ে উঠে',
#  'এটি এমন একটি কারণ যা আমাদের পিতামাতার সাথে এবং আমাদের সমাজের সাথে আমাদের সম্পর্ককে খারাপ করে তুলতে পারে',
#  'এটি না খেলা ই উত্তম কিন্তু সময় নষ্ট না করে অল্প সময়ের জন্য শিক্ষামূলক গেম খেললে তা গ্রহনযোগ্য কিন্তু অতিরিক্ত সময় ব্যয় করে অপ্র্যজনীয় জিনিসে সময় ব্যয় না করা ই ভালো',
#  'অনলাইন গেম খেলা স্বাস্থ্যের জন্য ক্ষতিকর',
#  'কোনোরুপ মন্তব্য নেই অনলাইন গেম খেলা না খেলা নিয়ে',
#  'অনলাইনে গেম খেলা খুব খারাপ বলে আমি মনে করি',
#  'বিনোদন এর জন্যে প্রয়োজন কিন্তু বেশি মাতামাতি না করাই ভালো',
#  'সবকিছুুতে সীমাবদ্ধতা থাকা উচিৎ',
#  'গেম খেলা আমাদের সময়ের অপচয় মাত্র',
#  'সীমা অতিক্রম না করা পর্যন্ত অনলাইন গেম ক্ষতিকর নয় কেউ যদি ওভারটাইম করে অনলাইন গেম না খেলে তাহলে এটা ক্ষতিকর নয় আবার অনেক লোক গেম খেলার জন্য প্রচুর অর্থ ব্যয় করে যা মোটেও ভাল নয় আমার মনে হয় তারা একটি মূল্যহীন জিনিসের জন্য অর্থ ব্যয় করছে যদি কেউ গেম খেলতে চায় তবে তা সীমিত রাখতে হবে যতক্ষণ না এটি ব্যক্তির জন্য ক্ষতিকর হয়',
#  'এটা আমাদের আগামী প্রজন্মের জন্য একেবারেই উদ্বেগজনক এটা তাদের অসুস্থ করে তোলে শৃঙ্খলাহীন হিংস্র এবং আরও অনেক কিছু করে তুলে একটি জাতির মেরুদন্ড ধ্বংস করে ফেলে',
#  'এই মুহূর্তে গেমিং খাতে একটি বড় ই স্পোর্টস বিনিয়োগ রয়েছে পিসি বা কনসোল গেমগুলি এখন ক্রিকেট ফুটবল ইত্যাদির মতো শারীরিকভাবে খেলা খেলার সাথে তুলনা করা হয়৷ যদি একটি বাচ্চা একই গেমিং প্ল্যাটফর্মে অন্যান্য বাচ্চাদের ছাড়িয়ে যাওয়ার মতো প্রতিভাবান হয় তবে সে সহজেই বিশ্বের শীর্ষ উপার্জনকারীদের একজন হতে পারে৷ সুতরাং কেউ যদি সিরিয়াস গেম খেলে সে বা সে অন্যান্য ক্রিকেট বা ফুটবল পেশাদার খেলোয়াড়দের মতো একজন পেশাদার খেলোয়াড় হতে পারে',
#  'গেম এর ব্যাপারে কোনো মতামত নেই',
#  'অনলাইন গেম সম্পর্কে ধারণা নেই',
#  'আমি তখনই অফলাইন মিনি গেম পছন্দ করি যখন আমার কিছুই করার থাকে না যেনো ক্ষতিসাধ্ণ না হয়',
#  'প্রতিযোগিতামূলক গেম দ্রুত চিন্তা করার ক্ষমতা উন্নত করতে সাহায্য করে',
#  'বিনোদনের জন্য অনলাইন গেম খেলি',
#  'সময় নষ্ট করা ছাড়া এটা আর কিছুই না৷ জীবনে বড় হতে হলে এইসব সময় নষ্ট করা খেলা থেকে দূরে থাকা অনেক জরুরী',
#  'সতেজতার জন্য অনলাইন গেম খেলা উচিত',
#  'অনলাইন গেম খেলা ভালো প্ল্যাটফর্ম এর ভেতর পড়ে',
#  'অনলাইন গেম খেলা সীমাবদ্ধতা অনুযায়ী হলে সবসময়ই ভালো কিন্তু সীমাবদ্ধতা পেরিয়ে গেলে সবসময় ক্ষতিকর',
#  'আপনি যখন এটি খেলেন তখন এটি ভালো কিন্তু যখন এটি আপনাকে খেলে তখন এটি খুব বিপজ্জনক হতে পারে',
#  'আমাদের গেম খেলা উচিত এটা আমাদের আইকিউ লেভেল বাড়াতে সাহায্য করে তবে তা সীমিত সময়ের জন্য হওয়া উচিত আমার মতে মিনিট মিনিটের সীমা থাকা উচিত',
#  'অনলাইন গেম খেলা কখনো ভালো আবার কখনো জীবনের জন্য খারাপ',
#  'এটি খেলা ভালো তবে বর্তমানে মানুষ এর প্রতি সময় অনেক বেশি ব্যয় করে যা করা উচিত না খুব কম সময় এর প্রতি ব্যয় করলে সব দিক থেকে ঠিক থাকবে',
#  'এটা ঠিক আছে যতক্ষণ না আপনি জানেন আপনি কি করছেন আপনার জীবনের প্রতি',
#  'নিরপেক্ষ থাকা উচিৎ অনলাইন গেম খেলা নিয়ে',
#  'আমি সবসময় গেম খেলা পছন্দ করি না কিন্তু বিরক্তিকর সময় পার করি গেম খেলে',
#  'গেম খেলা গুরুত্বপূর্ণ কিছুই না',
#  'আমি কোন গেম খেলায় আগ্রহী নই',
#  'অনলাইন গেম খেলা মূলত সাময়িক মানষিক সুখ দেয় কিন্তুু এটার ক্ষতিকর দিক প্রচুর এই গেম খেলার ফলে অনেকে আসক্ত হয়ে পড়ে এবং পড়াশুনোর প্রতি অমনোযোগী হয়ে পড়ে',
#  'অনলাইন গেম খেলার ফলে অনেকে তাদের মানুষিক ভারসাম্যতাও হারাতে পারে',
#  'অনলাইন গেম খেলার প্রতি আগ্রহী নই',
#  'মতামত দেওয়ার মতো ধারণা নাই অনলাইন গেম সম্পর্কে',
#  'সময় নষ্ট করা ছাড়া কিছুই না এইজন্য অনলাইন গেম না খেলাই ভালো',
#  'অনলাইন গেমটি একটি বিনোদন হিসাবে খেলা উচিত যদি না কেউ ই খেলাধুলায় পেশাদার হয় অন্যথায় এটি আমাদের দৈনন্দিন জীবনকে ব্যাহত করতে পারে',
#  'প্রযুক্তির ভালো এবং খারাপ উভয় দিকই আছে কিন্তু আমাদের নিজেদের নিয়ন্ত্রণ করার চাবিকাঠি রয়েছে তাই অনলাইন গেম খেললে প্রতিক্রিয়া কেমন হতে পারে সেটা সম্পর্কে ধারণা থাকতে হবে',
#  'কিছু সময় কাটানোর জন্য অনলাইন গেম খেলা আকর্ষণীয় ব্যাপার বলে মনে হয়',
#  'ভালো এবং খারাপ দুটো দিকই আছে অনলাইন গেম খেলায়',
#  'আমি অনলাইন গেম খেলি না সুতরাং অনলাইন গেম সম্পর্কে আমার কোন মতামত নেই',
#  'অনলাইন গেম খেলা সুখী বোধ করার সেরা উপায়',
#  'অনলাইন গেমস আমাদের মধ্যে খুব একটা খারাপ প্রভাব ফেলেছে তা কিন্তু না অনলাইন গেমসের পজেটিভ দিকটাও দেখা প্রয়োজন আমাদের অনলাইন গেমস খেলে এখন অনেকেই জীবিকার পথ বেঁচে নিয়েছে',
#  'কখনও কখনও অনলাইন গেম খেলা মনকে সতেজ করার জন্য ভালো',
#  'আপনি যদি অনলাইন গেম এর ভালো ব্যবহার করতে পারেন তবে এটি বিনোদনমূলক হতে পারে কিন্তু আপনি যদি এটিতে আসক্ত হন তবে এটি খুব বিপজ্জনক',
#  'মন্তব্য নেই',
#  'চিন্তাহীন ভাবে মানুষের এভাবে বেশিরভাগ সময় গেমে পড়ে থাকা সব দিক দিয়েই ধ্বংস ডেকে আনে',
#  'সময়ের অপচয় ছাড়া আর কিছু না অনলাইন গেম খেলা',
#  'অনলাইন গেম না খেলাই ভালো',
#  'অনলাইন গেমকে আপনি যেভাবে নিবেন তা আপনার লাইফে সেরকম ইফেক্টই ফেলবে',
#  'গেম খেলা মোটেও ভালো না',
#  'সময় কাটানোর সবচেয়ে খারাপ জিনিস',
#  'আপনি যদি আসক্ত হন তবে অনলাইন গেম খেলা খুব খারাপ এছাড়া এটি স্বাভাবিক',
#  'মাদক দ্রব্য সেবন করছি না তাই আমি মনে করি মাদক দ্রব্য গ্রহণ করার চেয়ে অনলাইন গেম খেলা ভালো',
#  'অনলাইনে গেম খেলা খারাপ অভ্যাস',
#  'আমার সবচেয়ে প্রিয় জিনিসটি হল গেমিং গেম খেললে মন ভালো থাকে আমার',
#  'গেম খেলা খাারাপ অভ্যাস',
#  'অনলাইন গেম কাছের বন্ধুদের সাথে খেলা উচিত না কেননা তাতে আসক্তিতে পড়ে যাওয়ার সম্ভাবনা বেশি থাকে',
#  'নিজেকে নিয়ন্ত্রণ করা সবচেয়ে সুন্দর জিনিস আমি বন্ধুদের সাথে গেম খেলতে ভালোবাসি এর মানে এই নয় যে আমি ঘন্টার পর ঘন্টা গেম খেলব',
#  'অনলাইন গেম খেলা জরুরি বিষয় নয় আনন্দ পেতে গেম খেলি',
#  'অনলাইন গেম খেলা ভালো না এতে শারীরিক অসুস্থতা হতে পারে',
#  'গেম খেলা আপনাকে মানসিক চাপ কমাতে সাহায্য করে এবং আপনার বিশ্লেষণাত্মক দক্ষতাও বিকাশে সাহায্য করে',
#  'শুধু বিনোদন এবং মজার জন্য অনলাইন গেম খেলি',
#  'আমি মনে করি এটি শুধুমাত্র বিনোদন এবং কিছু সময় বিশ্রামের জন্য খেলা',
#  'চাইলেই অন গেম খেলা ছেড়ে দেওয়া যায় যেটা আমার কাছে মনে হয়ছে মাঝেমধ্যে সময় কাটাতে অনলাইন গেম খেলি',
#  'অনলাইন গেম মানসিক শান্তি দেয়',
#  'বিরক্তিকর খেলা হচ্ছে অনলাইন গেম',
#  'গেম একটি নির্দিষ্ট সময়ের জন্য আমাদের কিছু আনন্দ দেয় কিন্তু এটি আমাদের জন্য ভালো নয় আজ এটা সব প্রজন্মের মানুষের জন্য বিশেষ করে তরুণ প্রজন্মের জন্য বিপদ হয়ে উঠছে তবুও অনেক মানুষ গেম খেলে তাদের মূল্যবান সময় নষ্ট করছে',
#  'সময় কাটানোর ভালো মাধ্যম অনলাইন গেম খেলা যদি ইন্টারনেট ভালো থাকে তবে আসক্তি খারাপ সেটা গেম হোক বা অন্য কিছু',
#  'গেম খেলা আমাদের পরবর্তী প্রজন্মের জন্য খুবই খারাপ অভ্যাস হবে',
#  'অনলাইন গেমিং ভালো তবে সবসময়ই অনলাইন গেম খেলা খুব একটা ভালো হয় না প্রত্যেকের এটি খেলার কিছু সীমা থাকা উচিত',
#  'অনলাইন গেমটি খুবই খারাপ কারণ এতে আমাদের মূল্যবান সময় নষ্ট হয়',
#  'কখনো ভালো আবার কখনো খারাপ',
#  'ধারণা নেই অনলাইন গেম সম্পর্কে',
#  'অনলাইন গেম ভালো আমি এ পর্যন্ত মনে করি',
#  'যতক্ষণ না অবধি অনলাইন গেম আপনাকে নিয়ন্ত্রণ করে ততক্ষণ ক্ষতিকারক নয়',
#  'আমি খেলি না কারণ এটা আমাদের দৈনন্দিন জীবনকে ধ্বংস করে দেয়',
#  'মাঝে মাঝে আমি অনলাইন গেম খেলি তবে সবসময় না',
#  'অনলাইন গেম খেলা খুবই ক্ষতিকর',
#  'অবসর সময় কাটানো যায় অনলাইন গেম খেলে',
#  'মন্তব্য কিছুই নেই',
#  'বিনোদনের জন্য মাঝে মধ্যে অনলাইন গেম খেলে থাকি',
#  'অনলাইন গেম খুবই খারাপ এতে আমাদের মূল্যবান সময় নষ্ট হয় আমি জানি অনলাইন গেম খারাপ',
#  'এটা মানুষকে মানসিকভাবে অনেক ক্ষতি করে যার ফলে কোন কাজে মন বসে না',
#  'সময় কাটানোর জন্য অনলাইন গেম একটি খুব ভাল মাধ্যম কিন্তু দিনে দিনে এটিতে মানুষ আসক্ত হয় সতেজতা এবং আসক্তির মধ্যে পার্থক্যটি বোঝার জন্য অনলাইন গেম উদাহরণ হিসেবে গন্য করা যায়',
#  'সময় অতিবাহিত করার মাধ্যম',
#  'অনলাইন গেমের ফলে একজন মানুষ তার সঠিক মানসিকতা বিকাশ ঘটাতে পারে না',
#  'অনলাইন গেম খেলতে আমার ভালো লাগে',
#  'মূলত আমাদের এটির প্রয়োজন নেই কেননা এটি কেবল সময়ের অপচয় করে',
#  'সময় নষ্ট হয় অনলাইন গেম খেলে',
#  'অনলাইন গেম খেলা বর্তমান যুব সমাজের জন্য ক্ষতিকারক দিক',
#  'এটা সরকারি ভাবে বন্ধ করা উচিত এটা শিক্ষার্থীদের লেখা পড়া ধ্বংস করছে এবং এই গেমস জাতিকে পঙ্গু করে ফেলছে',
#  'আমি অনলাইন গেম অধিক সময় ধরে কখনো খেলি নাই আর অধিক সময় গেমের মধ্যে থাকলে বিভিন্ন ধরনের সমস্যার সম্মুখীন হতে হয় সেটা ছাত্র ছাত্রী থেকে শুরু করে সকল পেশার মানুষের উপরে খারাপ প্রভাব পড়তে পারে ফলে অনেক বড় ধরনের সমস্যার পড়তে হয়',
#  'প্রত্যাহিক জীবনের মূল্যবান সময়কে নষ্ট করে ফেলে',
#  'কিছুই বলার নাই',
#  'আমি ভালো মানসিক স্বাস্থ্যের জন্য অনলাইন গেম খেলি না',
#  'অনলাইন গেম খেলা ভালো না',
#  'আমাদের মূল্যবান সময় বাঁচানোর জন্য অনলাইন গেম এড়ানো উচিত',
#  'অনলাইন গেম খুবই সময়সাপেক্ষ তাই এটা আমাদের খেলা উচিত না বলে মনে করি',
#  'মাঝে মাঝে আমি টাইম পাসের জন্য খেলি কিন্তু আমার মনে হয় আপনি যদি নিয়মিত খেলেন তাহলে আপনি আসক্ত হবেন আর এটা খেলা কোনো মানুষের জন্যই ভালো নয়',
#  'অনলাইন গেম না খেলাই ভালো বলে আমার ধারণা',
#  'অনলাইন গেম খেলা বিশেষ করে ছাত্রদের জন্য খারাপ অভ্যাস',
#  'ছোটবেলায় থেকে আমি খুব বেশি গেম খেলতাম এর পরে আমি ভেবেছিলাম আমি একটি গেম বানাতে চেষ্টা করতে পারি যার ফলে কিছুটা হলেও শিখতে পেরেছি',
#  'এটা সম্পূর্ণ সময় অপচয় কিছু লোক এটিকে অর্থ উপার্জনের ফানেল হিসাবে প্রচার করছে যা সত্যিই বাস্তব নয়',
#  'অবসর সময় খেললে সমস্যা নেই যদি তা শিক্ষামূলক গেমস হয়',
#  'অনলাইন গেম খেলা বিনোদন এর মতো কিন্তু এটা নেশা হিসেবে নেওয়া যাবে না পড়াশোনা পাশাপাশি একটু বিনোদনের জন্য খেলা যেতে পারে কিন্তু পড়াশোনা অমনোযোগী হয়ে গেম খেলাই হচ্ছে নেশা',
#  'ছোটরা এখন এই গেমে আসক্ত হচ্ছে এর ফলে এমবি কিনে টাকা নষ্ট করে পাবজি ফ্রি ফায়ার এর মতো গেম খেলছে',
#  'গেমকে বিনোদন হিসেবে নিন নেশা হিসেবে নয়',
#  'এটি সময় এবং মস্তিষ্ককে হত্যা করে এটি অবচেতন মনকে ম্যানিপুলেট করে একটি শিশুকে অপব্যবহার করতে পারে',
#  'এটি একটি খারাপ দিক যা মানুষের সময় নষ্ট করে এমনকি মন মানসিকতা নষ্ট করে',
#  'শুূুধু সময় অপচয় করা তাছাড়া আর কিছু না আমার মতে গেম না খেলে মাঠে মিনিট ক্রিকেট খেলা অনেক ভালো',
#  'আমি খেলি না কেননা এতে শুধু সময় নষ্ট হয়',
#  'বেশিরভাগ ক্ষেত্রেই অনলাইন গেম খেলে সময় নষ্ট হয়',
#  'অনলাইন গেম অতিরিক্ত খেলার ফলে মাঝে মাঝে স্বাস্থ্য সমস্যা তৈরি হতে পারে',
#  'অনলাইন গেম খেলায় দিনদিন শিশুরা আসক্ত হয়ে পড়ছে যেটা তাদের অনাগত ভবিষ্যৎ এর জন্য বিপদজনক হতে পারে',
#  'অনলাইন গেমিং তরুণ প্রাপ্তবয়স্কদের জন্য বিনোদনের একটি খুব ভাল উপায় হতে পারে',
#  'অনলাইন গেমে আসক্ত হওয়া উচিত নয় তাহলে ভবিষ্যৎ অন্ধকার এ পতিত হতে পারে',
#  'আমি অনলাইন গেম পছন্দ করি না এর ক্ষতিকর দিকের কারণে',
#  'আনন্দ এবং বন্ধুদের সাথে ভালো সময় কাটানোর মাধ্যম হচ্ছে অনলাইন গেম',
#  'অনলাইন গেমগুলি খেলার কারণে খারাপ আসক্তি চলে আসছে শিক্ষার্থীরা তাদের সময় নষ্ট করছে এবং তাদের শারীরিক কার্যকলাপ থেকে দূরে সরে যাচ্ছে',
#  'অনলাইন গেম খেলা আমাদের দিনের চাপ থেকে মুক্তি দেওয়ার একটি উপায় মাত্র এছাড়া কিছুই না তাই আমাদের গেম খেলার দিকে খুব বেশি মনোযোগ দেওয়া উচিত নয়',
#  'গেমিং একটি খারাপ জিনিস নয় এটি মস্তিষ্কের শক্তি বাড়ায় এবং এটি থিসিস দ্বারা প্রমাণিত',
#  'আমি গেম খেলি শুধুমাত্র নিজের সন্তুষ্টির জন্য অনলাইন গেমগুলোকে অভ্যাস না করে নিলে কোনো সমস্যা হবে বলে আমি মনে করি না',
#  'আমি অনলাইন গেম পছন্দ করি কেননা আপনি অনলাইনে বন্ধু তৈরি করতে পারেন এবং তাদের সাথে গেম খেলতে পারেন অনলাইন গেমিং খুবই বিনোদনমূলক',
#  'কিছুই বলার নাই গেম খেলা নিয়ে',
#  'স্বল্প সময়ের বিনোদনের জন্য অনলাইন গেম ঠিক আছে তবে তা অভ্যাস এ পরিনত করা যাবে না বিনোদনের উপকরণ যেমনটা হওয়া উচিত সে হিসেবেই অগ্রাধিকার দিতে হবে',
#  'অনলাইন গেম এমন কিছু হওয়া উচিত যা আমাদেরকে এটি থেকে শিখতে জ্ঞান অর্জন করতে সাহায্য করতে পারে এবং এমন একটি প্ল্যাটফর্ম হওয়া উচিত যেখানে লোকেরা তাদের যোগাযোগ দক্ষতা বাড়াতে পারে এটি বাস্তব জগতের মানুষকে সমাজের সাথে যোগাযোগ করতে সাহায্য করবে এছাড়া আসক্তি হলে অনলাইন গেম ক্ষতিকার প্রভাব ফেলবে',
#  'আমার মতামত হলো গার্লফ্রেন্ড পর্যবেক্ষণ করার চেয়ে গেমিং ভালো',
#  'গেমিং হলো সময় অপচয় এর মাধ্যম',
#  'অনলাইন গেমিং মানুষকে তাদের জীবনে লক্ষ্য তৈরি করার জন্য একটি পরিষ্কার মানসিকতা রাখতে সাহায্য করে এবং এটি মানুষকে সমালোচনামূলকভাবে চিন্তা করতেও সহায়তা করে কিন্তু অতিরিক্ত খেলা আমাদের শারীরিক ও মানসিকভাবে প্রভাবিত করতে পারে অতিরিক্ত খেলার জন্য লোকেরা দিনে দিনে আবেগপ্রবণ হয় এবং জিনিসগুলি পরিষ্কারভাবে বিচার করতে পারে না',
#  'অনলাইন গেমিং আমাদের জন্য প্রয়োজনীয় নয়',
#  'এটিকে বিনোদনের অংশ হিসাবে নেওয়া উচিত তবে জীবনের অংশ হিসাবে নয় প্রাপ্তবয়স্ক পুরুষ এবং নারীরা অগ্রাধিকার সারণী নিয়ন্ত্রণ করতে পারে কিন্তু শিশুরা তা করতে ব্যর্থ হয় ফলস্বরূপ খেলায় তাদের আসক্তি তাদের একটি বিশৃঙ্খল জীবনধারার দিকে নিয়ে যায়',
#  'মাঝে মাঝে অনলাইন গেম খেলে আপনার ভালো লাগে তবে হ্যাঁ সব সময় নয়',
#  'আমি ব্যক্তিগতভাবে মনে করি যে মাঝে মাঝে গেম খেলা ঠিক আছে কিন্তু খেয়াল রাখতে হবে এটি যেনো আমাদের আসক্ত করতে না পারে এবং এর ফলে যেনো আমাদের পড়াশোনায় বিরুপ প্রভাব না পড়ে',
#  'গেম খেলা ভালো তবে অতিরিক্ত আসক্ত হওয়া নিজ এবং সমাজের জন্য খারাপ দিক',
#  'দেখুন ছুড়ি হাতে কেউ ফল কাটে আর কেউ বা পকেট চিত্তবিনোদন এর এই মাধ্যমকে বিনোদনের অবকাশ হিসেবে নিলে ভালো আর যদি প্রধান কাজ হিসেবে নেওয়া হয় তাহলে অবশ্যই ক্ষতিকর প্রভাব পড়বে৷',
#  'কোনো মতামত নেই',
#  'অনলাইন গেম খেলা আমাদের জন্য খুবই বিপজ্জনক',
#  'কোন মন্তব্য নেই অনলাইন গেম নিয়ে',
#  'গেমিং মানসিক সমস্যার সাথেও যুক্ত হয়েছে ভিডিও গেমে আসক্তি বা ইন্টারনেট গেমিং এখন একটি মানসিক সমস্যা হয়ে দাঁড়িয়েছে',
#  'আমি মনে করি এটা সময়ের অপচয় এবং মস্তিষ্কের জন্য ক্ষতিকর',
#  'অনলাইন গেম খেলা খারাপ অভ্যাস ছাড়া কিছুই না',
#  'অনলাইন গেম খেলাকে যদি জীবনের একটি অপরিহার্য অংশ হিসেবে নেওয়া হয় তবে এটি বিপজ্জনক হবে৷ আর যদি এটি শুধুমাত্র সময় কাটানোর জন্য নেওয়া হয় তবে এটি মজাদার এবং উপভোগ্য হবে৷',
#  'অনলাইন গেমিং শুধুমাত্র যে সময় কেড়ে নেয় তা নয় এটি একজন ব্যক্তির মস্তিষ্কের জন্যও খুব ক্ষতিকারক',
#  'অনলাইন গেমিং নিয়ে আমার মতামত নেতিবাচক',
#  'কমবয়সী শিশুদের বিশেষ করে বছরের নিচে যারা আছে তাদেরকে অন লাইন গেমিং এর প্রতি আসক্তি ও এর কুফল সম্পর্কে সচেতন করতে হবে',
#  'অনলাইন গেম খেলা চমৎকার উপভোগ বিনোদন এবং সময় ততিবাহিত করার মাধ্যম',
#  'অনলাইনে গেম খেলা নিয়ে কোন মতামত নেই আমার',
#  'সময় কাটানোর জন্য প্রশংসিত অনলাইনে গেম খেলা',
#  'অনলাইন গেম কারও কারও জীবন বিপর্যস্থ করে তুলেছে আবার কেউ কেউ স্ট্রিমিং করে এখান থেকে ইনকামও জেনারেট করতে সক্ষম হয়েছেন আসলে অনলাইন গেমিং কিশোরদের জন্য মারাত্মক একটি প্রভাবক যা তাদের ভবিষ্যৎ জীবনকে কঠিন করে দিচ্ছে গেমিং সবার জন্য না যারা এখান থেকে যেকোন সময় বেড়িয়ে আসতে পারবে বলে মনে করে তাদের জন্য গেমিং খারাপ নয়',
#  'অনলাইনে গেম খেলার মানে হচ্ছে সময়ের অপচয় এবং অর্থের অপচয় করা',
#  'আমি গেমিং ভালোবাসি একটি ভালো গেম খেলা একটি ভাল বইয়ের মতো জ্ঞান আহরণে সাহায্য করে',
#  'এটা শুধুমাত্র একটি বিনোদন এবং সময় অতিবাহিত করার মাধ্যম',
#  'অনলাইন গেম খেলবেন না কারণ এটি আপনার প্রতি মিনিট বা সেকেন্ড নষ্ট করে উদাহরণঃ পাবজি ফ্রি ফায়ারের মতো অনলাইন গেমগুলি',
#  'অনলাইনে গেম খেলা আমার দ্বিতীয় জীবনের ন্যায়',
#  'এটি শুধুমাত্র বিনোদন তাই আমার দিক থেকে শেষ পর্যন্ত এর ভালো মন্দ দিক সম্পর্কে কোন মন্তব্য নেই',
#  'জীবনের প্রয়োজনে আমাদের কিছু গুরুত্বপূর্ণ জিনিস শেখা দরকার আর সেই মূল্যবান সময়কে অনলাইন গেম খেলে নষ্ট করা উচিত নয়',
#  'অনলাইন গেম এর প্রতি কারো আসক্তি হওয়া উচিত না',
#  'প্রাপ্তবয়স্কদের জন্য অনলাইন গেম খেলা খারাপ কিছু নয় তবে আসক্ত হওয়া ভালো নয়',
#  'সময়ের অপচয় ছাড়া আর কিছু না অনলাইনে গেম খেলা',
#  'গেম খেলা অকাজের কাজ ছাড়া কিছুই না',
#  'নির্ভর করছে কোন ধরনের গেম খেলছি অনলাইনে অনলাইন গেম যে একদমই খারাপ এটা আমি মনে করি না যেসব খেলায় সৃজনশীলতা রয়েছে এবং বুদ্ধিমত্তার প্রয়োগ রয়েছে যেমনঃ দাবা এসব গেম কেই প্রাধান্য দেওয়া উচিত আর অবশ্যই খেয়াল রাখা উচিত গেম খেলা আপনার প্রতিদিনের অভ্যাসে যেনো পরিনত না হয়',
#  'বাস্তব জীবনে খারাপ প্রভাব ফেলে অনলাইন গেম খেলা',
#  'গেম খেলা সবসময়ই আমাদের জন্য সহায়ক কেননা গেম খেললে মস্তিষ্কের কর্মক্ষমতা বাড়ে',
#  'কখনো একা থাকলে সময় ব্যয় করার প্রয়োজনীয়তা থেকে গেম খেলা ঠিক আছে কিন্তু অতিরিক্ত আসক্তি থেকে গেম খেলা ভালো না',
#  'অনলাইন গেম খেলা সত্যিই ক্ষতিকর',
#  'আমি অনলাইন গেম খেলাকে ঘৃণা করি',
#  'গেম খেলা মানসিক শান্তির এর জন্য একটু ভালো তাই বলে সেটা অভ্যাসে পরিনত করা মোটেও ঠিক না নেশা হয়ে গেলে মানসিক সমস্যা আরো বাড়ে সুতরাং সাপ্তাহিক একবার কিছুক্ষণ এর জন্য গেম খেলা মানসিক প্রশান্তির জন্যে ভালো বলে আমি মনে করি',
#  'গেম খেলা মোটেও ঠিক না কেননা এতে সময়ের অপচয় হয়',
#  'অনলাইনে গেম খেলা আমাার কাছে বিরক্তিকর বলে মনে হয়',
#  'গেম খেলা মাঝে মাঝে শুধুমাত্র মজা করার জন্য খেলা যেতে পারে তবে আমাদের সজাগ থাকতে হবে যাতে এটি আসক্তিতে পরিণত না হয়',
#  'কখনও কখনও শুধুমাত্র মজার জন্য গেম খেলা খারাপ জিনিস না',
#  'কোন মন্তব্য নেই অনলাইন গেম খেলাা না খেলার ব্যাপারে',
#  'শুধু মনের সতেজতার জন্য অনলাইন গেম খেলে থাকি',
#  'আমাদের জীবনে বিনোদন দরকার গেমিং বিনোদন এর একটি উদাহরণ আমি মনে করি গেমিং ভালো কিন্তু অতিরিক্ত গেমিং আমাদের সামাজিক জীবন এবং কর্মজীবনে বাধা সৃষ্টি করতে পারে',
#  'অনলাইন গেমিং শুধুমাত্র যে সময় কেড়ে নেয় তা নয় এটি একজন ব্যক্তির মস্তিষ্কের জন্যও খুব ক্ষতিকারক',
#  'অনলাইন গেম খেলা অবসর সময় কাটানোর জন্য ঠিক আছে কিন্তু আসক্তির জন্য নয়',
#  'যখন আমি আমার অবসর সময় কাটাই তখন আমি পাবজি খেলি এবং এটি একটি চমৎকার গেম যেখানে আমি অনেক বন্দুকের নাম এবং নিজেকে নিরাপদ রাখার কৌশল শিখতে পারি',
#  'সর্বোপরি অনলাইন গেমিং একটা টাইম কিলিং মেশিন বলতে পারেন যা আমাদের গুরুত্বপূর্ণ সময় নষ্ট করে',
#  'অনলাইন গেমিং এর জন্য আমার কোন সময় নেই কেননা অনলাইন গেম খেললে চোখের ক্ষতি হয়',
#  'অলস সময় কাটাতে এটি অনেকটা কাজে লাগে তবে অলস সময়ে শিক্ষামূলক কিছু করলে সেটা নিজের ক্যারিয়ার এ কাজে লাগবে এটাও বুঝি সেক্ষেত্রে তখন অনলাইন গেম খেলাকে সময়ের অপচয় বলে মনে হয়',
#  'নিজেকে আনন্দ দিতে এবং নিজের দক্ষতা গেম খেলার মাধ্যমে বিকাশ হয় বলে আমি মনে করি',
#  'অনলাইন গেম শুধুমাত্র মজার জন্য খেলা উচিত আমি তরুণদের পরামর্শ দেব যে পেশাগতভাবে এটাকে সিরিয়াসলি না নেওয়ার জন্য কেননা এতে ক্ষতির সম্ভাবনা আছে',
#  'বর্তমানে অনলাইন গেম এর কথা চিন্তা করলে দেখা যায় যে অনলাইন গেম খেলার জন্য মানুষ মারা যাচ্ছে এবং অনেক সময় নষ্ট হচ্ছে পড়ালেখায় সমস্যা হচ্ছে মনোযোগ দিতে না পারার জন্য',
#  'অনলাইন গেম মানেই সময় নষ্ট মানসিক অবসাদ ব্রেনের উপর বাড়তি চাপ ওই সময়টা খোলা আকাশের নীচে মিনিট হাঁটলেও অনেক উপকারে আসবে বলে আমি মনে করি',
#  'আমি মনে করি এটা তরুণ প্রজন্মের জন্য খুবই ক্ষতিকর কেউ যদি উজ্জ্বল ভবিষ্যৎ গড়তে চান তাহলে তাকে সব ধরনের অনলাইন গেম এড়িয়ে চলতে হবে',
#  'অনলাইনে গেম খেলি নাই কখনো যার ফলে এই ব্যাপারে আমার কোনো মন্তব্য নাই',
#  'অনলাইন গেম খেলা সময় কাটানোর জন্য একটি ভালো প্ল্যাটফর্ম',
#  'কিছু সময় খেলতে পারেন সময় কাটানোর জন্য অন্যথায় অনলাইন গেমিং আসক্তির জন্য খেলে আপনার সময় নষ্ট করবেন না',
#  'এটি আপনার মনের চাপ দূর করবে৷ এটি বাক্সের বাইরে চিন্তা করতে সাহায্য করবে৷ কিন্তু যদি আপনি মনে করেন যে আপনি গেমে আসক্ত হয়েছেন তবে আপনার ডিভাইসটি কম ব্যবহার করার চেষ্টা করুন',
#  'আমি মোটেও আগ্রহী নই অনলাইন গেম খেলার প্রতি সেটাতে ভালো অথবা খারাপ যাইহোক না কেনো',
#  'আমি অনলাইন গেমের প্রতি আসক্ত নই আমি মনে করি এটি আমাদের মূল্যবান সময় এবং ক্যারিয়ারও নষ্ট করে দেয় তাই আমি সবসময় অনলাইন গেম এড়িয়ে চলি',
#  'মন সতেজ রাখতে গেম খেলা গুরুত্বপূর্ণ ভূমিকা পালন করে',
#  'আমি অনলাইন গেম খেলতে আগ্রহী নই আমি জানি অনলাইন গেম খেলা সময়ের অপচয় করা শুধু',
#  'অনলাইন গেম খেলা আমাদের জন্য ক্ষতিকর গুরুত্বপূর্ণ সময়ের অপচয় করে',
#  'আমি বিশ্বাস করি যে ছাত্ররা জীবনে ভালো কিছু করার জন্য প্রস্তুতি নিচ্ছে তাদের গেমিংয়ে বেশি সময় দেওয়া উচিত নয় তা না হলে তাদের জীবন ক্ষতির সম্মুখীন হবে',
#  'মানসিক তৃপ্তি এবং চাপ থেকে শিথিল হওয়ার জন্য অনলাইন গেম খেলা চালিয়ে যাওয়া উচিত',
#  'কিছু গেম যেমন দাবা পাজল এবং সুডোকু ইত্যাদি আমাদের মস্তিকের কর্মদক্ষতা বাড়াতে সাহায্য করে',
#  'অনলাইন গেমিং শুধুমাত্র যে সময় কেড়ে নেয় তা নয় এটি একজন ব্যক্তির মস্তিষ্কের জন্যও খুবই ক্ষতিকারক',
#  'গেম খেলে সময় নষ্ট করে জীবনের কোনো কিছুই ভালো করা যায় না তাই গেম খেলার প্রতি আমার কোন আগ্রহ নেই',
#  'অনলাইন গেম খেলার ফলে পরিবার এবং কাছের মানুষের সাথে দূরত্ব বাড়তে পারে',
#  'অনলাইন গেম খেলা খারাপ অভ্যাস বলে আমি মনে করি',
#  'অনলাইন গেম খেলা এটা খুবই খারাপ অভ্যাস কেননা ঘণ্টার পর ঘণ্টা গেম খেলে ছেলে মেয়েরা তার মূল্যবান সময় নষ্ট করছে',
#  'গেম খেলা ভালো কিন্তু এর জন্য যেনো কোনো কাজের বা নিজের ক্ষতি না হয় সে দিকে খেয়াল রাখতে হবে',
#  'অনলাইন গেম খেলা খুবই আসক্তিকর এবং সময়সাপেক্ষ',
#  'মাঝে মাঝে একঘেয়ে হয়ে যাই সেই সময় অনলাইনে গেম খেলি আমার বিরক্তিকর সময় কাটানোর জন্য আর এই কারনে অনলাইনে গেম খেলা আমার কাছে ভালো দিক বলে মনে হয়',
#  'পাবজি ফ্রি ফায়ার এই ধরনের গেম খেলা জীবনের ধ্বংস ডেকে আনা ছাড়া কিছুই করতে পারে না',
#  'অনলাইন গেম খেলার সুবিধা অসুবিধাগুলিকে ছাড়িয়ে যায় তাই অনলাইন গেম খেলা বন্ধ করার দরকার',
#  'মাঝে মাঝে ভালো লাগার জন্য বা সময় কাটানোর জন্য খেলাটা কোন সমস্যা না কিন্তু বেশি গুরুত্ব দিয়ে ফেললে সমস্যা',
#  'অনলাইন গেম খেলা একটি খারাপ অভ্যাস',
#  'অনলাইন গেম খেলা অবসর সময় কাটানোর মাধ্যম এই অবসর সময়টি বাইরের কোনো খারাপ কাজে লিপ্ত হওয়া থেকে বিরত রাখে যেমনঃ খারাপ বন্ধুর সাথে বিভিন্ন অনৈতিক কাজে লিপ্ত হওয়া থেকে মুক্ত রাখে',
#  'আমি কখনই অনলাইন গেম খেলব না কেননা কিছু গেম খেলা হারাম',
#  'মাঝে মাঝে অনলাইন গেম খেলে আমার কর্মক্ষমতা কমে যায়',
#  'আমাদের দক্ষতা বিকাশ করা উচিত এবং অনলাইন গেম না খেলা উচিত',
#  'অনলাইন গেম মানুষকে সাময়িক ভালো রাখে কিন্তু যারা অতিরিক্ত খেলে তাদের জন্য ক্ষতি করে',
#  'এটি বিনোদনের একটি অংশ এটাকে সিরিয়াসলি নেওয়া যাবে না জীবনের অংশ হিসেবে',
#  'যদিও আজকাল অনলাইন গেম জনপ্রিয় কিন্তু কারোরই দিনে ঘণ্টার বেশি সময় অনলাইন গেম খেলে কাটানো উচিত নয় আর যারা চাকুরী করে তাদের ছুটি ছাড়া অনলাইনে গেম খেলা উচিত নয়',
#  'মানসিক তৃপ্তির জন্য অনলাইন গেম খেলা ঠিক আছে কিন্তু অনলাইন গেমের প্রতি দীর্ঘমেয়াদে আসক্তি ক্ষতিকর',
#  'আমি মনে করি অযথা অনলাইন গেম খেলে সময় ব্যয় না করে জ্ঞান অর্জনে সময় দেয়া উচিত',
#  'আমি অনলাইন গেম খেলা পছন্দ করি না এটা মন এবং শারীরিক সুস্থতার জন্য ক্ষতিকর এবং অনেক সময় নষ্ট করে',
#  'এটা বর্তমান যুবসমাজ ধ্বংসের মূল কারণ গুলোর মধ্যে অন্যতম',
#  'কাজ ফে\u200cলে অনলাইন গেম খেলা উ\u200cচিত না',
#  'আমি সাধারণত অনলাইন গেম খেলি না কারণ আমি এটি পছন্দ করি না এর ক্ষতিকর প্রভাবের জন্য',
#  'অনলাইন গেম খেললে মানসিক দৃড়তা বাড়ে বলে আমি মনে করি',
#  'সৃজনশীলতা বৃদ্ধিতে অনলাইন গেম খেলা বাঁধা প্রদান করে',
#  'অনলাইন গেম খেললে আমার ভেতর মানসিক প্রশান্তি বাড়ে',
#  'গেমসের জগতে এখন সবচেয়ে বেশি জনপ্রিয় হয়ে উঠেছে অনলাইন গেমস গুলো এর কারণ হিসেবে বলতে পারি এই গেমস গুলো একা খেলতে হয় না বা বট এর সাথে খেলতে হয় না এই গেমসে আপনার অপনেন্টস আপনার মতই একজন মানুষ আপনার সাথে লড়াই করে আর আপনি চাইলে আপনার টিমে আপনার বন্ধুদের সাথে টিম করে অপনেন্টস দের সাথে লড়াই করতে পারেন যার জন্য অনলাইন গেমস গুলো এখন সবাই বেশি পছন্দ করে',
#  'আমি মনে করি এই ভার্চুয়াল গেমস গুলোর অনেক ভালো দিকও রয়েছে এই গেমস গুলো ব্যাবহার করে অনেক মানুষ এখন তার ইনকাম এর পথ বের করে নিতে পেরেছে',
#  'অনেক যুবক ছেলে অনেক সময় অবসাদ গ্রস্থ থাকে এই গেম খেলার মাধ্যমে তাদের অবসাদ গ্রস্থতা দূর হয় একাকিত্ব দূর হয় এখনকার ছেলেমেয়েরা এখন অনেক একাকিত্ব অনুভব করে এই গেমস খেলার মাধ্যমে তারা নিজেদের একাকিত্ব দূর করতে পারে',
#  'গেমস নিয়ে এখন দেশে বিদেশে অনেক বড় মানের টুর্নামেন্ট ও হচ্ছে এখানে অনেক বড় অংকের অর্থ প্রাইজ পুল থাকে যার ফলে পরিবারে সচ্ছলতা ফিরে আসতে পারে যেটা আমার কাছে ইতিবাচক বলে মনে হয়',
#  'গেমস শুধু আমাদের বিনোদন হিসেবে ব্যাবহার হচ্ছে না গেমস এখন আমাদের অর্থ উপার্জনের মাধ্যমও বটে',
#  'যারা ভিডিও গেম খেলার ঘোরতর বিরোধী তাঁরা বলবে এই গেম খেলা মানে হচ্ছে অযথা জীবনের মূল্যবান সময় নষ্ট করা কিন্তু বেশিরভাগ মানুষই যারা এই গেমে মগ্ন থাকেন তাঁরা অনুভব করেছেন যে এই গেম খেললে তাদের স্ট্রেস বা মানসিক চাপ অনেক কমে যায়',
#  'অনলাইন গেম খেলে একাকিত্ব দূরীকরণ তাৎক্ষণিক সিদ্ধান্ত গ্রহণের ক্ষমতা বৈশ্বিক যোগাযোগ তৈরি দলগত কাজের অভিজ্ঞতা অর্জন সমস্যা সমাধানে মেধার সূক্ষ্ম ব্যবহার চাপ নেওয়ার ক্ষমতা বৃদ্ধি প্রভৃতি ইতিবাচক দিক রয়েছে',
#  'ভিডিও গেম খেলার ইতিবাচক দিকগুলির মধ্যে রয়েছে জ্ঞান শেখানো এবং শারীরিক এবং মানসিক দক্ষতা উন্নত করা',
#  'গবেষণায় দেখা গেছে যে প্রতিদিন ভিডিও গেম খেলে আমাদের চাক্ষুষ মনোযোগ বাড়ানো যায় কার্য পরিবর্তনের ক্ষেত্রে আমাদের কার্যকারিতা উন্নত হয় দৃশ্যমান অনুসন্ধান এবং বস্তুর বৈষম্যের কার্যক্রমে আমরা আরও দ্রুত এটি একাধিক ক্রিয়াকলাপ সম্পাদনেও উপকার নিয়ে আসে',
#  'শারীরিক এবং মানসিক উভয়ই সমস্যা রয়েছে এমন লোকদের দ্বারা ভিডিও গেমগুলি ব্যবহার করা হয়েছে এগুলি মনোযোগ সমস্যাযুক্ত লোকদের পুনর্বাসন চিকিত্সা হিসাবে ব্যবহৃত হতে পারে',
#  'সমস্ত ভিডিও গেমগুলি কনসোল বা কম্পিউটারে হোক না কেন সংহতি বন্ধুত্ব এবং একটি গোষ্ঠীতে অন্তর্ভুক্তির অনুভূতির মতো মূল্যবোধ প্রচার করতে সহায়তা করে',
#  'যেহেতু বেশিরভাগ গেমস একটি দল হিসাবে খেলা হয় যে কোনও সিদ্ধান্ত গ্রহণ ভালো বা খারাপ গ্রুপ অংশগ্রহণকারীদের জন্য পরিণতি ঘটতে পারে এই কারণেই ভিডিও গেমগুলি অন্য মানুষের প্রতি সহানুভূতি বিকাশ করে',
#  'ভিডিও গেমগুলি একরকম স্বাস্থ্যকর প্রতিযোগিতা প্রচার এবং আত্ম সম্মান বাড়াতে সহায়তা করে কারণ আপনি যখন কোনও খেলা জিতেন বা স্তরগুলি অতিক্রম করবেন তখন আপনি এগিয়ে যেতে পেরে খুশি হন',
#  'অনলাইন গেম খেলে আমাদের দলবদ্ধ দক্ষতা উন্নত করতেও সহায়তা করে কারণ কখনও কখনও গেমের সময় তাদের চ্যালেঞ্জ কাটিয়ে উঠতে একত্রে যোগ দিতে হবে পাশাপাশি এটি আপনাকে দ্রুত চিন্তা করতে উৎসাহিত করে',
#  'কৌশল এবং নেতৃত্বের উন্নতি করনে অনলাইন গেম খেলা গুরুত্বপূর্ণ ভূমিকা পালন করে কারণ ভিডিও গেমগুলি এমন পরিস্থিতিতে চরিত্রগুলি রাখে যেখানে তাদের সমস্যা সমাধানের জন্য কৌশলগুলি ব্যবহার করতে হয়',
#  'ভিডিও গেমগুলির সিংহভাগ ইংরেজি বা অন্য কোনও ভাষায় কথিত হয় সুতরাং যে ব্যক্তি খেলছে তাকে গেমের মধ্যে থাকা অন্য ব্যক্তির সাথে যোগাযোগের জন্য একটি নির্দিষ্ট উপায়ে শিখতে হবে এইক্ষেত্রে অন্য ভাষার প্রতি দক্ষতা বাড়ে',
#  'সৃজনশীলতা বাড়াতে অনলাইন গেম খেলা সাহায্য করে',
#  'যে কোনও ব্যক্তি ভিডিও গেম খেলায় আসক্ত হয়ে থাকে কারণ তারা বসে বসে খেলা করতে সময় কাটায়',
#  'গেম খেলায় আসক্ত হয়ে একজন ব্যক্তি অস্বাভাবিক আগ্রাসন বাড়িয়ে ফেলতে পারে অন্যর উপর যেটা আমার কাছে নেতিবাচক দিক বলে মনে হয়',
#  'কিছু নির্দিষ্ট সহিংস সামগ্রী রয়েছে এমন ভিডিও গেম খেলতে ঘন্টা ব্যয় করে তবে এটি সামাজিকীকরণ স্তরে নেতিবাচক প্রভাব ফেলতে পারে যেহেতু একটি খেলায় অনেক ঘন্টা ব্যয় করা হয়',
#  'তরুণ বা শিশুরা স্ক্রিনে অনেক ঘন্টা ব্যয় করে যে কারণে তাদের ঘুমোতে সমস্যা হতে পারে পাশাপাশি দুঃস্বপ্ন দেখা দিতে পারে',
#  'ভিডিও গেম তরুণ প্রজন্মের জন্য কেবল অবসর কাটানোর একটা অনুষঙ্গ ছিল তা এখন পরিণত হয়েছে আসক্তিতে যার ফলে নৈতিক অবক্ষয় ঘটছে',
#  'ভিডিও গেম ও সন্ত্রাসবাদী কর্মকাণ্ডকে উস্কে দিচ্ছে',
#  'অনলাইনে গেম খেলে ইন্টারনেটের মাধ্যমে অর্থ উপার্জন করা যায় বাড়িতে বসে',
#  'অনলাইন গেমসের প্রতিটি স্তরে বিভিন্ন ধাঁধার সমাধান করে সামনে এগিয়ে যেতে হয় এর ফলে ছোটবেলা থেকে বাচ্চাদের লজিক ডেভেলপমেন্ট এর বিকাশ হয়',
#  'অনলাইন গেম খেললে আশেপাশের পরিবেশ সম্পর্কে ভালো ধারণা পাওয়া যায় এবং সেই সাথে বিকল্প উপায়ের দক্ষতা বাড়ে',
#  'বাচ্চাদের ক্ষেত্রে ভিডিও গেমসের ইন্টারেকশন বাচ্চাদের সূক্ষ মোটর স্কিল বাড়াতে এবং চোখ আর মুখের সমন্বয় প্রক্রিয়াকেও যথেষ্ট তরান্বিত করে',
#  'দলীয় অনলাইন গেমস অথবা বিভিন্ন ভিডিও গেমসগুলি বাচ্চাদের এমনকি প্রাপ্তবয়স্ক দের ও সামাজিক হবার দলীয় কাজ করার এবং যে কোনো সমস্যা সমাধানের সক্ষমতা বাড়ায়',
#  'ভিডিও গেমস নিয়ে ব্যস্ত হলে বিভিন্নরকম স্বাস্থ্য সুবিধা যেমন শরীর ব্যথা মানসিক হতাশা মানসিক ক্ষোভ আক্রমণাত্মক আচারণ ইত্যাদি কমে যায়',
#  'অনলাইন ভিডিও গেমস খেলার সময় বাচ্চারা বিভিন্ন এগ্রেসিভ অনলাইন কন্টেন্ট দেখার সুযোগ পায় এসব ভায়োলেন্ট কন্টেন্ট দেখার ফলে বাচ্চাদের বিভিন্ন শারীরিক এবং মানসিক সমস্যার সৃষ্টি হচ্ছে',
#  'অনলাইন গেমসের যেমন ভালো দিক রয়েছে ঠিক অনুরূপভাবে খারাপ দিক ও রয়েছে',
#  'কম্পিউটার গেমে আসক্তি শারীরিক পরিশ্রম বিমুখ করে তোলে',
#  'অনলাইন গেম খেলা আপনার একাগ্রতা বাড়ার সুযোগ প্রচুর বৃদ্ধি করে কারণ যখন আপনি একটি অ্যাকশন গেম খেলছেন তখন আপনার সম্পূর্ণ মন সেই গেমের মধ্যেই থাকে',
#  'অনলাইন গেম খেললে আপনি সমন্বয়তা বা সহযোগিতার ক্ষেত্রেও প্রচুর উপকার পেতে পারবেন',
#  'যেকোনো গেম খেলার সময় আপনার কাছে বিভিন্ন সংঘর্ষের পরিবেশ বিপদ এবং নিয়ম থাকে তাই প্রথম লেভেল থেকে শুরু করে পরের লেভেল গুলোতে যেতে হলে আপনাকে বিভিন্ন নিয়ম গুলো মেনে সমস্যা গুলোর সমাধান বের করতে হয় এটা এক ধরণের মানসিক ব্যায়াম এর মতোই কাজ করবে যার ফলে আপনার ব্যক্তিগত জীবনেও যেকোনো সমস্যার সমাধান করার কৌশল বৃদ্ধি পাবে',
#  'যেকোনো গেম খেলার জন্যে আপনার বিভিন্ন জিনিস গুলোর ওপরে নজর দিতে হবে উদাহরণস্বরুপঃ গেম এর সাথে জড়িত বিভিন্ন জায়গা নির্দেশাবলী কন্ট্রোল চরিত্র স্টোরি ইত্যাদি যার ফলে অনলাইন গেম স্মৃতি শক্তি বাড়াতে সাহায্য করে',
#  'গেমিং এর প্রতি আলাদা এক উৎসাহ চলে আসার কারণ বাইরের নতুন নতুন লোকেদের সাথে চেনা পরিচিত হয়ে ওঠা এর ফলে যোগাযোগ সক্ষমতা বাড়ে',
#  'গেমিং এর মাধ্যমে লোকেদের মন সত্যি ভালো হয়ে যায় মানসিক চাপ থেকে মুক্ত হওয়ার ক্ষেত্রেও অনেক ভিডিও গেম গুলো প্রচুর কাজে আসে',
#  'বাইরের বিভিন্ন দেশ গুলোতে বয়স্ক লোকেরাও পর্যন্ত ভিডিও গেম খেলেন এতে আপনি নিজেকে উৎসাহিত এবং তরুণ হওয়ার অনুভব দিতে পারবেন',
#  'অনলাইন গেম খেলার মাধ্যমে আপনি আপনার ব্যস্ততা পূর্ণ জীবনের থেকে নিজেকে আলাদা রাখতে পারবেন যা আপনাকে শারীরিক ভাবে সুস্থ রাখতে পারে বলে আমি মনে করি',
#  'গেমস খেলে আমাদের একাকীত্ব দূর করা যায় অনেকে আছেন যারা একা থাকলে তাদের বিভিন্ন ধরনের চিন্তা ভাবনা চলে আসে তাদের মস্তিষ্কে সাধারণত এটা হয়ে থাকে তাদের টেনশনের কারণে তারা যদি গেমস খেলে তাহলে তাদের এই ধরনের চিন্তাধারা বা তাদের মস্তিষ্কে এ ধরনের চিন্তা ভাবনা কখনোই আসবেনা এবং তার টেনশন কমে যাবে এবং তার অনেক ভালো লাগবে']

# %%
for i in range(237):
  print("Data #"+str(i))
  print("Raw Data: ",df['opinion'][i])
  print("Preprocess Data: ",clear_text2[i])
  print("Sentence Type: ",df['class'][i])
  print()
# Out:
# Data #0
# Raw Data:  মন্তব্য নেই।
# Preprocess Data:  মন্তব্য নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #1
# Raw Data:  অভিমত নেই।
# Preprocess Data:  অভিমত নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #2
# Raw Data:  অনলাইন গেম শুধুমাত্র  আমাদের  সময়কে নষ্ট করে।
# Preprocess Data:  অনলাইন গেম শুধুমাত্র আমাদের সময়কে নষ্ট করে
# Sentence Type:  নেগেটিভ
#
# Data #3
# Raw Data:  ভালো-মন্দ কিছুই না।
# Preprocess Data:  ভালো মন্দ কিছুই না
# Sentence Type:  নিরপেক্ষ
#
# Data #4
# Raw Data:   অনলাইন গেম খেললে যে মানুষের শুধু সমস্যা-ই হয় তা না, এর থেকে অনেকে উপার্জনও করছে।
# Preprocess Data:  অনলাইন গেম খেললে যে মানুষের শুধু সমস্যা ই হয় তা না এর থেকে অনেকে উপার্জনও করছে
# Sentence Type:  পজিটিভ
#
# Data #5
# Raw Data:  মতামত নেই।
# Preprocess Data:  মতামত নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #6
# Raw Data:  এটা সত্য যে কিছু গবেষণায় দেখানো হয়েছে যে কিছু ভিডিও গেম হাত-চোখের সমন্বয়, সমস্যা সমাধানের দক্ষতা এবং তথ্য প্রক্রিয়া করার জন্য মনের ক্ষমতাকে উন্নত করতে পারে।
# Preprocess Data:  এটা সত্য যে কিছু গবেষণায় দেখানো হয়েছে যে কিছু ভিডিও গেম হাত চোখের সমন্বয় সমস্যা সমাধানের দক্ষতা এবং তথ্য প্রক্রিয়া করার জন্য মনের ক্ষমতাকে উন্নত করতে পারে
# Sentence Type:  পজিটিভ
#
# Data #7
# Raw Data:  গেম খেলা একটি স্ব-উন্নয়ন দক্ষতা। যদি কেউ একবার ব্যবহার করে এবং দক্ষতার সাথে তাদের পছন্দের ভারসাম্য বজায় রাখে তবে কোন সমস্যা নেই।
# Preprocess Data:  গেম খেলা একটি স্ব উন্নয়ন দক্ষতা যদি কেউ একবার ব্যবহার করে এবং দক্ষতার সাথে তাদের পছন্দের ভারসাম্য বজায় রাখে তবে কোন সমস্যা নেই
# Sentence Type:  পজিটিভ
#
# Data #8
# Raw Data:  গেম খেললে শুধুমাত্র আমাদের সময়েরই অপচয় হয়।
# Preprocess Data:  গেম খেললে শুধুমাত্র আমাদের সময়েরই অপচয় হয়
# Sentence Type:  নেগেটিভ
#
# Data #9
# Raw Data:  ভালো তবে সময়সাপেক্ষ।
# Preprocess Data:  ভালো তবে সময়সাপেক্ষ
# Sentence Type:  নিরপেক্ষ
#
# Data #10
# Raw Data:  এটি বিনোদনের একটি উপায়।
# Preprocess Data:  এটি বিনোদনের একটি উপায়
# Sentence Type:  নিরপেক্ষ
#
# Data #11
# Raw Data:  নেশা ছাড়াই খেলুন।
# Preprocess Data:  নেশা ছাড়াই খেলুন
# Sentence Type:  নিরপেক্ষ
#
# Data #12
# Raw Data:  অনলাইন গেমিং সম্পর্কে আমার মতামত হচ্ছে নিরপেক্ষ।
# Preprocess Data:  অনলাইন গেমিং সম্পর্কে আমার মতামত হচ্ছে নিরপেক্ষ
# Sentence Type:  নিরপেক্ষ
#
# Data #13
# Raw Data:  আবর্জনা, টাকা নষ্ট, পড়াশুনা নষ্ট, এগুলা দিয়ে কিছু হয় না।
# Preprocess Data:  আবর্জনা টাকা নষ্ট পড়াশুনা নষ্ট এগুলা দিয়ে কিছু হয় না
# Sentence Type:  নেগেটিভ
#
# Data #14
# Raw Data:  গেম খেলা আমাদের  শরীরের জন্য খারাপ।
# Preprocess Data:  গেম খেলা আমাদের শরীরের জন্য খারাপ
# Sentence Type:  নেগেটিভ
#
# Data #15
# Raw Data:  মন্তব্য নেই।
# Preprocess Data:  মন্তব্য নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #16
# Raw Data:  কোন মতামত নেই।
# Preprocess Data:  কোন মতামত নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #17
# Raw Data:  গেমটি একটি খেলা হিসাবে খেলুন। তেমন সিরিয়াসলি না।
# Preprocess Data:  গেমটি একটি খেলা হিসাবে খেলুন তেমন সিরিয়াসলি না
# Sentence Type:  নিরপেক্ষ
#
# Data #18
# Raw Data:  সময়ের অপচয়, এক ধরনের ওষুধ।
# Preprocess Data:  সময়ের অপচয় এক ধরনের ওষুধ
# Sentence Type:  নেগেটিভ
#
# Data #19
# Raw Data:  আমি সব ধরনের গেম খেলা ঘৃণা করি l বিশেষ করে অনলাইন গেম।
# Preprocess Data:  আমি সব ধরনের গেম খেলা ঘৃণা করি বিশেষ করে অনলাইন গেম
# Sentence Type:  নেগেটিভ
#
# Data #20
# Raw Data:  ভালো কিন্তু আমরা প্রতিদিন আমাদের মূল্যবান সময় নষ্ট করতে পারি না।
# Preprocess Data:  ভালো কিন্তু আমরা প্রতিদিন আমাদের মূল্যবান সময় নষ্ট করতে পারি না
# Sentence Type:  নিরপেক্ষ
#
# Data #21
# Raw Data:  মাত্রাতিরিক্ত অনলাইন গেম আমাদের চোখের ক্ষতিসাধণ করে।
# Preprocess Data:  মাত্রাতিরিক্ত অনলাইন গেম আমাদের চোখের ক্ষতিসাধণ করে
# Sentence Type:  নেগেটিভ
#
# Data #22
# Raw Data:  অনলাইন গেম খেলা আমাদের মস্তিষ্কের কর্মক্ষমতা বাড়িয়ে দেয়।
# Preprocess Data:  অনলাইন গেম খেলা আমাদের মস্তিষ্কের কর্মক্ষমতা বাড়িয়ে দেয়
# Sentence Type:  পজিটিভ
#
# Data #23
# Raw Data:  এটা ভালো, যদি আপনি এটিকে বিনোদন হিসেবে নেন। তবে আপনাকে অবশ্যই দীর্ঘ সময়ের গেমিং সম্পর্কে সচেতন হতে হবে।
# Preprocess Data:  এটা ভালো যদি আপনি এটিকে বিনোদন হিসেবে নেন তবে আপনাকে অবশ্যই দীর্ঘ সময়ের গেমিং সম্পর্কে সচেতন হতে হবে
# Sentence Type:  নিরপেক্ষ
#
# Data #24
# Raw Data:  অনলাইনে গেম খেলা খারাপ।
# Preprocess Data:  অনলাইনে গেম খেলা খারাপ
# Sentence Type:  নেগেটিভ
#
# Data #25
# Raw Data:  অনলাইনে গেম খেলা স্বাস্থ্যের জন্য ক্ষতিকর।
# Preprocess Data:  অনলাইনে গেম খেলা স্বাস্থ্যের জন্য ক্ষতিকর
# Sentence Type:  নেগেটিভ
#
# Data #26
# Raw Data:  এটা মানুষের মস্তিষ্কের জন্য আতঙ্ক।
# Preprocess Data:  এটা মানুষের মস্তিষ্কের জন্য আতঙ্ক
# Sentence Type:  নেগেটিভ
#
# Data #27
# Raw Data:  আমি  একটা জিনিস বলতে চাই যে, যদি সম্ভব হয় তাহলে আমাদের অনলাইন গেমিং এড়িয়ে চলতে হবে সময় বাঁচাতে।
# Preprocess Data:  আমি একটা জিনিস বলতে চাই যে যদি সম্ভব হয় তাহলে আমাদের অনলাইন গেমিং এড়িয়ে চলতে হবে সময় বাঁচাতে
# Sentence Type:  নেগেটিভ
#
# Data #28
# Raw Data:  শিক্ষাগত, শিল্প এবং প্রাসঙ্গিক খেলা সবার জন্য ভাল হবে। কিছু গেম আমাদের দৈনন্দিন জীবনকে নষ্ট করে দিতে পারে যেমনঃ পাবজি, ফ্রি ফায়ার এবং আরো কিছু অপ্রাসঙ্গিক গেম।
# Preprocess Data:  শিক্ষাগত শিল্প এবং প্রাসঙ্গিক খেলা সবার জন্য ভাল হবে কিছু গেম আমাদের দৈনন্দিন জীবনকে নষ্ট করে দিতে পারে যেমনঃ পাবজি ফ্রি ফায়ার এবং আরো কিছু অপ্রাসঙ্গিক গেম
# Sentence Type:  নিরপেক্ষ
#
# Data #29
# Raw Data:  ইচ্ছা হলে খেলি আবার ইচ্ছা না হলে খেলি না।
# Preprocess Data:  ইচ্ছা হলে খেলি আবার ইচ্ছা না হলে খেলি না
# Sentence Type:  নিরপেক্ষ
#
# Data #30
# Raw Data:  প্রাপ্তবয়স্ক থেকে বাচ্চারা ফ্রি ফায়ার, পাবজির মতো অনলাইন গেম খেলে অনেক সময় ব্যয় করে এবং এটি পড়াশোনায়র ক্ষতি করে।
# Preprocess Data:  প্রাপ্তবয়স্ক থেকে বাচ্চারা ফ্রি ফায়ার পাবজির মতো অনলাইন গেম খেলে অনেক সময় ব্যয় করে এবং এটি পড়াশোনায়র ক্ষতি করে
# Sentence Type:  নেগেটিভ
#
# Data #31
# Raw Data:  অনলাইন গেম খেলতে মজা লাগে এবং বিরক্তিকর সময় নিমিষেই দূর হয়ে যায়।
# Preprocess Data:  অনলাইন গেম খেলতে মজা লাগে এবং বিরক্তিকর সময় নিমিষেই দূর হয়ে যায়
# Sentence Type:  পজিটিভ
#
# Data #32
# Raw Data:  অনলাইন গেম বহিস্কার করা হোক। বাংলাদেশের কোনো লোক যেন গেম খেলে সময় অপচয় না করে সেই উদ্যেগ নেয়া হোক।
# Preprocess Data:  অনলাইন গেম বহিস্কার করা হোক বাংলাদেশের কোনো লোক যেন গেম খেলে সময় অপচয় না করে সেই উদ্যেগ নেয়া হোক
# Sentence Type:  নেগেটিভ
#
# Data #33
# Raw Data:  সবকিছু বাদ দিয়ে  গেম খেললে, পরিবারের মানুষের ভেতর মনোমালিন্যতার সৃষ্টি হয়।
# Preprocess Data:  সবকিছু বাদ দিয়ে গেম খেললে পরিবারের মানুষের ভেতর মনোমালিন্যতার সৃষ্টি হয়
# Sentence Type:  নেগেটিভ
#
# Data #34
# Raw Data:  অনলাইন গেম সম্পর্কে তেমন কোনো অভিজ্ঞতা আমার নেই।
# Preprocess Data:  অনলাইন গেম সম্পর্কে তেমন কোনো অভিজ্ঞতা আমার নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #35
# Raw Data:  পরিমিতভাবে অনলাইন গেম খেলা ঠিক আছে।
# Preprocess Data:  পরিমিতভাবে অনলাইন গেম খেলা ঠিক আছে
# Sentence Type:  পজিটিভ
#
# Data #36
# Raw Data:  নিয়ন্ত্রণে থাকা পর্যন্ত কোনো কিছুই খারাপ নয়।
# Preprocess Data:  নিয়ন্ত্রণে থাকা পর্যন্ত কোনো কিছুই খারাপ নয়
# Sentence Type:  পজিটিভ
#
# Data #37
# Raw Data:  ভালো গেম খেলার দক্ষতা থাকলে উপার্জন করার সম্ভব।
# Preprocess Data:  ভালো গেম খেলার দক্ষতা থাকলে উপার্জন করার সম্ভব
# Sentence Type:  পজিটিভ
#
# Data #38
# Raw Data:  এতে আপনার মূল্যবান সময় নষ্ট হয়।
# Preprocess Data:  এতে আপনার মূল্যবান সময় নষ্ট হয়
# Sentence Type:  নেগেটিভ
#
# Data #39
# Raw Data:  এটা আমার জন্য কখনই প্রয়োজন ছিল না বরং মাঝে মাঝে আমি শুধুমাত্র টাইম পাসের জন্য অনলাইন গেম খেলি।
# Preprocess Data:  এটা আমার জন্য কখনই প্রয়োজন ছিল না বরং মাঝে মাঝে আমি শুধুমাত্র টাইম পাসের জন্য অনলাইন গেম খেলি
# Sentence Type:  নিরপেক্ষ
#
# Data #40
# Raw Data:  মতাামত শূন্য।
# Preprocess Data:  মতাামত শূন্য
# Sentence Type:  নিরপেক্ষ
#
# Data #41
# Raw Data:  এর অনেক পার্শ্বপ্রতিক্রিয়া আছে এবং মানুষ এতে করে বিভিন্ন রোগের   উপসর্গের  সম্মুখীন হয়।
# Preprocess Data:  এর অনেক পার্শ্বপ্রতিক্রিয়া আছে এবং মানুষ এতে করে বিভিন্ন রোগের উপসর্গের সম্মুখীন হয়
# Sentence Type:  নেগেটিভ
#
# Data #42
# Raw Data:  গেম খেলে মানসিক প্রশান্তি পাওয়া যায়।
# Preprocess Data:  গেম খেলে মানসিক প্রশান্তি পাওয়া যায়
# Sentence Type:  পজিটিভ
#
# Data #43
# Raw Data:  সময় নষ্ট এলাকা বলে মনে হয় গেম খেলা।
# Preprocess Data:  সময় নষ্ট এলাকা বলে মনে হয় গেম খেলা
# Sentence Type:  নেগেটিভ
#
# Data #44
# Raw Data:  সময় কাটানোর জন্য ভালো।
# Preprocess Data:  সময় কাটানোর জন্য ভালো
# Sentence Type:  পজিটিভ
#
# Data #45
# Raw Data:  যেহেতু গেম খেলা হয়ে উঠে না সেহেতু এর ভালো-মন্দ দিক সম্পর্কে ধারনা নেই।
# Preprocess Data:  যেহেতু গেম খেলা হয়ে উঠে না সেহেতু এর ভালো মন্দ দিক সম্পর্কে ধারনা নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #46
# Raw Data:  বর্ধিত সময়ের জন্য অনলাইন গেম খেলেও আসক্তি হতে পারে।
# Preprocess Data:  বর্ধিত সময়ের জন্য অনলাইন গেম খেলেও আসক্তি হতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #47
# Raw Data:  আমি মনে করি সম্পূর্নরুপে ব্যাক্তির উপরেই নির্ভরশীল। কেননা অবসরে বিনোদনের একটা মাধ্যম হিসেবে এর কোনো প্রকার ক্ষতি আছে বলে আমি মনে করি না।
# Preprocess Data:  আমি মনে করি সম্পূর্নরুপে ব্যাক্তির উপরেই নির্ভরশীল কেননা অবসরে বিনোদনের একটা মাধ্যম হিসেবে এর কোনো প্রকার ক্ষতি আছে বলে আমি মনে করি না
# Sentence Type:  পজিটিভ
#
# Data #48
# Raw Data:  যদি আসক্তি নিয়ে অনলাইন গেমের পিছনে লেগে থাকে তাহলে তা অবশ্যই খারাপ।
#
# Preprocess Data:  যদি আসক্তি নিয়ে অনলাইন গেমের পিছনে লেগে থাকে তাহলে তা অবশ্যই খারাপ
# Sentence Type:  নেগেটিভ
#
# Data #49
# Raw Data:  আমরা যদি উন্নত দেশের দিকে তাকাই তাদের গেমিং সেক্টর অনেক বেশি উন্নত এবং সেখানে অনেক শিক্ষার্থী গেমিংয়ে তাদের ক্যারিয়ার সেট করে।
# Preprocess Data:  আমরা যদি উন্নত দেশের দিকে তাকাই তাদের গেমিং সেক্টর অনেক বেশি উন্নত এবং সেখানে অনেক শিক্ষার্থী গেমিংয়ে তাদের ক্যারিয়ার সেট করে
# Sentence Type:  পজিটিভ
#
# Data #50
# Raw Data:  আমাদের শিক্ষার্থীদেরও অনলাইন গেমিংয়ের সঠিক শিক্ষার প্রয়োজন এবং একজন ভালো মানুষ হওয়ার জন্য তাদের যথাযথ শিক্ষারও প্রয়োজন।
# Preprocess Data:  আমাদের শিক্ষার্থীদেরও অনলাইন গেমিংয়ের সঠিক শিক্ষার প্রয়োজন এবং একজন ভালো মানুষ হওয়ার জন্য তাদের যথাযথ শিক্ষারও প্রয়োজন
# Sentence Type:  পজিটিভ
#
# Data #51
# Raw Data:  কিছুই বলার নাই অনলাইন গেম এর খারাপ-ভালো দিক সম্পর্কে।
# Preprocess Data:  কিছুই বলার নাই অনলাইন গেম এর খারাপ ভালো দিক সম্পর্কে
# Sentence Type:  নিরপেক্ষ
#
# Data #52
# Raw Data:  সময়ের অপচয় ছাড়া কিছুই না।
# Preprocess Data:  সময়ের অপচয় ছাড়া কিছুই না
# Sentence Type:  নেগেটিভ
#
# Data #53
# Raw Data:  অনলাইন গেম আমাদের অবসর সময় কাটাতে সাহায্য করে।
# Preprocess Data:  অনলাইন গেম আমাদের অবসর সময় কাটাতে সাহায্য করে
# Sentence Type:  পজিটিভ
#
# Data #54
# Raw Data:  নিজেকে নিয়ন্ত্রণ করে গেমিং করলে খুব বেশি সমস্যা হওয়ার কথা নয় যদি না আসক্ত হয়ে যায়। শুধু বিনোদন /রিফ্রেশমেন্ট এর জন্য দিনের কোন একটা সময় গেমিং করা যেতে পারে।
# Preprocess Data:  নিজেকে নিয়ন্ত্রণ করে গেমিং করলে খুব বেশি সমস্যা হওয়ার কথা নয় যদি না আসক্ত হয়ে যায় শুধু বিনোদন রিফ্রেশমেন্ট এর জন্য দিনের কোন একটা সময় গেমিং করা যেতে পারে
# Sentence Type:  পজিটিভ
#
# Data #55
# Raw Data:  অনলাইনে গেম খেলা খারাপ। এর ফলে মানসিক সমস্যা হতে পারে।
# Preprocess Data:  অনলাইনে গেম খেলা খারাপ এর ফলে মানসিক সমস্যা হতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #56
# Raw Data:  অনলাইন গেম সম্পর্কে আমার কোনো মন্তব্য নেই।
# Preprocess Data:  অনলাইন গেম সম্পর্কে আমার কোনো মন্তব্য নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #57
# Raw Data:  আমরা সাধারণত বিনোদনের জন্য গেমিং করে থাকি। একেক জন মানুষ একেকটা মাধ্যমকে বিনোদনের জন্য ব্যবহার করে থাকে। সেটা মুভি-সিরিজ, বই পড়া বা গেমিং যে কোনো একটা হতে পারে। সেখানে গেমিংকে অফেন্সিভ হিসেবে দেখানোর কোনো মানে হয় না। আমি আমার বিনোদনের জন্য যে মাধ্যমটা ব্যবহার করার করতেছি, সেটা যদি কারো ক্ষতির কারন না হয়, সেখানে কোনো সমস্যা দেখছি না।
# Preprocess Data:  আমরা সাধারণত বিনোদনের জন্য গেমিং করে থাকি একেক জন মানুষ একেকটা মাধ্যমকে বিনোদনের জন্য ব্যবহার করে থাকে সেটা মুভি সিরিজ বই পড়া বা গেমিং যে কোনো একটা হতে পারে সেখানে গেমিংকে অফেন্সিভ হিসেবে দেখানোর কোনো মানে হয় না আমি আমার বিনোদনের জন্য যে মাধ্যমটা ব্যবহার করার করতেছি সেটা যদি কারো ক্ষতির কারন না হয় সেখানে কোনো সমস্যা দেখছি না
# Sentence Type:  পজিটিভ
#
# Data #58
# Raw Data:  অনলাইন গেম খেলার ফলে প্রতিদিন আমাদের মূল্যবান সময় নষ্ট হয়।
# Preprocess Data:  অনলাইন গেম খেলার ফলে প্রতিদিন আমাদের মূল্যবান সময় নষ্ট হয়
# Sentence Type:  নেগেটিভ
#
# Data #59
# Raw Data:  অনলাইনে গেমে খেলে কতটা সময় ব্যয় করবো তা সবসময় আমার নিজের উপর নির্ভর করবে। যদি আমি মনে করি যে আমার জীবনে এর খারাপ প্রভাব আছে তাহলে আমাকে অবশ্যই এই গেমগুলি ছেড়ে দিতে হবে।
# Preprocess Data:  অনলাইনে গেমে খেলে কতটা সময় ব্যয় করবো তা সবসময় আমার নিজের উপর নির্ভর করবে যদি আমি মনে করি যে আমার জীবনে এর খারাপ প্রভাব আছে তাহলে আমাকে অবশ্যই এই গেমগুলি ছেড়ে দিতে হবে
# Sentence Type:  নিরপেক্ষ
#
# Data #60
# Raw Data:  মন্তব্য নেই।
# Preprocess Data:  মন্তব্য নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #61
# Raw Data:  কখনও কখনও এটি ভালো, তবে অবশ্যই এটি আমাদের জন্য ক্ষতিকারক।
# Preprocess Data:  কখনও কখনও এটি ভালো তবে অবশ্যই এটি আমাদের জন্য ক্ষতিকারক
# Sentence Type:  নিরপেক্ষ
#
# Data #62
# Raw Data:  কিছুুই না।
# Preprocess Data:  কিছুুই না
# Sentence Type:  নিরপেক্ষ
#
# Data #63
# Raw Data:  এটা শুধু উপভোগের জন্য নিন।
# Preprocess Data:  এটা শুধু উপভোগের জন্য নিন
# Sentence Type:  নিরপেক্ষ
#
# Data #64
# Raw Data:  ক্ষতিকারক বিষয় জড়িত থাকার কারণে আমি অনলাইন গেম খেলি না।
# Preprocess Data:  ক্ষতিকারক বিষয় জড়িত থাকার কারণে আমি অনলাইন গেম খেলি না
# Sentence Type:  নেগেটিভ
#
# Data #65
# Raw Data:  অনলাইন গেম খেলে সময় নষ্ট করা ছাড়া আর কিছুই না।
# Preprocess Data:  অনলাইন গেম খেলে সময় নষ্ট করা ছাড়া আর কিছুই না
# Sentence Type:  নেগেটিভ
#
# Data #66
# Raw Data:  আমার মতামত হলো অনলাইন গেম হচ্ছে  মজা নিতে কাটানো কিছু মুহূর্ত। যেটাকে আমরা সময় অপচয় এর ভেতর ফেলতে পারি।
# Preprocess Data:  আমার মতামত হলো অনলাইন গেম হচ্ছে মজা নিতে কাটানো কিছু মুহূর্ত যেটাকে আমরা সময় অপচয় এর ভেতর ফেলতে পারি
# Sentence Type:  নিরপেক্ষ
#
# Data #67
# Raw Data:  অনলাইন গেম খেললে পরিবাবের সাথে দূরুত্ব তৈরি হতে পারে।
# Preprocess Data:  অনলাইন গেম খেললে পরিবাবের সাথে দূরুত্ব তৈরি হতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #68
# Raw Data:  আপনি যখন অতিরিক্ত বেশি সময় নষ্ট করছেন তখন এটি খুব খারাপ।
# Preprocess Data:  আপনি যখন অতিরিক্ত বেশি সময় নষ্ট করছেন তখন এটি খুব খারাপ
# Sentence Type:  নেগেটিভ
#
# Data #69
# Raw Data:  আপনি খেলার সময় একটি নির্দিষ্ট সীমা অনুসরণ করলে এটি ঠিক হবে।
# Preprocess Data:  আপনি খেলার সময় একটি নির্দিষ্ট সীমা অনুসরণ করলে এটি ঠিক হবে
# Sentence Type:  নিরপেক্ষ
#
# Data #70
# Raw Data:  অনলাইন গেম খেলা একজন ব্যক্তিকে তার কৌশলগত চিন্তাভাবনা বিকাশে সহায়তা করে।
# Preprocess Data:  অনলাইন গেম খেলা একজন ব্যক্তিকে তার কৌশলগত চিন্তাভাবনা বিকাশে সহায়তা করে
# Sentence Type:  পজিটিভ
#
# Data #71
# Raw Data:  বাচ্চারা অনলাইন গেম খেলে অনেক বেশি সময় নষ্ট করে এবং এটা বাচ্চাদের জন্য ক্ষতিকর।
# Preprocess Data:  বাচ্চারা অনলাইন গেম খেলে অনেক বেশি সময় নষ্ট করে এবং এটা বাচ্চাদের জন্য ক্ষতিকর
# Sentence Type:  নেগেটিভ
#
# Data #72
# Raw Data:  অনলাইন গেম খেলা একটি শিশুর মানসিক বৃদ্ধিতে সবচেয়ে গুরুত্বপূর্ণ ভূমিকা পালন করে। তবে এটি সীমাবদ্ধ এবং নিয়ন্ত্রণের মধ্যে হওয়া উচিত।
# Preprocess Data:  অনলাইন গেম খেলা একটি শিশুর মানসিক বৃদ্ধিতে সবচেয়ে গুরুত্বপূর্ণ ভূমিকা পালন করে তবে এটি সীমাবদ্ধ এবং নিয়ন্ত্রণের মধ্যে হওয়া উচিত
# Sentence Type:  নিরপেক্ষ
#
# Data #73
# Raw Data:  যতক্ষণ না অনলাইন গেম খেলা আমাদের মানসিকতা, আচার-আচরণ, শিষ্টাচার বা সমাজের ক্ষতি না করে ততক্ষণ এটি বিনোদন হিসেবে একেবারেই ঠিক।
# Preprocess Data:  যতক্ষণ না অনলাইন গেম খেলা আমাদের মানসিকতা আচার আচরণ শিষ্টাচার বা সমাজের ক্ষতি না করে ততক্ষণ এটি বিনোদন হিসেবে একেবারেই ঠিক
# Sentence Type:  পজিটিভ
#
# Data #74
# Raw Data:  মন্তব্য নেই অনলাইন গেম খেলা সম্পর্কে।
# Preprocess Data:  মন্তব্য নেই অনলাইন গেম খেলা সম্পর্কে
# Sentence Type:  নিরপেক্ষ
#
# Data #75
# Raw Data:  কিছুই বলার নাই অনলাইন গেম সম্পর্কে।
# Preprocess Data:  কিছুই বলার নাই অনলাইন গেম সম্পর্কে
# Sentence Type:  নিরপেক্ষ
#
# Data #76
# Raw Data:  এটা আসক্তি কিন্তু এর সাথে অন্য কাজের অগ্রাধিকার অনুভব করা উচিত। অনলাইন গেমিং মুছে না দিয়ে, আমাদের এই প্ল্যাটফর্মটিকে প্রধানত আমাদের বাচ্চাদের জন্য একটি শেখার পরিবেশ  পরিবর্তন করার দিকে আরও বেশি মনোযোগ দেওয়া উচিত।
# Preprocess Data:  এটা আসক্তি কিন্তু এর সাথে অন্য কাজের অগ্রাধিকার অনুভব করা উচিত অনলাইন গেমিং মুছে না দিয়ে আমাদের এই প্ল্যাটফর্মটিকে প্রধানত আমাদের বাচ্চাদের জন্য একটি শেখার পরিবেশ পরিবর্তন করার দিকে আরও বেশি মনোযোগ দেওয়া উচিত
# Sentence Type:  নিরপেক্ষ
#
# Data #77
# Raw Data:  কিছু সময় কাটানোর জন্য ভালো মাধ্যম।
# Preprocess Data:  কিছু সময় কাটানোর জন্য ভালো মাধ্যম
# Sentence Type:  পজিটিভ
#
# Data #78
# Raw Data:  অনলাইন গেম খেলা মানুষকে ব্যস্ত করে ফেলে এবং যেটা একসময় মানুষকে আসক্তির দিকে নিয়ে যায়।
# Preprocess Data:  অনলাইন গেম খেলা মানুষকে ব্যস্ত করে ফেলে এবং যেটা একসময় মানুষকে আসক্তির দিকে নিয়ে যায়
# Sentence Type:  নেগেটিভ
#
# Data #79
# Raw Data:  অনলাইন গেম খেলা এক ধরনের ডিজিটাল ড্রাগ।
# Preprocess Data:  অনলাইন গেম খেলা এক ধরনের ডিজিটাল ড্রাগ
# Sentence Type:  নেগেটিভ
#
# Data #80
# Raw Data:  অনলাইন গেমিং  সময় নষ্ট করা ছাড়া আর কিছুই না।
# Preprocess Data:  অনলাইন গেমিং সময় নষ্ট করা ছাড়া আর কিছুই না
# Sentence Type:  নেগেটিভ
#
# Data #81
# Raw Data:  অনলাইন গেম খেলা  সত্যিই একটি খারাপ অভ্যাস।
# Preprocess Data:  অনলাইন গেম খেলা সত্যিই একটি খারাপ অভ্যাস
# Sentence Type:  নেগেটিভ
#
# Data #82
# Raw Data:  সীমার মধ্যে অনলাইন গেম খেলা উচিত। যেনো এর ক্ষতিকর প্রভাব না পড়ে।
# Preprocess Data:  সীমার মধ্যে অনলাইন গেম খেলা উচিত যেনো এর ক্ষতিকর প্রভাব না পড়ে
# Sentence Type:  নিরপেক্ষ
#
# Data #83
# Raw Data:  অনলাইন গেম খেলা বিনোদনের একটি মাধ্যম।
# Preprocess Data:  অনলাইন গেম খেলা বিনোদনের একটি মাধ্যম
# Sentence Type:  পজিটিভ
#
# Data #84
# Raw Data:  আমি গেমিং পছন্দ করি না।
# Preprocess Data:  আমি গেমিং পছন্দ করি না
# Sentence Type:  নেগেটিভ
#
# Data #85
# Raw Data:  বেশিরভাগ ক্ষেত্রে আমি অনলাইন গেম খেলা সমর্থন করি না।
# Preprocess Data:  বেশিরভাগ ক্ষেত্রে আমি অনলাইন গেম খেলা সমর্থন করি না
# Sentence Type:  নেগেটিভ
#
# Data #86
# Raw Data:  সময় নষ্ট করা ছাড়া কিছুই না অনলাইন গেম খেলা।
# Preprocess Data:  সময় নষ্ট করা ছাড়া কিছুই না অনলাইন গেম খেলা
# Sentence Type:  নেগেটিভ
#
# Data #87
# Raw Data:  নিজেকে নিয়ন্ত্রণ করতে পারলে ভালো তাছাড়া ক্ষতিকর।
# Preprocess Data:  নিজেকে নিয়ন্ত্রণ করতে পারলে ভালো তাছাড়া ক্ষতিকর
# Sentence Type:  নিরপেক্ষ
#
# Data #88
# Raw Data:  অনলাইন গেমটি বিনোদনমূলক কিন্তু দৈনিক ভিত্তিতে দীর্ঘ সময়ের জন্য অনলাইন গেম খেলা একটি ক্ষতিকর দিক।
# Preprocess Data:  অনলাইন গেমটি বিনোদনমূলক কিন্তু দৈনিক ভিত্তিতে দীর্ঘ সময়ের জন্য অনলাইন গেম খেলা একটি ক্ষতিকর দিক
# Sentence Type:  নিরপেক্ষ
#
# Data #89
# Raw Data:  অনলাইন গেম খেলার কোনো দরকার আসে না।
# Preprocess Data:  অনলাইন গেম খেলার কোনো দরকার আসে না
# Sentence Type:  নেগেটিভ
#
# Data #90
# Raw Data:  অনলাইন গেমে আসক্তি হয়ে গেলে সমস্যা।
# Preprocess Data:  অনলাইন গেমে আসক্তি হয়ে গেলে সমস্যা
# Sentence Type:  নেগেটিভ
#
# Data #91
# Raw Data:  জীবনের প্রয়োজনীয় সময়কে কাজে লাগানোর জন্য সব সময় গেম খেলতে হবে।
# Preprocess Data:  জীবনের প্রয়োজনীয় সময়কে কাজে লাগানোর জন্য সব সময় গেম খেলতে হবে
# Sentence Type:  পজিটিভ
#
# Data #92
# Raw Data:  প্রত্যাহিক কাজে  নিয়োজিত ব্যক্তিরা কখনো গেম খেলে সময় নষ্ট করে না।
# Preprocess Data:  প্রত্যাহিক কাজে নিয়োজিত ব্যক্তিরা কখনো গেম খেলে সময় নষ্ট করে না
# Sentence Type:  নেগেটিভ
#
# Data #93
# Raw Data:  বিনোদনের জন্য খেলা যায়, কিন্তু আসক্ত হয়ে যাওয়া মোটেও কাজের কথা নয়। যদি আসক্তি আসে তাহলে অবশ্যই গ্যাপ দেওয়া বা ছেড়ে দেয়া উচিৎ।
# Preprocess Data:  বিনোদনের জন্য খেলা যায় কিন্তু আসক্ত হয়ে যাওয়া মোটেও কাজের কথা নয় যদি আসক্তি আসে তাহলে অবশ্যই গ্যাপ দেওয়া বা ছেড়ে দেয়া উচিৎ
# Sentence Type:  নিরপেক্ষ
#
# Data #94
# Raw Data:  এটি বিনোদনের একটি মাধ্যম কিন্তু বর্তমানে এটি প্রধানত নেতিবাচক প্রভাব ফেলেছে।
# Preprocess Data:  এটি বিনোদনের একটি মাধ্যম কিন্তু বর্তমানে এটি প্রধানত নেতিবাচক প্রভাব ফেলেছে
# Sentence Type:  নিরপেক্ষ
#
# Data #95
# Raw Data:  অনলাইন গেম খেলা ভালো না আমার দৃষ্টিতে।
# Preprocess Data:  অনলাইন গেম খেলা ভালো না আমার দৃষ্টিতে
# Sentence Type:  নেগেটিভ
#
# Data #96
# Raw Data:  আমি গেইম খুব কম খেলি।শিক্ষামূলক গেইম বা পাজল গেইম হলে খেলে থাকি।
# Preprocess Data:  আমি গেইম খুব কম খেলি শিক্ষামূলক গেইম বা পাজল গেইম হলে খেলে থাকি
# Sentence Type:  নিরপেক্ষ
#
# Data #97
# Raw Data:  অনলাইন গেম মানসিক স্বাস্থ্যের জন্য ক্ষতিকর। এছাড়া এটা সময় নষ্ট করে।
# Preprocess Data:  অনলাইন গেম মানসিক স্বাস্থ্যের জন্য ক্ষতিকর এছাড়া এটা সময় নষ্ট করে
# Sentence Type:  নেগেটিভ
#
# Data #98
# Raw Data:  এটা আমাদের মূল্যবান সময় নষ্ট করে, আমাদের পড়াশোনায় বাঁধা দেয়।
# Preprocess Data:  এটা আমাদের মূল্যবান সময় নষ্ট করে আমাদের পড়াশোনায় বাঁধা দেয়
# Sentence Type:  নেগেটিভ
#
# Data #99
# Raw Data:  মানসিক প্রশান্তির জন্য অনলাইন গেম খেলা ভালো।
# Preprocess Data:  মানসিক প্রশান্তির জন্য অনলাইন গেম খেলা ভালো
# Sentence Type:  পজিটিভ
#
# Data #100
# Raw Data:  অনলাইন গেম খেলা ভাালো মানসিক বিকাশের জন্য।
# Preprocess Data:  অনলাইন গেম খেলা ভাালো মানসিক বিকাশের জন্য
# Sentence Type:  পজিটিভ
#
# Data #101
# Raw Data:  অনলাইন গেম খেলা আমাকে আনন্দের সাথে আমার অবসর সময় কাটাতে সাহায্য করে এবং এটি আমাকে মানসিকভাবে সক্রিয় থাকতেও সাহায্য করে।
# Preprocess Data:  অনলাইন গেম খেলা আমাকে আনন্দের সাথে আমার অবসর সময় কাটাতে সাহায্য করে এবং এটি আমাকে মানসিকভাবে সক্রিয় থাকতেও সাহায্য করে
# Sentence Type:  পজিটিভ
#
# Data #102
# Raw Data:  অনলাইন গেমিং আমাদের দিনের অনেকটা সময় নষ্ট করে।
# Preprocess Data:  অনলাইন গেমিং আমাদের দিনের অনেকটা সময় নষ্ট করে
# Sentence Type:  নেগেটিভ
#
# Data #103
# Raw Data:  গেম খেলা  বিনোদনের উদ্দেশ্য মাত্র। তবে এটা নিয়ে সিরিয়াস হয়ে পড়লে ক্ষতিকর।
# Preprocess Data:  গেম খেলা বিনোদনের উদ্দেশ্য মাত্র তবে এটা নিয়ে সিরিয়াস হয়ে পড়লে ক্ষতিকর
# Sentence Type:  নিরপেক্ষ
#
# Data #104
# Raw Data:  আমি মনে করি অনলাইন গেম খেলা সময়ের অপচয় করে এবং মস্তিষ্কেরও ক্ষতিসাধন করে।
# Preprocess Data:  আমি মনে করি অনলাইন গেম খেলা সময়ের অপচয় করে এবং মস্তিষ্কেরও ক্ষতিসাধন করে
# Sentence Type:  নেগেটিভ
#
# Data #105
# Raw Data:  অতিরিক্ত গেম খেলা  একজন সুস্থ  ব্যক্তিকে অস্বাভাবিক করে তুলতে পারে।
# Preprocess Data:  অতিরিক্ত গেম খেলা একজন সুস্থ ব্যক্তিকে অস্বাভাবিক করে তুলতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #106
# Raw Data:  কখনও কখনও আমাদের অনলাইন গেম খেলতে হয়।কারণ আমরা যখন একটানা কাজ করে ক্লান্ত হয়ে পড়ি তখন আমরা খুব বিরক্ত বোধ করি। তখন যদি আমরা গেম খেলি তবে এটি আমাদের  আনন্দ দেয়। যেটা অনলাইন গেম খেলার ইতিবাচক দিক বলে  আমি মনে করি।
# Preprocess Data:  কখনও কখনও আমাদের অনলাইন গেম খেলতে হয় কারণ আমরা যখন একটানা কাজ করে ক্লান্ত হয়ে পড়ি তখন আমরা খুব বিরক্ত বোধ করি তখন যদি আমরা গেম খেলি তবে এটি আমাদের আনন্দ দেয় যেটা অনলাইন গেম খেলার ইতিবাচক দিক বলে আমি মনে করি
# Sentence Type:  পজিটিভ
#
# Data #107
# Raw Data:  অনলাইন গেম খেলা আমার জীবনের একটা অংশ বলা চলে।
# Preprocess Data:  অনলাইন গেম খেলা আমার জীবনের একটা অংশ বলা চলে
# Sentence Type:  পজিটিভ
#
# Data #108
# Raw Data:  অনলাইন গেম খেলা আমাদের দৈনন্দিন জীবনের একটি অংশ। সময় কাটানোর জন্য এটি একটি ভাল মাধ্যম।
# Preprocess Data:  অনলাইন গেম খেলা আমাদের দৈনন্দিন জীবনের একটি অংশ সময় কাটানোর জন্য এটি একটি ভাল মাধ্যম
# Sentence Type:  পজিটিভ
#
# Data #109
# Raw Data:   অবসর সময় কাটানোর ক্ষেত্রে ভালো উপায়।
# Preprocess Data:  অবসর সময় কাটানোর ক্ষেত্রে ভালো উপায়
# Sentence Type:  পজিটিভ
#
# Data #110
# Raw Data:  সময় অপচয় হয়  এবং ইন্টারনেট কিনতে টাকার প্রয়োজন পড়ে।
# Preprocess Data:  সময় অপচয় হয় এবং ইন্টারনেট কিনতে টাকার প্রয়োজন পড়ে
# Sentence Type:  নেগেটিভ
#
# Data #111
# Raw Data:  এটি ভালো যদি লিমিটেড সময়ে খেলা হয়।
# Preprocess Data:  এটি ভালো যদি লিমিটেড সময়ে খেলা হয়
# Sentence Type:  নিরপেক্ষ
#
# Data #112
# Raw Data:  মানুষের নৈতিকতা বিকাশের লক্ষ্যে গেম খেলার বিকাশ করা উচিত যা মানুষকে  শান্তিতে থাকতে দেয়।
# Preprocess Data:  মানুষের নৈতিকতা বিকাশের লক্ষ্যে গেম খেলার বিকাশ করা উচিত যা মানুষকে শান্তিতে থাকতে দেয়
# Sentence Type:  পজিটিভ
#
# Data #113
# Raw Data:  এটি একজন ব্যক্তির গুরুত্বপূর্ণ সময় নষ্ট করে।
# Preprocess Data:  এটি একজন ব্যক্তির গুরুত্বপূর্ণ সময় নষ্ট করে
# Sentence Type:  নেগেটিভ
#
# Data #114
# Raw Data:  কোন মন্তব্য নেই অনলাইন গেম খেলা নিয়ে।
# Preprocess Data:  কোন মন্তব্য নেই অনলাইন গেম খেলা নিয়ে
# Sentence Type:  নিরপেক্ষ
#
# Data #115
# Raw Data:  ভালো-খারাপ কোনোকিছু নিয়ে বলার কিছু নাই অনলাইন গেম সম্পর্কে।
# Preprocess Data:  ভালো খারাপ কোনোকিছু নিয়ে বলার কিছু নাই অনলাইন গেম সম্পর্কে
# Sentence Type:  নিরপেক্ষ
#
# Data #116
# Raw Data:  গবেষণায় দেখা গেছে যে নিয়মিত ভিডিও গেম খেললে মস্তিষ্কে ধূসর পদার্থ বাড়তে পারে এবং মস্তিষ্কের সংযোগ বাড়াতে পারে।
# Preprocess Data:  গবেষণায় দেখা গেছে যে নিয়মিত ভিডিও গেম খেললে মস্তিষ্কে ধূসর পদার্থ বাড়তে পারে এবং মস্তিষ্কের সংযোগ বাড়াতে পারে
# Sentence Type:  পজিটিভ
#
# Data #117
# Raw Data:  গেম খেলা একটি ইতিবাচক দিক বলে মনে করি।
# Preprocess Data:  গেম খেলা একটি ইতিবাচক দিক বলে মনে করি
# Sentence Type:  পজিটিভ
#
# Data #118
# Raw Data:  অনলাইন গেম খেলা জীবনের মূল্যবান সময় নষ্ট করে।
# Preprocess Data:  অনলাইন গেম খেলা জীবনের মূল্যবান সময় নষ্ট করে
# Sentence Type:  নেগেটিভ
#
# Data #119
# Raw Data:  ভালো সময় কাটানোর ক্ষেত্রে হঠাৎ খেলা যেতে পারে তবে সেটা যেনো মাত্রাতিরিক্ত হয়ে না পড়ে।
# Preprocess Data:  ভালো সময় কাটানোর ক্ষেত্রে হঠাৎ খেলা যেতে পারে তবে সেটা যেনো মাত্রাতিরিক্ত হয়ে না পড়ে
# Sentence Type:  নিরপেক্ষ
#
# Data #120
# Raw Data:  অনলাইন গেম খেলা ভালো এবং সেই সাথে আনন্দদায়ক।
# Preprocess Data:  অনলাইন গেম খেলা ভালো এবং সেই সাথে আনন্দদায়ক
# Sentence Type:  পজিটিভ
#
# Data #121
# Raw Data:  এটা আমাদের সময় কাটানোর জন্য ভালো।
# Preprocess Data:  এটা আমাদের সময় কাটানোর জন্য ভালো
# Sentence Type:  পজিটিভ
#
# Data #122
# Raw Data:  এটি আমাদের জীবনের একটি অপরিহার্য অংশ হয়ে উঠেছে।
# Preprocess Data:  এটি আমাদের জীবনের একটি অপরিহার্য অংশ হয়ে উঠেছে
# Sentence Type:  পজিটিভ
#
# Data #123
# Raw Data:  ব্যক্তিগতভাবে আমি গেম খেলা পছন্দ করি না।
# Preprocess Data:  ব্যক্তিগতভাবে আমি গেম খেলা পছন্দ করি না
# Sentence Type:  নেগেটিভ
#
# Data #124
# Raw Data:  গেম খেলা শুধু সময়ের অপচয় ছাড়া কিছুই না।
# Preprocess Data:  গেম খেলা শুধু সময়ের অপচয় ছাড়া কিছুই না
# Sentence Type:  নেগেটিভ
#
# Data #125
# Raw Data:  অনলাইন গেম সম্পর্কে জানা নেই।
# Preprocess Data:  অনলাইন গেম সম্পর্কে জানা নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #126
# Raw Data:  আমরা একটি বধ্য পরিবেশে বাস করি, খেলার মতো তেমন কোন পরিবেশ নেই। তাই বিনোদনের জন্য হলেও কিছু সময় অনলাইন গেম খেলা দরকার।
# Preprocess Data:  আমরা একটি বধ্য পরিবেশে বাস করি খেলার মতো তেমন কোন পরিবেশ নেই তাই বিনোদনের জন্য হলেও কিছু সময় অনলাইন গেম খেলা দরকার
# Sentence Type:  পজিটিভ
#
# Data #127
# Raw Data:  আমাদের মজার জন্য হলেও অনলাইন গেম খেলা উচিত।
# Preprocess Data:  আমাদের মজার জন্য হলেও অনলাইন গেম খেলা উচিত
# Sentence Type:  পজিটিভ
#
# Data #128
# Raw Data:  অবসর সময়ের জন্য ভালো অনলাইন গেম খেলা।
# Preprocess Data:  অবসর সময়ের জন্য ভালো অনলাইন গেম খেলা
# Sentence Type:  পজিটিভ
#
# Data #129
# Raw Data:  অনলাইন গেম থেকে ভালো কিছুই আসে না।
# Preprocess Data:  অনলাইন গেম থেকে ভালো কিছুই আসে না
# Sentence Type:  নেগেটিভ
#
# Data #130
# Raw Data:  অনলাইন গেমস শিক্ষা জীবনে ছাত্র-ছাত্রীদের উপর প্রভাব পেলে। এটি সময় নষ্টের পাশাপাশি জীবন গঠনে বাঁধা হয়ে দাঁড়ায়। সুতারং অনলাইন গেমসকে প্রত্যাখান করাই উচিৎ।
# Preprocess Data:  অনলাইন গেমস শিক্ষা জীবনে ছাত্র ছাত্রীদের উপর প্রভাব পেলে এটি সময় নষ্টের পাশাপাশি জীবন গঠনে বাঁধা হয়ে দাঁড়ায় সুতারং অনলাইন গেমসকে প্রত্যাখান করাই উচিৎ
# Sentence Type:  নেগেটিভ
#
# Data #131
# Raw Data:  গেম খেলা খারাপ আমার দৃষ্টিতে।
# Preprocess Data:  গেম খেলা খারাপ আমার দৃষ্টিতে
# Sentence Type:  নেগেটিভ
#
# Data #132
# Raw Data:  গেম খেলা যার যার ব্যক্তিগত ইচ্ছা বলে আমার মনে হয়।
# Preprocess Data:  গেম খেলা যার যার ব্যক্তিগত ইচ্ছা বলে আমার মনে হয়
# Sentence Type:  পজিটিভ
#
# Data #133
# Raw Data:  উপভোগের উদ্দেশ্যে এটি ঠিক আছে কিন্তু যখন এটি গেমিং আসক্তিতে চলে যায় তখন এটি যে কারও জন্য সমস্যার কারণ হতে পারে।
# Preprocess Data:  উপভোগের উদ্দেশ্যে এটি ঠিক আছে কিন্তু যখন এটি গেমিং আসক্তিতে চলে যায় তখন এটি যে কারও জন্য সমস্যার কারণ হতে পারে
# Sentence Type:  নিরপেক্ষ
#
# Data #134
# Raw Data:  আমাদের মূল্যবান সময় নষ্ট করে।
# Preprocess Data:  আমাদের মূল্যবান সময় নষ্ট করে
# Sentence Type:  নেগেটিভ
#
# Data #135
# Raw Data:  আমি যখন গেম খেলি তখন আমার সময়টা উপভোগ্য হয়ে উঠে।
# Preprocess Data:  আমি যখন গেম খেলি তখন আমার সময়টা উপভোগ্য হয়ে উঠে
# Sentence Type:  পজিটিভ
#
# Data #136
# Raw Data:  এটি এমন একটি কারণ যা আমাদের পিতামাতার সাথে এবং আমাদের সমাজের সাথে আমাদের সম্পর্ককে খারাপ করে তুলতে পারে।
# Preprocess Data:  এটি এমন একটি কারণ যা আমাদের পিতামাতার সাথে এবং আমাদের সমাজের সাথে আমাদের সম্পর্ককে খারাপ করে তুলতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #137
# Raw Data:  এটি না খেলা ই উত্তম।কিন্তু সময় নষ্ট না করে অল্প সময়ের জন্য, শিক্ষামূলক গেম খেললে তা গ্রহনযোগ্য। কিন্তু অতিরিক্ত সময় ব্যয় করে, অপ্র্যজনীয় জিনিসে সময় ব্যয় না করা ই ভালো।
# Preprocess Data:  এটি না খেলা ই উত্তম কিন্তু সময় নষ্ট না করে অল্প সময়ের জন্য শিক্ষামূলক গেম খেললে তা গ্রহনযোগ্য কিন্তু অতিরিক্ত সময় ব্যয় করে অপ্র্যজনীয় জিনিসে সময় ব্যয় না করা ই ভালো
# Sentence Type:  নিরপেক্ষ
#
# Data #138
# Raw Data:  অনলাইন গেম খেলা স্বাস্থ্যের জন্য ক্ষতিকর।
# Preprocess Data:  অনলাইন গেম খেলা স্বাস্থ্যের জন্য ক্ষতিকর
# Sentence Type:  নেগেটিভ
#
# Data #139
# Raw Data:  কোনোরুপ মন্তব্য নেই অনলাইন গেম খেলা-না খেলা নিয়ে।
# Preprocess Data:  কোনোরুপ মন্তব্য নেই অনলাইন গেম খেলা না খেলা নিয়ে
# Sentence Type:  নিরপেক্ষ
#
# Data #140
# Raw Data:  অনলাইনে গেম খেলা খুব খারাপ বলে আমি মনে করি।
# Preprocess Data:  অনলাইনে গেম খেলা খুব খারাপ বলে আমি মনে করি
# Sentence Type:  নেগেটিভ
#
# Data #141
# Raw Data:  বিনোদন এর জন্যে প্রয়োজন কিন্তু বেশি মাতামাতি না করাই ভালো।
# Preprocess Data:  বিনোদন এর জন্যে প্রয়োজন কিন্তু বেশি মাতামাতি না করাই ভালো
# Sentence Type:  নিরপেক্ষ
#
# Data #142
# Raw Data:  সবকিছুুতে সীমাবদ্ধতা থাকা উচিৎ।
# Preprocess Data:  সবকিছুুতে সীমাবদ্ধতা থাকা উচিৎ
# Sentence Type:  নিরপেক্ষ
#
# Data #143
# Raw Data:  গেম খেলা আমাদের সময়ের অপচয় মাত্র।
# Preprocess Data:  গেম খেলা আমাদের সময়ের অপচয় মাত্র
# Sentence Type:  নেগেটিভ
#
# Data #144
# Raw Data:  সীমা অতিক্রম না করা পর্যন্ত অনলাইন গেম ক্ষতিকর নয়। কেউ যদি ওভারটাইম করে অনলাইন গেম না খেলে, তাহলে এটা ক্ষতিকর নয়। আবার, অনেক লোক গেম খেলার জন্য প্রচুর অর্থ ব্যয় করে, যা মোটেও ভাল নয়। আমার মনে হয় তারা একটি মূল্যহীন জিনিসের জন্য অর্থ ব্যয় করছে। যদি কেউ গেম খেলতে চায়, তবে তা সীমিত রাখতে হবে যতক্ষণ না এটি ব্যক্তির জন্য ক্ষতিকর হয়।
# Preprocess Data:  সীমা অতিক্রম না করা পর্যন্ত অনলাইন গেম ক্ষতিকর নয় কেউ যদি ওভারটাইম করে অনলাইন গেম না খেলে তাহলে এটা ক্ষতিকর নয় আবার অনেক লোক গেম খেলার জন্য প্রচুর অর্থ ব্যয় করে যা মোটেও ভাল নয় আমার মনে হয় তারা একটি মূল্যহীন জিনিসের জন্য অর্থ ব্যয় করছে যদি কেউ গেম খেলতে চায় তবে তা সীমিত রাখতে হবে যতক্ষণ না এটি ব্যক্তির জন্য ক্ষতিকর হয়
# Sentence Type:  নিরপেক্ষ
#
# Data #145
# Raw Data:  এটা আমাদের আগামী প্রজন্মের জন্য একেবারেই উদ্বেগজনক। এটা তাদের অসুস্থ করে তোলে, শৃঙ্খলাহীন হিংস্র এবং আরও অনেক কিছু করে তুলে। একটি জাতির মেরুদন্ড ধ্বংস করে ফেলে।
# Preprocess Data:  এটা আমাদের আগামী প্রজন্মের জন্য একেবারেই উদ্বেগজনক এটা তাদের অসুস্থ করে তোলে শৃঙ্খলাহীন হিংস্র এবং আরও অনেক কিছু করে তুলে একটি জাতির মেরুদন্ড ধ্বংস করে ফেলে
# Sentence Type:  নেগেটিভ
#
# Data #146
# Raw Data:  এই মুহূর্তে গেমিং খাতে একটি বড় ই-স্পোর্টস বিনিয়োগ রয়েছে। পিসি বা কনসোল গেমগুলি এখন ক্রিকেট, ফুটবল ইত্যাদির মতো শারীরিকভাবে খেলা খেলার সাথে তুলনা করা হয়৷ যদি একটি বাচ্চা একই গেমিং প্ল্যাটফর্মে অন্যান্য বাচ্চাদের ছাড়িয়ে যাওয়ার মতো প্রতিভাবান হয় তবে সে সহজেই বিশ্বের শীর্ষ উপার্জনকারীদের একজন হতে পারে৷ সুতরাং, কেউ যদি সিরিয়াস গেম খেলে সে বা সে অন্যান্য ক্রিকেট বা ফুটবল পেশাদার খেলোয়াড়দের মতো একজন পেশাদার খেলোয়াড় হতে পারে।
# Preprocess Data:  এই মুহূর্তে গেমিং খাতে একটি বড় ই স্পোর্টস বিনিয়োগ রয়েছে পিসি বা কনসোল গেমগুলি এখন ক্রিকেট ফুটবল ইত্যাদির মতো শারীরিকভাবে খেলা খেলার সাথে তুলনা করা হয়৷ যদি একটি বাচ্চা একই গেমিং প্ল্যাটফর্মে অন্যান্য বাচ্চাদের ছাড়িয়ে যাওয়ার মতো প্রতিভাবান হয় তবে সে সহজেই বিশ্বের শীর্ষ উপার্জনকারীদের একজন হতে পারে৷ সুতরাং কেউ যদি সিরিয়াস গেম খেলে সে বা সে অন্যান্য ক্রিকেট বা ফুটবল পেশাদার খেলোয়াড়দের মতো একজন পেশাদার খেলোয়াড় হতে পারে
# Sentence Type:  পজিটিভ
#
# Data #147
# Raw Data:  গেম এর ব্যাপারে কোনো মতামত নেই।
# Preprocess Data:  গেম এর ব্যাপারে কোনো মতামত নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #148
# Raw Data:  অনলাইন গেম সম্পর্কে ধারণা নেই।
# Preprocess Data:  অনলাইন গেম সম্পর্কে ধারণা নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #149
# Raw Data:  আমি তখনই অফলাইন মিনি গেম পছন্দ করি যখন আমার কিছুই করার থাকে না। যেনো ক্ষতিসাধ্ণ না হয়।
# Preprocess Data:  আমি তখনই অফলাইন মিনি গেম পছন্দ করি যখন আমার কিছুই করার থাকে না যেনো ক্ষতিসাধ্ণ না হয়
# Sentence Type:  নিরপেক্ষ
#
# Data #150
# Raw Data:  প্রতিযোগিতামূলক গেম দ্রুত চিন্তা করার ক্ষমতা উন্নত করতে সাহায্য করে।
# Preprocess Data:  প্রতিযোগিতামূলক গেম দ্রুত চিন্তা করার ক্ষমতা উন্নত করতে সাহায্য করে
# Sentence Type:  পজিটিভ
#
# Data #151
# Raw Data:  বিনোদনের জন্য অনলাইন গেম খেলি।
# Preprocess Data:  বিনোদনের জন্য অনলাইন গেম খেলি
# Sentence Type:  পজিটিভ
#
# Data #152
# Raw Data:  সময় নষ্ট করা ছাড়া এটা আর কিছুই না৷  জীবনে বড় হতে হলে এইসব সময় নষ্ট করা খেলা থেকে দূরে থাকা অনেক জরুরী।
# Preprocess Data:  সময় নষ্ট করা ছাড়া এটা আর কিছুই না৷ জীবনে বড় হতে হলে এইসব সময় নষ্ট করা খেলা থেকে দূরে থাকা অনেক জরুরী
# Sentence Type:  নেগেটিভ
#
# Data #153
# Raw Data:  সতেজতার জন্য অনলাইন গেম খেলা উচিত।
# Preprocess Data:  সতেজতার জন্য অনলাইন গেম খেলা উচিত
# Sentence Type:  পজিটিভ
#
# Data #154
# Raw Data:  অনলাইন গেম খেলা ভালো প্ল্যাটফর্ম এর ভেতর পড়ে।
# Preprocess Data:  অনলাইন গেম খেলা ভালো প্ল্যাটফর্ম এর ভেতর পড়ে
# Sentence Type:  পজিটিভ
#
# Data #155
# Raw Data:  অনলাইন গেম খেলা সীমাবদ্ধতা অনুযায়ী হলে সবসময়ই ভালো, কিন্তু সীমাবদ্ধতা পেরিয়ে গেলে সবসময় ক্ষতিকর।
# Preprocess Data:  অনলাইন গেম খেলা সীমাবদ্ধতা অনুযায়ী হলে সবসময়ই ভালো কিন্তু সীমাবদ্ধতা পেরিয়ে গেলে সবসময় ক্ষতিকর
# Sentence Type:  নিরপেক্ষ
#
# Data #156
# Raw Data:  আপনি যখন এটি খেলেন তখন এটি ভালো, কিন্তু যখন এটি আপনাকে খেলে তখন এটি খুব বিপজ্জনক হতে পারে।
# Preprocess Data:  আপনি যখন এটি খেলেন তখন এটি ভালো কিন্তু যখন এটি আপনাকে খেলে তখন এটি খুব বিপজ্জনক হতে পারে
# Sentence Type:  নিরপেক্ষ
#
# Data #157
# Raw Data:  আমাদের গেম খেলা উচিত। এটা আমাদের আইকিউ লেভেল বাড়াতে সাহায্য করে। তবে তা সীমিত সময়ের জন্য হওয়া উচিত। আমার মতে ৩০ মিনিট-৬০ মিনিটের সীমা থাকা উচিত।
# Preprocess Data:  আমাদের গেম খেলা উচিত এটা আমাদের আইকিউ লেভেল বাড়াতে সাহায্য করে তবে তা সীমিত সময়ের জন্য হওয়া উচিত আমার মতে মিনিট মিনিটের সীমা থাকা উচিত
# Sentence Type:  নিরপেক্ষ
#
# Data #158
# Raw Data:  অনলাইন গেম খেলা কখনো ভালো আবার কখনো জীবনের জন্য খারাপ।
# Preprocess Data:  অনলাইন গেম খেলা কখনো ভালো আবার কখনো জীবনের জন্য খারাপ
# Sentence Type:  নিরপেক্ষ
#
# Data #159
# Raw Data:  এটি খেলা ভালো তবে বর্তমানে মানুষ এর প্রতি সময় অনেক বেশি ব্যয় করে। যা করা উচিত না। খুব কম সময় এর প্রতি ব্যয় করলে সব দিক থেকে ঠিক থাকবে।
# Preprocess Data:  এটি খেলা ভালো তবে বর্তমানে মানুষ এর প্রতি সময় অনেক বেশি ব্যয় করে যা করা উচিত না খুব কম সময় এর প্রতি ব্যয় করলে সব দিক থেকে ঠিক থাকবে
# Sentence Type:  নিরপেক্ষ
#
# Data #160
# Raw Data:  এটা ঠিক আছে যতক্ষণ না আপনি জানেন, আপনি কি করছেন আপনার জীবনের প্রতি।
# Preprocess Data:  এটা ঠিক আছে যতক্ষণ না আপনি জানেন আপনি কি করছেন আপনার জীবনের প্রতি
# Sentence Type:  পজিটিভ
#
# Data #161
# Raw Data:  নিরপেক্ষ থাকা উচিৎ অনলাইন গেম খেলা নিয়ে।
# Preprocess Data:  নিরপেক্ষ থাকা উচিৎ অনলাইন গেম খেলা নিয়ে
# Sentence Type:  নিরপেক্ষ
#
# Data #162
# Raw Data:  আমি সবসময় গেম খেলা পছন্দ করি না, কিন্তু বিরক্তিকর সময় পার করি গেম খেলে।
# Preprocess Data:  আমি সবসময় গেম খেলা পছন্দ করি না কিন্তু বিরক্তিকর সময় পার করি গেম খেলে
# Sentence Type:  নিরপেক্ষ
#
# Data #163
# Raw Data:  গেম খেলা গুরুত্বপূর্ণ কিছুই না।
# Preprocess Data:  গেম খেলা গুরুত্বপূর্ণ কিছুই না
# Sentence Type:  নেগেটিভ
#
# Data #164
# Raw Data:  আমি কোন গেম খেলায় আগ্রহী নই।
# Preprocess Data:  আমি কোন গেম খেলায় আগ্রহী নই
# Sentence Type:  নেগেটিভ
#
# Data #165
# Raw Data:  অনলাইন গেম খেলা মূলত  সাময়িক মানষিক সুখ দেয়। কিন্তুু এটার ক্ষতিকর দিক প্রচুর। এই গেম খেলার ফলে অনেকে আসক্ত হয়ে পড়ে এবং  পড়াশুনোর প্রতি অমনোযোগী হয়ে পড়ে।
# Preprocess Data:  অনলাইন গেম খেলা মূলত সাময়িক মানষিক সুখ দেয় কিন্তুু এটার ক্ষতিকর দিক প্রচুর এই গেম খেলার ফলে অনেকে আসক্ত হয়ে পড়ে এবং পড়াশুনোর প্রতি অমনোযোগী হয়ে পড়ে
# Sentence Type:  নেগেটিভ
#
# Data #166
# Raw Data:  অনলাইন গেম খেলার ফলে অনেকে তাদের মানুষিক ভারসাম্যতাও হারাতে পারে।
# Preprocess Data:  অনলাইন গেম খেলার ফলে অনেকে তাদের মানুষিক ভারসাম্যতাও হারাতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #167
# Raw Data:  অনলাইন গেম খেলার প্রতি আগ্রহী নই।
# Preprocess Data:  অনলাইন গেম খেলার প্রতি আগ্রহী নই
# Sentence Type:  নেগেটিভ
#
# Data #168
# Raw Data:  মতামত দেওয়ার মতো ধারণা নাই অনলাইন গেম সম্পর্কে।
# Preprocess Data:  মতামত দেওয়ার মতো ধারণা নাই অনলাইন গেম সম্পর্কে
# Sentence Type:  নিরপেক্ষ
#
# Data #169
# Raw Data:  সময় নষ্ট করা ছাড়া কিছুই না, এইজন্য অনলাইন গেম না খেলাই ভালো।
# Preprocess Data:  সময় নষ্ট করা ছাড়া কিছুই না এইজন্য অনলাইন গেম না খেলাই ভালো
# Sentence Type:  নেগেটিভ
#
# Data #170
# Raw Data:  অনলাইন গেমটি একটি বিনোদন হিসাবে খেলা উচিত যদি না কেউ ই-খেলাধুলায় পেশাদার হয়। অন্যথায় এটি আমাদের দৈনন্দিন জীবনকে ব্যাহত করতে পারে।
# Preprocess Data:  অনলাইন গেমটি একটি বিনোদন হিসাবে খেলা উচিত যদি না কেউ ই খেলাধুলায় পেশাদার হয় অন্যথায় এটি আমাদের দৈনন্দিন জীবনকে ব্যাহত করতে পারে
# Sentence Type:  নিরপেক্ষ
#
# Data #171
# Raw Data:  প্রযুক্তির ভালো এবং খারাপ উভয় দিকই আছে। কিন্তু আমাদের নিজেদের নিয়ন্ত্রণ করার চাবিকাঠি রয়েছে। তাই অনলাইন গেম খেললে প্রতিক্রিয়া কেমন হতে পারে সেটা সম্পর্কে ধারণা থাকতে হবে।
# Preprocess Data:  প্রযুক্তির ভালো এবং খারাপ উভয় দিকই আছে কিন্তু আমাদের নিজেদের নিয়ন্ত্রণ করার চাবিকাঠি রয়েছে তাই অনলাইন গেম খেললে প্রতিক্রিয়া কেমন হতে পারে সেটা সম্পর্কে ধারণা থাকতে হবে
# Sentence Type:  নিরপেক্ষ
#
# Data #172
# Raw Data:  কিছু সময় কাটানোর জন্য অনলাইন গেম খেলা আকর্ষণীয় ব্যাপার বলে মনে হয়।
# Preprocess Data:  কিছু সময় কাটানোর জন্য অনলাইন গেম খেলা আকর্ষণীয় ব্যাপার বলে মনে হয়
# Sentence Type:  পজিটিভ
#
# Data #173
# Raw Data:  ভালো এবং খারাপ দুটো দিকই আছে অনলাইন গেম খেলায়।
# Preprocess Data:  ভালো এবং খারাপ দুটো দিকই আছে অনলাইন গেম খেলায়
# Sentence Type:  নিরপেক্ষ
#
# Data #174
# Raw Data:  আমি অনলাইন গেম খেলি না। সুতরাং, অনলাইন গেম সম্পর্কে আমার কোন মতামত নেই।
# Preprocess Data:  আমি অনলাইন গেম খেলি না সুতরাং অনলাইন গেম সম্পর্কে আমার কোন মতামত নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #175
# Raw Data:  অনলাইন গেম খেলা সুখী বোধ করার সেরা উপায়।
# Preprocess Data:  অনলাইন গেম খেলা সুখী বোধ করার সেরা উপায়
# Sentence Type:  পজিটিভ
#
# Data #176
# Raw Data:  অনলাইন গেমস আমাদের মধ্যে খুব একটা খারাপ প্রভাব ফেলেছে তা কিন্তু না। অনলাইন গেমসের পজেটিভ দিকটাও দেখা প্রয়োজন আমাদের।  অনলাইন গেমস খেলে এখন অনেকেই জীবিকার পথ বেঁচে নিয়েছে।
# Preprocess Data:  অনলাইন গেমস আমাদের মধ্যে খুব একটা খারাপ প্রভাব ফেলেছে তা কিন্তু না অনলাইন গেমসের পজেটিভ দিকটাও দেখা প্রয়োজন আমাদের অনলাইন গেমস খেলে এখন অনেকেই জীবিকার পথ বেঁচে নিয়েছে
# Sentence Type:  পজিটিভ
#
# Data #177
# Raw Data:  কখনও কখনও অনলাইন গেম খেলা মনকে সতেজ করার জন্য ভালো।
# Preprocess Data:  কখনও কখনও অনলাইন গেম খেলা মনকে সতেজ করার জন্য ভালো
# Sentence Type:  পজিটিভ
#
# Data #178
# Raw Data:  আপনি যদি অনলাইন গেম এর ভালো ব্যবহার করতে পারেন তবে এটি বিনোদনমূলক হতে পারে। কিন্তু আপনি যদি এটিতে আসক্ত হন তবে এটি খুব বিপজ্জনক।
# Preprocess Data:  আপনি যদি অনলাইন গেম এর ভালো ব্যবহার করতে পারেন তবে এটি বিনোদনমূলক হতে পারে কিন্তু আপনি যদি এটিতে আসক্ত হন তবে এটি খুব বিপজ্জনক
# Sentence Type:  নিরপেক্ষ
#
# Data #179
# Raw Data:  মন্তব্য নেই।
# Preprocess Data:  মন্তব্য নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #180
# Raw Data:  চিন্তাহীন ভাবে মানুষের এভাবে বেশিরভাগ সময় গেমে পড়ে থাকা সব দিক দিয়েই ধ্বংস ডেকে আনে।
# Preprocess Data:  চিন্তাহীন ভাবে মানুষের এভাবে বেশিরভাগ সময় গেমে পড়ে থাকা সব দিক দিয়েই ধ্বংস ডেকে আনে
# Sentence Type:  নেগেটিভ
#
# Data #181
# Raw Data:  সময়ের অপচয় ছাড়া আর কিছু না অনলাইন গেম খেলা।
# Preprocess Data:  সময়ের অপচয় ছাড়া আর কিছু না অনলাইন গেম খেলা
# Sentence Type:  নেগেটিভ
#
# Data #182
# Raw Data:  অনলাইন গেম না খেলাই ভালো।
# Preprocess Data:  অনলাইন গেম না খেলাই ভালো
# Sentence Type:  নেগেটিভ
#
# Data #183
# Raw Data:  অনলাইন গেমকে আপনি যেভাবে নিবেন তা আপনার লাইফে সেরকম ইফেক্টই ফেলবে।
# Preprocess Data:  অনলাইন গেমকে আপনি যেভাবে নিবেন তা আপনার লাইফে সেরকম ইফেক্টই ফেলবে
# Sentence Type:  নিরপেক্ষ
#
# Data #184
# Raw Data:  গেম খেলা মোটেও ভালো না।
# Preprocess Data:  গেম খেলা মোটেও ভালো না
# Sentence Type:  নেগেটিভ
#
# Data #185
# Raw Data:  সময় কাটানোর সবচেয়ে খারাপ জিনিস।
# Preprocess Data:  সময় কাটানোর সবচেয়ে খারাপ জিনিস
# Sentence Type:  নেগেটিভ
#
# Data #186
# Raw Data:  আপনি যদি আসক্ত হন তবে অনলাইন গেম খেলা খুব খারাপ। এছাড়া এটি স্বাভাবিক।
# Preprocess Data:  আপনি যদি আসক্ত হন তবে অনলাইন গেম খেলা খুব খারাপ এছাড়া এটি স্বাভাবিক
# Sentence Type:  নিরপেক্ষ
#
# Data #187
# Raw Data:  মাদক দ্রব্য সেবন করছি না। তাই আমি মনে করি  মাদক দ্রব্য গ্রহণ করার চেয়ে অনলাইন গেম খেলা ভালো।
# Preprocess Data:  মাদক দ্রব্য সেবন করছি না তাই আমি মনে করি মাদক দ্রব্য গ্রহণ করার চেয়ে অনলাইন গেম খেলা ভালো
# Sentence Type:  পজিটিভ
#
# Data #188
# Raw Data:  অনলাইনে গেম খেলা খারাপ অভ্যাস।
# Preprocess Data:  অনলাইনে গেম খেলা খারাপ অভ্যাস
# Sentence Type:  নেগেটিভ
#
# Data #189
# Raw Data:  আমার সবচেয়ে প্রিয় জিনিসটি হল গেমিং। গেম খেললে মন ভালো থাকে আমার।
# Preprocess Data:  আমার সবচেয়ে প্রিয় জিনিসটি হল গেমিং গেম খেললে মন ভালো থাকে আমার
# Sentence Type:  পজিটিভ
#
# Data #190
# Raw Data:  গেম খেলা খাারাপ অভ্যাস।
# Preprocess Data:  গেম খেলা খাারাপ অভ্যাস
# Sentence Type:  নেগেটিভ
#
# Data #191
# Raw Data:  অনলাইন গেম কাছের বন্ধুদের সাথে খেলা উচিত না, কেননা তাতে আসক্তিতে পড়ে যাওয়ার সম্ভাবনা বেশি থাকে।
# Preprocess Data:  অনলাইন গেম কাছের বন্ধুদের সাথে খেলা উচিত না কেননা তাতে আসক্তিতে পড়ে যাওয়ার সম্ভাবনা বেশি থাকে
# Sentence Type:  নেগেটিভ
#
# Data #192
# Raw Data:  নিজেকে নিয়ন্ত্রণ করা সবচেয়ে সুন্দর জিনিস। আমি বন্ধুদের সাথে গেম খেলতে ভালোবাসি। এর মানে এই নয় যে আমি ঘন্টার পর ঘন্টা গেম খেলব।
# Preprocess Data:  নিজেকে নিয়ন্ত্রণ করা সবচেয়ে সুন্দর জিনিস আমি বন্ধুদের সাথে গেম খেলতে ভালোবাসি এর মানে এই নয় যে আমি ঘন্টার পর ঘন্টা গেম খেলব
# Sentence Type:  পজিটিভ
#
# Data #193
# Raw Data:  অনলাইন গেম খেলা জরুরি বিষয় নয়। আনন্দ পেতে গেম খেলি।
# Preprocess Data:  অনলাইন গেম খেলা জরুরি বিষয় নয় আনন্দ পেতে গেম খেলি
# Sentence Type:  নিরপেক্ষ
#
# Data #194
# Raw Data:  অনলাইন গেম খেলা ভালো না। এতে শারীরিক অসুস্থতা হতে পারে।
# Preprocess Data:  অনলাইন গেম খেলা ভালো না এতে শারীরিক অসুস্থতা হতে পারে
# Sentence Type:  নেগেটিভ
#
# Data #195
# Raw Data:  গেম খেলা আপনাকে মানসিক চাপ কমাতে সাহায্য করে এবং আপনার বিশ্লেষণাত্মক দক্ষতাও বিকাশে সাহায্য করে।
# Preprocess Data:  গেম খেলা আপনাকে মানসিক চাপ কমাতে সাহায্য করে এবং আপনার বিশ্লেষণাত্মক দক্ষতাও বিকাশে সাহায্য করে
# Sentence Type:  পজিটিভ
#
# Data #196
# Raw Data:  শুধু বিনোদন এবং মজার জন্য অনলাইন গেম খেলি।
# Preprocess Data:  শুধু বিনোদন এবং মজার জন্য অনলাইন গেম খেলি
# Sentence Type:  নিরপেক্ষ
#
# Data #197
# Raw Data:  আমি মনে করি এটি শুধুমাত্র বিনোদন এবং কিছু সময় বিশ্রামের জন্য খেলা।
# Preprocess Data:  আমি মনে করি এটি শুধুমাত্র বিনোদন এবং কিছু সময় বিশ্রামের জন্য খেলা
# Sentence Type:  নিরপেক্ষ
#
# Data #198
# Raw Data:  চাইলেই অন গেম খেলা ছেড়ে দেওয়া যায় যেটা আমার কাছে মনে হয়ছে। মাঝেমধ্যে সময় কাটাতে অনলাইন গেম খেলি।
# Preprocess Data:  চাইলেই অন গেম খেলা ছেড়ে দেওয়া যায় যেটা আমার কাছে মনে হয়ছে মাঝেমধ্যে সময় কাটাতে অনলাইন গেম খেলি
# Sentence Type:  নিরপেক্ষ
#
# Data #199
# Raw Data:  অনলাইন গেম মানসিক শান্তি দেয়।
# Preprocess Data:  অনলাইন গেম মানসিক শান্তি দেয়
# Sentence Type:  পজিটিভ
#
# Data #200
# Raw Data:  বিরক্তিকর খেলা হচ্ছে অনলাইন গেম।
# Preprocess Data:  বিরক্তিকর খেলা হচ্ছে অনলাইন গেম
# Sentence Type:  নেগেটিভ
#
# Data #201
# Raw Data:  গেম একটি নির্দিষ্ট সময়ের জন্য আমাদের কিছু আনন্দ দেয় কিন্তু এটি আমাদের জন্য ভালো নয়। আজ এটা সব প্রজন্মের মানুষের জন্য, বিশেষ করে তরুণ প্রজন্মের জন্য বিপদ হয়ে উঠছে। তবুও অনেক মানুষ গেম খেলে তাদের মূল্যবান সময় নষ্ট করছে।
# Preprocess Data:  গেম একটি নির্দিষ্ট সময়ের জন্য আমাদের কিছু আনন্দ দেয় কিন্তু এটি আমাদের জন্য ভালো নয় আজ এটা সব প্রজন্মের মানুষের জন্য বিশেষ করে তরুণ প্রজন্মের জন্য বিপদ হয়ে উঠছে তবুও অনেক মানুষ গেম খেলে তাদের মূল্যবান সময় নষ্ট করছে
# Sentence Type:  নেগেটিভ
#
# Data #202
# Raw Data:  সময় কাটানোর ভালো মাধ্যম অনলাইন গেম খেলা যদি ইন্টারনেট ভালো থাকে। তবে আসক্তি খারাপ সেটা গেম হোক বা অন্য কিছু।
# Preprocess Data:  সময় কাটানোর ভালো মাধ্যম অনলাইন গেম খেলা যদি ইন্টারনেট ভালো থাকে তবে আসক্তি খারাপ সেটা গেম হোক বা অন্য কিছু
# Sentence Type:  নিরপেক্ষ
#
# Data #203
# Raw Data:  গেম খেলা আমাদের পরবর্তী প্রজন্মের জন্য খুবই খারাপ অভ্যাস হবে।
# Preprocess Data:  গেম খেলা আমাদের পরবর্তী প্রজন্মের জন্য খুবই খারাপ অভ্যাস হবে
# Sentence Type:  নেগেটিভ
#
# Data #204
# Raw Data:  অনলাইন গেমিং ভালো। তবে সবসময়ই অনলাইন গেম খেলা খুব একটা ভালো হয় না। প্রত্যেকের এটি খেলার কিছু সীমা থাকা উচিত।
# Preprocess Data:  অনলাইন গেমিং ভালো তবে সবসময়ই অনলাইন গেম খেলা খুব একটা ভালো হয় না প্রত্যেকের এটি খেলার কিছু সীমা থাকা উচিত
# Sentence Type:  নিরপেক্ষ
#
# Data #205
# Raw Data:  অনলাইন গেমটি খুবই খারাপ কারণ এতে আমাদের মূল্যবান সময় নষ্ট হয়।
# Preprocess Data:  অনলাইন গেমটি খুবই খারাপ কারণ এতে আমাদের মূল্যবান সময় নষ্ট হয়
# Sentence Type:  নেগেটিভ
#
# Data #206
# Raw Data:  কখনো ভালো আবার কখনো খারাপ।
# Preprocess Data:  কখনো ভালো আবার কখনো খারাপ
# Sentence Type:  নিরপেক্ষ
#
# Data #207
# Raw Data:  ধারণা নেই অনলাইন গেম সম্পর্কে।
# Preprocess Data:  ধারণা নেই অনলাইন গেম সম্পর্কে
# Sentence Type:  নিরপেক্ষ
#
# Data #208
# Raw Data:  অনলাইন গেম ভালো, আমি এ পর্যন্ত মনে করি.
# Preprocess Data:  অনলাইন গেম ভালো আমি এ পর্যন্ত মনে করি
# Sentence Type:  পজিটিভ
#
# Data #209
# Raw Data:  যতক্ষণ না অবধি অনলাইন গেম  আপনাকে নিয়ন্ত্রণ করে ততক্ষণ ক্ষতিকারক নয়।
# Preprocess Data:  যতক্ষণ না অবধি অনলাইন গেম আপনাকে নিয়ন্ত্রণ করে ততক্ষণ ক্ষতিকারক নয়
# Sentence Type:  নিরপেক্ষ
#
# Data #210
# Raw Data:  আমি খেলি না কারণ এটা আমাদের দৈনন্দিন জীবনকে ধ্বংস করে দেয়।
# Preprocess Data:  আমি খেলি না কারণ এটা আমাদের দৈনন্দিন জীবনকে ধ্বংস করে দেয়
# Sentence Type:  নেগেটিভ
#
# Data #211
# Raw Data:  মাঝে মাঝে আমি অনলাইন গেম খেলি। তবে সবসময় না।
# Preprocess Data:  মাঝে মাঝে আমি অনলাইন গেম খেলি তবে সবসময় না
# Sentence Type:  নিরপেক্ষ
#
# Data #212
# Raw Data:  অনলাইন গেম খেলা খুবই ক্ষতিকর।
# Preprocess Data:  অনলাইন গেম খেলা খুবই ক্ষতিকর
# Sentence Type:  নেগেটিভ
#
# Data #213
# Raw Data:  অবসর সময় কাটানো যায় অনলাইন গেম খেলে।
# Preprocess Data:  অবসর সময় কাটানো যায় অনলাইন গেম খেলে
# Sentence Type:  পজিটিভ
#
# Data #214
# Raw Data:  মন্তব্য কিছুই নেই।
# Preprocess Data:  মন্তব্য কিছুই নেই
# Sentence Type:  নিরপেক্ষ
#
# Data #215
# Raw Data:  বিনোদনের জন্য মাঝে মধ্যে অনলাইন গেম খেলে থাকি।
# Preprocess Data:  বিনোদনের জন্য মাঝে মধ্যে অনলাইন গেম খেলে থাকি
# Sentence Type:  পজিটিভ
#
# Data #216
# Raw Data:  অনলাইন গেম খুবই খারাপ। এতে আমাদের মূল্যবান সময় নষ্ট হয়। আমি জানি অনলাইন গেম খারাপ।
# Preprocess Data:  অনলাইন গেম খুবই খারাপ এতে আমাদের মূল্যবান সময় নষ্ট হয় আমি জানি অনলাইন গেম খারাপ
# Sentence Type:  নেগেটিভ
#
# Data #217
# Raw Data:  এটা মানুষকে মানসিকভাবে অনেক ক্ষতি করে। যার ফলে কোন কাজে মন বসে না।
# Preprocess Data:  এটা মানুষকে মানসিকভাবে অনেক ক্ষতি করে যার ফলে কোন কাজে মন বসে না
# Sentence Type:  নেগেটিভ
#
# Data #218
# Raw Data:  সময় কাটানোর জন্য অনলাইন গেম একটি খুব ভাল মাধ্যম। কিন্তু দিনে দিনে এটিতে মানুষ আসক্ত হয়।  সতেজতা এবং আসক্তির মধ্যে পার্থক্যটি বোঝার জন্য অনলাইন গেম উদাহরণ হিসেবে গন্য করা যায়।
# Preprocess Data:  সময় কাটানোর জন্য অনলাইন গেম একটি খুব ভাল মাধ্যম কিন্তু দিনে দিনে এটিতে মানুষ আসক্ত হয় সতেজতা এবং আসক্তির মধ্যে পার্থক্যটি বোঝার জন্য অনলাইন গেম উদাহরণ হিসেবে গন্য করা যায়
# Sentence Type:  নিরপেক্ষ
#
# Data #219
# Raw Data:  সময় অতিবাহিত করার মাধ্যম।
# Preprocess Data:  সময় অতিবাহিত করার মাধ্যম
# Sentence Type:  নিরপেক্ষ
#
# Data #220
# Raw Data:  অনলাইন গেমের ফলে একজন মানুষ তার সঠিক মানসিকতা বিকাশ ঘটাতে পারে না।
# Preprocess Data:  অনলাইন গেমের ফলে একজন মানুষ তার সঠিক মানসিকতা বিকাশ ঘটাতে পারে না
# Sentence Type:  নেগেটিভ
#
# Data #221
# Raw Data:  অনলাইন গেম খেলতে আমার ভালো লাগে।
# Preprocess Data:  অনলাইন গেম খেলতে আমার ভালো লাগে
# Sentence Type:  পজিটিভ
#
# Data #222
# Raw Data:  মূলত আমাদের এটির প্রয়োজন নেই। কেননা এটি কেবল সময়ের অপচয় করে।
# Preprocess Data:  মূলত আমাদের এটির প্রয়োজন নেই কেননা এটি কেবল সময়ের অপচয় করে
# Sentence Type:  নেগেটিভ
#
# Data #223
# Raw Data:  সময়,নষ্ট হয় অনলাইন গেম খেলে।
# Preprocess Data:  সময় নষ্ট হয় অনলাইন গেম খেলে
# Sentence Type:  নেগেটিভ
#
# Data #224
# Raw Data:  অনলাইন গেম খেলা বর্তমান যুব সমাজের জন্য ক্ষতিকারক দিক।
# Preprocess Data:  অনলাইন গেম খেলা বর্তমান যুব সমাজের জন্য ক্ষতিকারক দিক
# Sentence Type:  নেগেটিভ
#
# Data #225
# Raw Data:  এটা সরকারি ভাবে বন্ধ করা উচিত। এটা শিক্ষার্থীদের লেখা পড়া ধ্বংস করছে এবং এই গেমস জাতিকে পঙ্গু করে ফেলছে।
# Preprocess Data:  এটা সরকারি ভাবে বন্ধ করা উচিত এটা শিক্ষার্থীদের লেখা পড়া ধ্বংস করছে এবং এই গেমস জাতিকে পঙ্গু করে ফেলছে
# Sentence Type:  নেগেটিভ
#
# Data #226
# Raw Data:  আমি অনলাইন গেম অধিক সময়  ধরে কখনো খেলি নাই।আর অধিক  সময় গেমের মধ্যে থাকলে বিভিন্ন  ধরনের সমস্যার সম্মুখীন হতে হয়। সেটা ছাত্র/ ছাত্রী  থেকে শুরু করে সকল পেশার মানুষের  উপরে খারাপ প্রভাব পড়তে পারে। ফলে অনেক বড় ধরনের সমস্যার পড়তে হয়।
# Preprocess Data:  আমি অনলাইন গেম অধিক সময় ধরে কখনো খেলি নাই আর অধিক সময় গেমের মধ্যে থাকলে বিভিন্ন ধরনের সমস্যার সম্মুখীন হতে হয় সেটা ছাত্র ছাত্রী থেকে শুরু করে সকল পেশার মানুষের উপরে খারাপ প্রভাব পড়তে পারে ফলে অনেক বড় ধরনের সমস্যার পড়তে হয়
# Sentence Type:  নিরপেক্ষ
#
# Data #227
# Raw Data:  প্রত্যাহিক জীবনের মূল্যবান সময়কে নষ্ট করে ফেলে।
# Preprocess Data:  প্রত্যাহিক জীবনের মূল্যবান সময়কে নষ্ট করে ফেলে
# Sentence Type:  নেগেটিভ
#
# Data #228
# Raw Data:  কিছুই বলার নাই।
# Preprocess Data:  কিছুই বলার নাই
# Sentence Type:  নিরপেক্ষ
#
# Data #229
# Raw Data:  আমি ভালো মানসিক স্বাস্থ্যের জন্য অনলাইন গেম খেলি না।
# Preprocess Data:  আমি ভালো মানসিক স্বাস্থ্যের জন্য অনলাইন গেম খেলি না
# Sentence Type:  নেগেটিভ
#
# Data #230
# Raw Data:  অনলাইন গেম খেলা  ভালো না।
# Preprocess Data:  অনলাইন গেম খেলা ভালো না
# Sentence Type:  নেগেটিভ
#
# Data #231
# Raw Data:  আমাদের মূল্যবান সময় বাঁচানোর জন্য অনলাইন গেম এড়ানো উচিত।
# Preprocess Data:  আমাদের মূল্যবান সময় বাঁচানোর জন্য অনলাইন গেম এড়ানো উচিত
# Sentence Type:  নেগেটিভ
#
# Data #232
# Raw Data:  অনলাইন গেম খুবই সময়সাপেক্ষ। তাই এটা আমাদের খেলা উচিত না বলে মনে করি।
# Preprocess Data:  অনলাইন গেম খুবই সময়সাপেক্ষ তাই এটা আমাদের খেলা উচিত না বলে মনে করি
# Sentence Type:  নেগেটিভ
#
# Data #233
# Raw Data:  মাঝে মাঝে আমি টাইম পাসের জন্য খেলি। কিন্তু আমার মনে হয় আপনি যদি নিয়মিত খেলেন তাহলে আপনি আসক্ত হবেন। আর এটা খেলা কোনো মানুষের জন্যই ভালো নয়।
# Preprocess Data:  মাঝে মাঝে আমি টাইম পাসের জন্য খেলি কিন্তু আমার মনে হয় আপনি যদি নিয়মিত খেলেন তাহলে আপনি আসক্ত হবেন আর এটা খেলা কোনো মানুষের জন্যই ভালো নয়
# Sentence Type:  নেগেটিভ
#
# Data #234
# Raw Data:  অনলাইন গেম না খেলাই ভালো বলে আমার ধারণা।
# Preprocess Data:  অনলাইন গেম না খেলাই ভালো বলে আমার ধারণা
# Sentence Type:  নেগেটিভ
#
# Data #235
# Raw Data:  অনলাইন গেম খেলা বিশেষ করে ছাত্রদের জন্য খারাপ অভ্যাস।
# Preprocess Data:  অনলাইন গেম খেলা বিশেষ করে ছাত্রদের জন্য খারাপ অভ্যাস
# Sentence Type:  নেগেটিভ
#
# Data #236
# Raw Data:  ছোটবেলায় থেকে আমি খুব বেশি গেম খেলতাম। এর পরে আমি ভেবেছিলাম আমি একটি গেম বানাতে চেষ্টা করতে পারি। যার ফলে কিছুটা হলেও শিখতে পেরেছি।
# Preprocess Data:  ছোটবেলায় থেকে আমি খুব বেশি গেম খেলতাম এর পরে আমি ভেবেছিলাম আমি একটি গেম বানাতে চেষ্টা করতে পারি যার ফলে কিছুটা হলেও শিখতে পেরেছি
# Sentence Type:  পজিটিভ

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
encoder = LabelEncoder()
y1 = encoder.fit_transform(df['class'])

# %%
for i in range(10):
  print("class: ",df['class'][i])
  print("Encoder Value: ", y1[i])
# Out:
# class:  নিরপেক্ষ
# Encoder Value:  0
# class:  নিরপেক্ষ
# Encoder Value:  0
# class:  নেগেটিভ
# Encoder Value:  1
# class:  নিরপেক্ষ
# Encoder Value:  0
# class:  পজিটিভ
# Encoder Value:  2
# class:  নিরপেক্ষ
# Encoder Value:  0
# class:  পজিটিভ
# Encoder Value:  2
# class:  পজিটিভ
# Encoder Value:  2
# class:  নেগেটিভ
# Encoder Value:  1
# class:  নিরপেক্ষ
# Encoder Value:  0

# %%
cv = CountVectorizer(max_features=1500, ngram_range=(1,3))
x = cv.fit_transform(clear_text2).toarray()
x.shape
# Out:
# (401, 1500)

# %%
cv.get_feature_names()[0:-1]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['অক',
#  'অগ',
#  'অত',
#  'অত আম',
#  'অত আসক',
#  'অত কর',
#  'অত কর যম',
#  'অত জন',
#  'অত রম',
#  'অথব',
#  'অধ',
#  'অধ সময়',
#  'অন',
#  'অন কট',
#  'অন কর',
#  'অন ঘন',
#  'অন ঘন যয',
#  'অন বড',
#  'অন ভব',
#  'অন ভব কর',
#  'অন যথ',
#  'অন রত',
#  'অন সময',
#  'অন সময নষ',
#  'অনল',
#  'অনল ইন',
#  'অনল ইন অন',
#  'অনল ইন অবসর',
#  'অনল ইন অভ',
#  'অনল ইন আছ',
#  'অনল ইন আপন',
#  'অনল ইন আম',
#  'অনল ইন আসক',
#  'অনল ইন উচ',
#  'অনল ইন এক',
#  'অনল ইন একট',
#  'অনল ইন এড',
#  'অনল ইন এর',
#  'অনল ইন কখন',
#  'অনল ইন কর',
#  'অনল ইন জন',
#  'অনল ইন তব',
#  'অনল ইন তর',
#  'অনল ইন দন',
#  'অনল ইন দরক',
#  'অনল ইন নস',
#  'অনল ইন পছন',
#  'অনল ইন ফল',
#  'অনল ইন বই',
#  'অনল ইন বন',
#  'অনল ইন বল',
#  'অনল ইন মগ',
#  'অনল ইন মট',
#  'অনল ইন মস',
#  'অনল ইন যদ',
#  'অনল ইন রত',
#  'অনল ইন রদ',
#  'অনল ইন লত',
#  'অনল ইন লব',
#  'অনল ইন লল',
#  'অনল ইন ষক',
#  'অনল ইন ষত',
#  'অনল ইন সত',
#  'অনল ইন সম',
#  'অনল ইন সময',
#  'অনল ইন সময়',
#  'অনল ইন হচ',
#  'অপ',
#  'অপচয',
#  'অপচয আর',
#  'অপচয আর অনল',
#  'অপচয এব',
#  'অপচয কর',
#  'অপচয়',
#  'অপচয় কর',
#  'অপচয় হয়',
#  'অপন',
#  'অপন টস',
#  'অপর',
#  'অবক',
#  'অবশ',
#  'অবশ যই',
#  'অবস',
#  'অবস রস',
#  'অবসর',
#  'অবসর সময',
#  'অবসর সময জন',
#  'অবসর সময়',
#  'অভ',
#  'অভ ঞত',
#  'অভ পর',
#  'অভ পর নত',
#  'অমন',
#  'অমন হয়',
#  'অযথ',
#  'অর',
#  'অর উপ',
#  'অর উপ জন',
#  'অর জন',
#  'অর যয',
#  'অলস',
#  'অলস সময়',
#  'অস',
#  'অস কর',
#  'আক',
#  'আগ',
#  'আগ রহ',
#  'আগ রহ নই',
#  'আচ',
#  'আছ',
#  'আছ অনল',
#  'আছ অনল ইন',
#  'আন',
#  'আনন',
#  'আনন এব',
#  'আপন',
#  'আপন আপন',
#  'আপন আসক',
#  'আপন বন',
#  'আপন মন',
#  'আপন যখন',
#  'আপন যদ',
#  'আপন রত',
#  'আপন সময',
#  'আব',
#  'আব কখন',
#  'আম',
#  'আম অন',
#  'আম অনল',
#  'আম অনল ইন',
#  'আম অবসর',
#  'আম অবসর সময',
#  'আম আগ',
#  'আম আগ রহ',
#  'আম আনন',
#  'আম আম',
#  'আম ইম',
#  'আম ইম জন',
#  'আম উচ',
#  'আম একট',
#  'আম এট',
#  'আম কর',
#  'আম জন',
#  'আম জন ষত',
#  'আম তর',
#  'আম দন',
#  'আম নন',
#  'আম নন বনক',
#  'আম নস',
#  'আম নস কভ',
#  'আম পছন',
#  'আম পছন কর',
#  'আম পড',
#  'আম পর',
#  'আম পর যন',
#  'আম বন',
#  'আম বন একট',
#  'আম বপ',
#  'আম মত',
#  'আম মত মত',
#  'আম মন',
#  'আম মন কর',
#  'আম মন তব',
#  'আম মন হয',
#  'আম মস',
#  'আম মস কর',
#  'আম যক',
#  'আম যব',
#  'আম যব সময',
#  'আম রক',
#  'আম রক কর',
#  'আম রণ',
#  'আম সবসময',
#  'আম সম',
#  'আম সময',
#  'আমর',
#  'আর',
#  'আর অনল',
#  'আর অনল ইন',
#  'আর যদ',
#  'আরও',
#  'আল',
#  'আস',
#  'আসক',
#  'আসক এর',
#  'আসক চল',
#  'আসক জন',
#  'আসক পর',
#  'আসক হওয',
#  'আসক হওয়',
#  'আসক হন',
#  'আসক হন তব',
#  'আসক হয',
#  'আসক হয়',
#  'আসত',
#  'আসব',
#  'ইচ',
#  'ইচ হল',
#  'ইত',
#  'ইত চক',
#  'ইত চক বল',
#  'ইন',
#  'ইন অন',
#  'ইন অন সময',
#  'ইন অবসর',
#  'ইন অবসর সময',
#  'ইন অভ',
#  'ইন আছ',
#  'ইন আপন',
#  'ইন আম',
#  'ইন আম জন',
#  'ইন আম বন',
#  'ইন আম রক',
#  'ইন আসক',
#  'ইন উচ',
#  'ইন উচ নয',
#  'ইন এক',
#  'ইন একট',
#  'ইন এড',
#  'ইন এড চলত',
#  'ইন এর',
#  'ইন এর রত',
#  'ইন কখন',
#  'ইন কর',
#  'ইন জন',
#  'ইন জন ষত',
#  'ইন তব',
#  'ইন তর',
#  'ইন দন',
#  'ইন দরক',
#  'ইন নস',
#  'ইন নস জন',
#  'ইন পছন',
#  'ইন পছন কর',
#  'ইন ফল',
#  'ইন বই',
#  'ইন বন',
#  'ইন বল',
#  'ইন বল আম',
#  'ইন মগ',
#  'ইন মট',
#  'ইন মস',
#  'ইন মস এখন',
#  'ইন যদ',
#  'ইন রত',
#  'ইন রদ',
#  'ইন রন',
#  'ইন লত',
#  'ইন লব',
#  'ইন লল',
#  'ইন ষক',
#  'ইন ষত',
#  'ইন সত',
#  'ইন সম',
#  'ইন সম পর',
#  'ইন সময',
#  'ইন সময নয',
#  'ইন সময নষ',
#  'ইন সময়',
#  'ইন সময় নষ',
#  'ইন হচ',
#  'ইনক',
#  'ইফ',
#  'ইম',
#  'ইম জন',
#  'ইর',
#  'ইল',
#  'উচ',
#  'উচ অনল',
#  'উচ অনল ইন',
#  'উচ আম',
#  'উচ এট',
#  'উচ নয',
#  'উচ নয হল',
#  'উট',
#  'উঠ',
#  'উদ',
#  'উদ হরণ',
#  'উন',
#  'উন নত',
#  'উন নত করত',
#  'উপ',
#  'উপ জন',
#  'উপ জন কর',
#  'উপক',
#  'উপভ',
#  'উপর',
#  'উপর রভ',
#  'উভয',
#  'উৎস',
#  'এই',
#  'এই ধরন',
#  'এই মগ',
#  'এই মস',
#  'এক',
#  'এক কল',
#  'এক ধরন',
#  'একজন',
#  'একজন যক',
#  'একজন যক অস',
#  'একজন যক মস',
#  'একজন হত',
#  'একট',
#  'একট অন',
#  'একট অপর',
#  'একট অভ',
#  'একট উপ',
#  'একট টফর',
#  'একট দন',
#  'একট নস',
#  'একট পর',
#  'একট বল',
#  'একট যম',
#  'একট রভ',
#  'একট সময়',
#  'একব',
#  'এখ',
#  'এখন',
#  'এখন অন',
#  'এগ',
#  'এগ হয়',
#  'এছ',
#  'এছ এট',
#  'এট',
#  'এট আছ',
#  'এট আপন',
#  'এট আম',
#  'এট আম জন',
#  'এট আম নন',
#  'এট আম যব',
#  'এট আসক',
#  'এট এক',
#  'এট একজন',
#  'এট একজন যক',
#  'এট একট',
#  'এট জন',
#  'এট তখন',
#  'এট তব',
#  'এট দন',
#  'এট দন একট',
#  'এট পজ',
#  'এট পজ জনক',
#  'এট পড়',
#  'এট মস',
#  'এট যদ',
#  'এট ষক',
#  'এট ষত',
#  'এট ষত কর',
#  'এট সময',
#  'এট সল',
#  'এড',
#  'এড চলত',
#  'এড চলত হব',
#  'এত',
#  'এত আপন',
#  'এত আম',
#  'এত আম যব',
#  'এত সময়',
#  'এব',
#  'এব অন',
#  'এব আর',
#  'এব এট',
#  'এব দক',
#  'এব দক ষত',
#  'এব নস',
#  'এব মস',
#  'এব সময',
#  'এমন',
#  'এমন একট',
#  'এমনক',
#  'এর',
#  'এর অন',
#  'এর এই',
#  'এর জন',
#  'এর জন একট',
#  'এর তর',
#  'এর ফল',
#  'এর মত',
#  'এর মন',
#  'এর মন সম',
#  'এর যম',
#  'এর রত',
#  'এর রত আসক',
#  'এর ষত',
#  'এর ষত কর',
#  'এসব',
#  'ওয',
#  'ওয উচ',
#  'ওয উচ নয',
#  'ওয়',
#  'ওয় উচ',
#  'ওয় হয়',
#  'ওয় হয় তব',
#  'কই',
#  'কই আছ',
#  'কক',
#  'কখন',
#  'কখন আব',
#  'কখন আব কখন',
#  'কখনই',
#  'কখনও',
#  'কখনও কখনও',
#  'কট',
#  'কত',
#  'কত হব',
#  'কথ',
#  'কথ নয়',
#  'কথ নয় যদ',
#  'কদ',
#  'কদ জন',
#  'কন',
#  'কনস',
#  'কভ',
#  'কম',
#  'কম উট',
#  'কর',
#  'কর অত',
#  'কর অত আম',
#  'কর অন',
#  'কর অনল',
#  'কর অনল ইন',
#  'কর আম',
#  'কর আর',
#  'কর উচ',
#  'কর উদ',
#  'কর এই',
#  'কর এই মস',
#  'কর একট',
#  'কর এট',
#  'কর এব',
#  'কর এব এট',
#  'কর এর',
#  'কর এর ষত',
#  'কর কর',
#  'কর জন',
#  'কর ততক',
#  'কর ততক ষণ',
#  'কর তব',
#  'কর তব এট',
#  'কর নয',
#  'কর পর',
#  'কর মক',
#  'কর মক ষমত',
#  'কর মন',
#  'কর যম',
#  'কর রণ',
#  'কর রভ',
#  'কর লত',
#  'কর সব',
#  'কর সম',
#  'কর সময',
#  'কর সময়',
#  'কর হয',
#  'করছ',
#  'করছ এব',
#  'করণ',
#  'করত',
#  'করত এব',
#  'করত করত',
#  'করত করব',
#  'করত সহ',
#  'করত সহ কর',
#  'করব',
#  'করব যদ',
#  'করল',
#  'কল',
#  'কল উপ',
#  'কল ধরন',
#  'কশন',
#  'খত',
#  'খত হব',
#  'খল',
#  'গত',
#  'গতভ',
#  'গব',
#  'গব ষণ',
#  'ঘণ',
#  'ঘন',
#  'ঘন যয',
#  'ঘন যয কর',
#  'চক',
#  'চক বল',
#  'চক বল মন',
#  'চক রভ',
#  'চমৎক',
#  'চর',
#  'চল',
#  'চল আস',
#  'চলত',
#  'চলত হব',
#  'জগত',
#  'জত',
#  'জত জন',
#  'জত জন অনল',
#  'জন',
#  'জন অনল',
#  'জন অনল ইন',
#  'জন আপন',
#  'জন আম',
#  'জন এক',
#  'জন একট',
#  'জন একট পর',
#  'জন এব',
#  'জন কর',
#  'জন নন',
#  'জন নয',
#  'জন পড়',
#  'জন বই',
#  'জন বল',
#  'জন যও',
#  'জন যও ষত',
#  'জন রচ',
#  'জন ষত',
#  'জন ষত কর',
#  'জন ষত রক',
#  'জন সমস',
#  'জন সময়',
#  'জন হল',
#  'জনক',
#  'জনপ',
#  'জনশ',
#  'জনশ লত',
#  'জনশ লত অনল',
#  'জর',
#  'জল',
#  'ঞত',
#  'টফর',
#  'টব',
#  'টবল',
#  'টর',
#  'টস',
#  'ণত',
#  'তখন',
#  'তখন আপন',
#  'তখন আম',
#  'তখন এট',
#  'তত',
#  'ততক',
#  'ততক ষণ',
#  'তন',
#  'তব',
#  'তব অনল',
#  'তব অনল ইন',
#  'তব আপন',
#  'তব আসক',
#  'তব এট',
#  'তব এট পজ',
#  'তব বন',
#  'তবয',
#  'তবয কদ',
#  'তবয কদ জন',
#  'তম',
#  'তর',
#  'তর অন',
#  'তর রজন',
#  'তর রজন জন',
#  'থত',
#  'দক',
#  'দক রব',
#  'দক ষত',
#  'দক ষত উন',
#  'দক ষত কর',
#  'দন',
#  'দন একট',
#  'দন একট উপ',
#  'দন একট যম',
#  'দন এব',
#  'দন এব সময',
#  'দন এর',
#  'দন জন',
#  'দন জন অনল',
#  'দনম',
#  'দনম লক',
#  'দরক',
#  'দরক আর',
#  'দরক আর যব',
#  'দরক আস',
#  'দরক দন',
#  'দরক দন এর',
#  'দল',
#  'দল অনল',
#  'দল অনল ইন',
#  'দল কর',
#  'দল কর এব',
#  'দল হয',
#  'দল হয নও',
#  'দলগত',
#  'দলগত অভ',
#  'দলগত অভ ঞত',
#  'দলবদ',
#  'দলবদ দক',
#  'দলবদ দক ষত',
#  'ধক',
#  'ধক পত',
#  'ধক পত হত',
#  'ধণ',
#  'ধণ কর',
#  'ধত',
#  'ধত অন',
#  'ধত অন হল',
#  'ধত উচ',
#  'ধত সবসময',
#  'ধত সবসময ষত',
#  'ধন',
#  'ধন কর',
#  'ধর',
#  'ধর কখন',
#  'ধর কখন আর',
#  'ধরণ',
#  'ধরণ নস',
#  'ধরণ নস এর',
#  'ধরন',
#  'ধরন অনল',
#  'ধরন অনল ইন',
#  'ধরন ওষ',
#  'ধরন কর',
#  'ধরন কর কর',
#  'ধরন বন',
#  'ধরন বন আন',
#  'ধরন বন কখন',
#  'ধরন বন চল',
#  'ধরন মস',
#  'ধরন মস ধরন',
#  'ধরন লছ',
#  'ধরন লছ অনল',
#  'ধরন সমস',
#  'ধরন সমস পড়ত',
#  'ধরন সমস সম',
#  'নই',
#  'নই অনল',
#  'নই অনল ইন',
#  'নই আম',
#  'নই আম অনল',
#  'নই আম মন',
#  'নও',
#  'নও কথ',
#  'নও কথ হয',
#  'নও তরগ',
#  'নও তরগ অত',
#  'নও যক',
#  'নও যক আসক',
#  'নও রহণ',
#  'নও রহণ শগ',
#  'নজর',
#  'নজর হব',
#  'নজর হব উদ',
#  'নত',
#  'নত আম',
#  'নত আম জন',
#  'নত এব',
#  'নত এব অন',
#  'নত কর',
#  'নত কর দন',
#  'নত করত',
#  'নত করত কর',
#  'নন',
#  'নন এত',
#  'নন এত সময়',
#  'নন বনক',
#  'নন বনক হত',
#  'নন লল',
#  'নন লল মস',
#  'নয',
#  'নয আজ',
#  'নয আজ এট',
#  'নয আব',
#  'নয আব অন',
#  'নয আম',
#  'নয আম ঘন',
#  'নয আম মন',
#  'নয আর',
#  'নয আর কর',
#  'নয এট',
#  'নয এট একজন',
#  'নয এট মস',
#  'নয তব',
#  'নয তব আসক',
#  'নয তবয',
#  'নয তবয এব',
#  'নয দক',
#  'নয হল',
#  'নর',
#  'নশন',
#  'নশন কম',
#  'নশন কম এব',
#  'নশন রণ',
#  'নশন রণ যদ',
#  'নষ',
#  'নষ এগ',
#  'নষ এগ হয়',
#  'নষ এট',
#  'নষ এট ষত',
#  'নষ এল',
#  'নষ এল বল',
#  'নষ কর',
#  'নষ কর অন',
#  'নষ কর অনল',
#  'নষ কর অল',
#  'নষ কর আম',
#  'নষ কর আর',
#  'নষ কর উচ',
#  'নষ কর উদ',
#  'নষ কর এইজন',
#  'নষ কর এট',
#  'নষ কর এব',
#  'নষ কর এমনক',
#  'নষ কর বজ',
#  'নষ কর বন',
#  'নষ কর মন',
#  'নষ কর রভ',
#  'নষ করছ',
#  'নষ করছ এব',
#  'নষ করছ তখন',
#  'নষ করত',
#  'নষ করব',
#  'নষ নস',
#  'নষ নস অবস',
#  'নষ পড়',
#  'নষ পড় নষ',
#  'নষ বন',
#  'নষ বন গঠন',
#  'নষ হচ',
#  'নষ হচ পড়',
#  'নষ হয',
#  'নষ হয আম',
#  'নষ হয়',
#  'নষ হয় অনল',
#  'নস',
#  'নস অন',
#  'নস অন কম',
#  'নস অবস',
#  'নস অবস উপর',
#  'নস আক',
#  'নস আক রমণ',
#  'নস উভয',
#  'নস উভয সমস',
#  'নস এব',
#  'নস এব হওয',
#  'নস এর',
#  'নস এর জন',
#  'নস এর মত',
#  'নস কত',
#  'নস কত আচ',
#  'নস কত খত',
#  'নস কত ঘট',
#  'নস কত নষ',
#  'নস কভ',
#  'নস কভ অন',
#  'নস কভ রভ',
#  'নস কভ সক',
#  'নস কম',
#  'নস কম কর',
#  'নস জন',
#  'নস জন অনল',
#  'নস জন ষত',
#  'নস দক',
#  'নস দক ষত',
#  'নস বল',
#  'নস বল আম',
#  'নস রশ',
#  'নস রশ ওয়',
#  'নস রশ জন',
#  'নস সবচ',
#  'নস সবচ বপ',
#  'নস সমস',
#  'নস সমস আর',
#  'নস সমস হচ',
#  'নস সমস হত',
#  'নস সমস হয',
#  'নস সমস হয়',
#  'নস হওয়',
#  'নস হওয় অন',
#  'নস হত',
#  'নস হত নস',
#  'নয়',
#  'নয় আনন',
#  'নয় যদ',
#  'নয় যদ আসক',
#  'পক',
#  'পক তব',
#  'পক তব দন',
#  'পঙ',
#  'পঙ কর',
#  'পঙ কর লছ',
#  'পছন',
#  'পছন কর',
#  'পছন কর এট',
#  'পছন কর এর',
#  'পছন কর নন',
#  'পছন কর যখন',
#  'পছন কর রক',
#  'পছন রস',
#  'পছন রস বজ',
#  'পজ',
#  'পজ কট',
#  'পজ কট রয়',
#  'পজ জনক',
#  'পজ জনক হত',
#  'পজ জনক হব',
#  'পড',
#  'পড তখন',
#  'পড তখন আমর',
#  'পড রভ',
#  'পড রভ পড়',
#  'পত',
#  'পত হত',
#  'পথ',
#  'পথ কর',
#  'পদ',
#  'পদ এব',
#  'পদ এব মস',
#  'পদ এব য়ম',
#  'পদ শল',
#  'পদ শল খত',
#  'পদ হয',
#  'পদ হয উঠছ',
#  'পদজনক',
#  'পদজনক হত',
#  'পভ',
#  'পভ রয়',
#  'পর',
#  'পর অনল',
#  'পর অনল ইন',
#  'পর আম',
#  'পর আম আম',
#  'পর আম মত',
#  'পর আম মন',
#  'পর এব',
#  'পর এব রত',
#  'পর কক',
#  'পর কক কর',
#  'পর কর',
#  'পর কর মত',
#  'পর ঘণ',
#  'পর ঘণ যব',
#  'পর ঘন',
#  'পর ঘন লব',
#  'পর চর',
#  'পর চর রগ',
#  'পর ণত',
#  'পর ণত ঘটত',
#  'পর ণত হয',
#  'পর ণত হয়',
#  'পর তভ',
#  'পর তভ অনল',
#  'পর তর',
#  'পর তর মন',
#  'পর দন',
#  'পর দন জন',
#  'পর নত',
#  'পর নত কর',
#  'পর নত হয়',
#  'পর নস',
#  'পর নস কত',
#  'পর পদ',
#  'পর পদ এব',
#  'পর পর',
#  'পর পর বর',
#  'পর বর',
#  'পর বর তন',
#  'পর মন',
#  'পর মন অভ',
#  'পর মন তব',
#  'পর মর',
#  'পর মর গতভ',
#  'পর যন',
#  'পর রণ',
#  'পর সচ',
#  'পর সচ তন',
#  'পড়',
#  'পড় একট',
#  'পড়ত',
#  'ফল',
#  'ফল অন',
#  'ফল পর',
#  'বই',
#  'বই অভ',
#  'বই ষত',
#  'বই ষত কর',
#  'বক',
#  'বজ',
#  'বজ এব',
#  'বজ মত',
#  'বজ মত অনল',
#  'বট',
#  'বড',
#  'বদ',
#  'বদ ধত',
#  'বন',
#  'বন একট',
#  'বন একট অপর',
#  'বন এব',
#  'বন কর',
#  'বন করত',
#  'বন যব',
#  'বনক',
#  'বপ',
#  'বপ লন',
#  'বপ লন কর',
#  'বপ সময',
#  'বর',
#  'বর তন',
#  'বর তম',
#  'বল',
#  'বল অনল',
#  'বল অনল ইন',
#  'বল আম',
#  'বল আম মন',
#  'বল মন',
#  'বল মন কর',
#  'বল মন হয়',
#  'বলত',
#  'বস',
#  'বহ',
#  'বহ কর',
#  'বড়',
#  'বড় হত',
#  'বয়',
#  'বয় রক',
#  'বয় রক যথ',
#  'বয়ত',
#  'বয়ত সহয',
#  'বয়ত সহয রচ',
#  'বয়স',
#  'বয়স পর',
#  'বয়স পর যন',
#  'ভব',
#  'ভব কর',
#  'ভব কর উচ',
#  'ভব কর এই',
#  'ভব যৎ',
#  'ভব যৎ অন',
#  'ভব যৎ এর',
#  'ভব যৎ গড',
#  'ভব যৎ বনক',
#  'ভব রব',
#  'ভব হয',
#  'ভব হয হল',
#  'ভর',
#  'ভর করছ',
#  'ভর করছ ধরন',
#  'ভর করব',
#  'ভর করব যদ',
#  'ভরশ',
#  'ভরশ নন',
#  'ভরশ নন অবসর',
#  'মও',
#  'মও করত',
#  'মও করত সক',
#  'মক',
#  'মক আচ',
#  'মক আচ রণ',
#  'মক আপন',
#  'মক আপন আপন',
#  'মক একট',
#  'মক একট রভ',
#  'মক ডক',
#  'মক ডক উস',
#  'মক দক',
#  'মক দক ষত',
#  'মক দন',
#  'মক দন নয়',
#  'মক ষমত',
#  'মক ষমত কম',
#  'মগ',
#  'মগ অন',
#  'মগ অন ভব',
#  'মগ অন রত',
#  'মগ অভ',
#  'মগ অভ কর',
#  'মগ একরকম',
#  'মগ একরকম যকর',
#  'মগ এখন',
#  'মগ এখন টবল',
#  'মগ এমন',
#  'মগ এমন পর',
#  'মগ কনস',
#  'মগ কনস কম',
#  'মগ যবহ',
#  'মগ যবহ কর',
#  'মগ রণ',
#  'মগ রণ আসক',
#  'মগ রয',
#  'মগ রয এমন',
#  'মগ হব',
#  'মগ হভ',
#  'মগ হভ অন',
#  'মজ',
#  'মজ আমর',
#  'মজ আমর সময়',
#  'মজ এব',
#  'মজ এব উপভ',
#  'মজ এব রক',
#  'মজ কর',
#  'মজ কর জন',
#  'মজ জন',
#  'মজ জন অনল',
#  'মজ জন উচ',
#  'মজ জন হল',
#  'মজ বন',
#  ...]

# %%
def train_test_splits(data, train_size):
  train = data[:train_size]
  test = data[train_size:]
  return train, test

# %%
train_size = int(len(df) * .80)
print("Train Size: "+str(train_size))
print("Test Size: "+str(len(df)-train_size))
# Out:
# Train Size: 320
# Test Size: 81

# %%
x_train, x_test = train_test_splits(x, train_size)
y1_train, y1_test = train_test_splits(y1, train_size)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()

# %%
model.fit(x_train, y1_train)
# Out:
# MultinomialNB()

# %%
score = model.score(x_test, y1_test)
print("Accuracy: %0.2f" %score)
# Out:
# Accuracy: 0.63

# %%
y_preds = model.predict(x_test)

# %%
typeLabels = ['নিরপেক্ষ', 'নেগেটিভ','পজিটিভ']
j = len(x_test)
for i in range(10):
  print("Text: "+df['opinion'][j])
  print("Acctual Type: "+typeLabels[int(y1_test[i])])
  print("Predicted Type: "+typeLabels[int(y_preds[i])])
  j = j+1
  print("")
# Out:
# Text: অনলাইন গেম খেলা  সত্যিই একটি খারাপ অভ্যাস।
# Acctual Type: নিরপেক্ষ
# Predicted Type: নিরপেক্ষ
#
# Text: সীমার মধ্যে অনলাইন গেম খেলা উচিত। যেনো এর ক্ষতিকর প্রভাব না পড়ে।
# Acctual Type: পজিটিভ
# Predicted Type: নেগেটিভ
#
# Text: অনলাইন গেম খেলা বিনোদনের একটি মাধ্যম।
# Acctual Type: নিরপেক্ষ
# Predicted Type: নেগেটিভ
#
# Text: আমি গেমিং পছন্দ করি না।
# Acctual Type: নিরপেক্ষ
# Predicted Type: নিরপেক্ষ
#
# Text: বেশিরভাগ ক্ষেত্রে আমি অনলাইন গেম খেলা সমর্থন করি না।
# Acctual Type: নিরপেক্ষ
# Predicted Type: নেগেটিভ
#
# Text: সময় নষ্ট করা ছাড়া কিছুই না অনলাইন গেম খেলা।
# Acctual Type: নেগেটিভ
# Predicted Type: নেগেটিভ
#
# Text: নিজেকে নিয়ন্ত্রণ করতে পারলে ভালো তাছাড়া ক্ষতিকর।
# Acctual Type: পজিটিভ
# Predicted Type: পজিটিভ
#
# Text: অনলাইন গেমটি বিনোদনমূলক কিন্তু দৈনিক ভিত্তিতে দীর্ঘ সময়ের জন্য অনলাইন গেম খেলা একটি ক্ষতিকর দিক।
# Acctual Type: নেগেটিভ
# Predicted Type: নেগেটিভ
#
# Text: অনলাইন গেম খেলার কোনো দরকার আসে না।
# Acctual Type: নেগেটিভ
# Predicted Type: নেগেটিভ
#
# Text: অনলাইন গেমে আসক্তি হয়ে গেলে সমস্যা।
# Acctual Type: নেগেটিভ
# Predicted Type: নিরপেক্ষ

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn import metrics

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb.fit(x_train,y1_train)
predmnb = mnb.predict(x_test)
print("Confusion Matrix for Multinomial Naive Bayes:")
print(confusion_matrix(y1_test,predmnb))
print("Score:",round(accuracy_score(y1_test,predmnb)*100,2))
print("Classification Report:")
print(classification_report(y1_test,predmnb))
# cross_val_mnb = cross_val_score(mnb, x, y1, cv=5)
# print("5-flod Cross Validation Score: ", round(cross_val_mnb.mean()*100,2))
# Out:
# Confusion Matrix for Multinomial Naive Bayes:
# [[ 4  6  2]
#  [ 6 19  4]
#  [ 6  6 28]]
# Score: 62.96
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.33      0.29        12
#            1       0.61      0.66      0.63        29
#            2       0.82      0.70      0.76        40
#
#     accuracy                           0.63        81
#    macro avg       0.56      0.56      0.56        81
# weighted avg       0.66      0.63      0.64        81

# %%
acc1=round(accuracy_score(y1_test,predmnb)*100,2)
print("Accuracy:",acc1,"%")
# Out:
# Accuracy: 62.96 %

# %%
feature_names = cv.get_feature_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# from sklearn.model_selection import train_test_split, cross_val_score

# %%
# x_train, x_test, y1_train, y1_test = train_test_split(x, y1, test_size = 0.25, random_state=42)

# %%
# print("Total Data: "+str(len(x)))
# print("Train Size: "+str(len(x_train)))
# print("Test Size: "+str(len(x_test)))

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y1_train)
preddt = dt.predict(x_test)
print("Confusion Matrix for Decision Tree:")
print(confusion_matrix(y1_test,preddt))
print("Score:",round(accuracy_score(y1_test,preddt)*100,2))
print("Classification Report:")
print(classification_report(y1_test,preddt))
# cross_val_dt = cross_val_score(dt, x, y1, cv=5)
# print("5-flod Cross Validation Score: ", round(cross_val_dt.mean()*100,2))
# Out:
# Confusion Matrix for Decision Tree:
# [[ 4  8  0]
#  [ 6 18  5]
#  [11 14 15]]
# Score: 45.68
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.19      0.33      0.24        12
#            1       0.45      0.62      0.52        29
#            2       0.75      0.38      0.50        40
#
#     accuracy                           0.46        81
#    macro avg       0.46      0.44      0.42        81
# weighted avg       0.56      0.46      0.47        81

# %%
acc2=round(accuracy_score(y1_test,preddt)*100,2)
print("Accuracy:",acc2,"%")
# Out:
# Accuracy: 45.68 %

# %%
from sklearn.ensemble import RandomForestClassifier
rmfr = RandomForestClassifier()
rmfr.fit(x_train,y1_train)
predrmfr = rmfr.predict(x_test)
print("Confusion Matrix for Random Forest Classifier:")
print(confusion_matrix(y1_test,predrmfr))
print("Score:",round(accuracy_score(y1_test,predrmfr)*100,2))
print("Classification Report:")
print(classification_report(y1_test,predrmfr))
# cross_val_rmfr = cross_val_score(rmfr, x, y1, cv=5)
# print("5-flod Cross Validation Score: ", round(cross_val_rmfr.mean()*100,2))
# Out:
# Confusion Matrix for Random Forest Classifier:
# [[ 3  9  0]
#  [ 5 24  0]
#  [ 4 17 19]]
# Score: 56.79
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25        12
#            1       0.48      0.83      0.61        29
#            2       1.00      0.47      0.64        40
#
#     accuracy                           0.57        81
#    macro avg       0.58      0.52      0.50        81
# weighted avg       0.70      0.57      0.57        81

# %%
acc3=round(accuracy_score(y1_test,predrmfr)*100,2)
print("Accuracy:",acc3,"%")
# Out:
# Accuracy: 56.79 %

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(x_train,y1_train)
predsvm = svm.predict(x_test)
print("Confusion Matrix for Support Vector Machines:")
print(confusion_matrix(y1_test,predsvm))
print("Score:",round(accuracy_score(y1_test,predsvm)*100,2))
print("Classification Report:")
print(classification_report(y1_test,predsvm))
# cross_val_svm = cross_val_score(svm, x, y1, cv=5)
# print("5-flod Cross Validation Score: ", round(cross_val_svm.mean()*100,2))
# Out:
# Confusion Matrix for Support Vector Machines:
# [[ 5  6  1]
#  [ 6 23  0]
#  [24 11  5]]
# Score: 40.74
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.14      0.42      0.21        12
#            1       0.57      0.79      0.67        29
#            2       0.83      0.12      0.22        40
#
#     accuracy                           0.41        81
#    macro avg       0.52      0.44      0.37        81
# weighted avg       0.64      0.41      0.38        81

# %%
acc4=round(accuracy_score(y1_test,predsvm)*100,2)
print("Accuracy:",acc4,"%")
# Out:
# Accuracy: 40.74 %

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y1_train)
predknn = knn.predict(x_test)
print("Confusion Matrix for K Neighbors Classifier:")
print(confusion_matrix(y1_test,predknn))
print("Score: ",round(accuracy_score(y1_test,predknn)*100,2))
print("Classification Report:")
print(classification_report(y1_test,predknn))
# cross_val_knn = cross_val_score(knn, x, y1, cv=5)
# print("5-flod Cross Validation Score: ", round(cross_val_knn.mean()*100,2))
# Out:
# Confusion Matrix for K Neighbors Classifier:
# [[ 4  7  1]
#  [ 6 23  0]
#  [15 23  2]]
# Score:  35.8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.16      0.33      0.22        12
#            1       0.43      0.79      0.56        29
#            2       0.67      0.05      0.09        40
#
#     accuracy                           0.36        81
#    macro avg       0.42      0.39      0.29        81
# weighted avg       0.51      0.36      0.28        81

# %%
acc5=round(accuracy_score(y1_test,predknn)*100,2)
print("Accuracy:",acc5,"%")
# Out:
# Accuracy: 35.8 %

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(x_train,y1_train)
predxgb = xgb.predict(x_test)
print("Confusion Matrix for xgboost Classifier:")
print(confusion_matrix(y1_test,predxgb))
print("Score: ",round(accuracy_score(y1_test,predxgb)*100,2))
print("Classification Report:")
print(classification_report(y1_test,predxgb))
# cross_val_xgb = cross_val_score(xgb, x, y1, cv=5)
# print("5-flod Cross Validation Score: ", round(cross_val_xgb.mean()*100,2))
# Out:
# Confusion Matrix for xgboost Classifier:
# [[ 2  9  1]
#  [ 3 23  3]
#  [ 3 12 25]]
# Score:  61.73
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.17      0.20        12
#            1       0.52      0.79      0.63        29
#            2       0.86      0.62      0.72        40
#
#     accuracy                           0.62        81
#    macro avg       0.54      0.53      0.52        81
# weighted avg       0.65      0.62      0.61        81

# %%
acc6=round(accuracy_score(y1_test,predxgb)*100,2)
print("Accuracy:",acc6,"%")
# Out:
# Accuracy: 61.73 %

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import plot_confusion_matrix

classifiers = [DecisionTreeClassifier(criterion='entropy', max_depth=20, min_samples_leaf=10),
               RandomForestClassifier(),
               MultinomialNB(alpha = 1.5, fit_prior = True),
               XGBClassifier(),
               SVC(),
               KNeighborsClassifier(metric = 'manhattan', n_neighbors = 15, weights = 'uniform')]
for cls in classifiers:
    cls.fit(x_train, y1_train)

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,10))

for cls, ax in zip(classifiers, axes.flatten()):
    plot_confusion_matrix(cls, 
                          x_test, 
                          y1_test, 
                          ax=ax, 
                          cmap='Blues')
    ax.title.set_text(type(cls).__name__)
plt.tight_layout()
plt.savefig('confusion_matrix.jpg')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('MNB','DT','RF','SVM','KNN','XGB')
y_pos = np.arange(len(objects))
performance = [acc1,acc2,acc3,acc4,acc5,acc6]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Score')
plt.title('Best Accuracy')

plt.show()
